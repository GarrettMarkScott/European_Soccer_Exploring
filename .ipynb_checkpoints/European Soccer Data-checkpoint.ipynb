# %% [markdown]
# # Attributes of Winning Teams
# ## Exploring the Data of the EU Soccer League
#
# The goal of this analysis will be to see if there are common attributes amoung the top performing leagues in the European Soccer League. Data is from a Kaggle post,[European Soccer Database](https://www.kaggle.com/hugomathien/soccer) by Hugomathien.
#
# The process of discovery will be the following
# 1. Create SQL Queries to gather/organize original data
#     * Which teams the players belong too (most recent year)
#     * Join the player attributes to those teams (most recent performance scores)
#     * Which teams placed top on the league (most recent year)
# 2. Read the SQL Queries into Pandas for further manipulation
# 3. Provide exploratory visualization showing the combined attributes of each top-performing team
# 4. Make a judgement if there are common attributes that matter most to success

# %% [markdown]
# ## Setting Up Environment
#
# First I want to make sure I have my enviroments set up. I have a work station with three monitors but I am not always there so I want to make sure I can do analysis on the fly on my Chromebook. To do this I have set up a cloud instance with [Amazon SageMaker](https://docs.aws.amazon.com/sagemaker/latest/dg/whatis.html). I started the project on my workstation and then createe my [GitHub Repo](https://github.com/GarrettMarkScott/European_Soccer_Exploring). In the process of doing this I quickly learned that the 300mb database (SQLite) was too large for a simple git push command. This forced me to create a .gitignore file that I placed the database in. I then was able to clone the git repo into my Jupyter Cloud Instance and simply upload the SQLite database into the same directory in my cloud instance. Now I can push/pull from both machines without large file transfers.
#
# I used the below code to check to make sure my environment was working.

# %%
#These are the general items for simple loading

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import itertools
import pprint

pp = pprint.PrettyPrinter(indent=4)

conn = sqlite3.connect('soccer_data.sqlite')
tables = pd.read_sql('SELECT * FROM sqlite_master WHERE type="table";', conn)
countries = pd.read_sql('SELECT * FROM Country;', conn)
players = pd.read_sql('SELECT player_api_id, player_name FROM Player;', conn)
player_att = pd.read_sql('SELECT * FROM Player_Attributes;',conn)
league_teams = pd.read_sql('SELECT team_long_name FROM Team', conn)
player_att.columns.tolist() #I use this line for previewing original data
# Out:
# ['id',
#  'player_fifa_api_id',
#  'player_api_id',
#  'date',
#  'overall_rating',
#  'potential',
#  'preferred_foot',
#  'attacking_work_rate',
#  'defensive_work_rate',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'free_kick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes']

# %% [markdown]
# ## Matching Players to Teams
#
# Next was time to create the SQL queries to organize the raw data a little bit so it was easier to work with. I was able to borrow my girlfriends mac and load the SQLite datebase into [DB Browser for SQLite] for quick SQL Queries (since chromebook can't run programs).
#
# I spent quite a bit of time trying to figure out how to merge the players to teams. As seen in the screenshot below there was not a common key between player and team. My assumption is that this is due to players switching various teams over their career.
#
# ![Table Screenshot](https://i.imgur.com/KCpqgS5.jpg)
#
# I checked the *player_fifa_api_id* but that had 11,060 DISTINCT rows. I was able to create the query below that used the Match table data to see which players were associated with each match. Due to there being substitutions throughout the match, it is assumed that these 11 players are the starting roster for each team during the 2007-2008 season (May-August).
#
# This turned out to be a pretty big challege because I did not relize DB Browser for SQLite seemingly does not have a formal Date type but rather stores date types as a *Timestring* format. If anyone has any information regarding this and how to deal with it in the best/cleanest way I have made a [Stack Overflow Post](https://stackoverflow.com/questions/56202599/converting-timestrings-to-datetime-db-browser)

# %%
#Matches from most recent season and the starting players (in ID format)
#Is there an easy solution to use parameters for date range?
matches = pd.read_sql_query('''SELECT t.team_long_name, m.home_player_1, m.home_player_2, 
                                      m.home_player_3,m.home_player_4, m.home_player_5,
                                      m.home_player_6, m.home_player_7, m.home_player_8,
                                      m.home_player_9, m.home_player_10, m.home_player_11,
                                      m.date, m.home_team_goal, m.away_team_goal 
                                 FROM Team t 
                                 JOIN Match m ON t.team_api_id = m.home_team_api_id 
                                WHERE DATE(m.date) BETWEEN "2015-05-01" and "2016-05-25" 
                                ORDER BY t.team_long_name;''', conn, )
matches
# Out:
#                 team_long_name  home_player_1  home_player_2  home_player_3  \
# 0                   1. FC Köln       212815.0        36395.0        36934.0
# 1                   1. FC Köln       212815.0        36395.0        36934.0
# 2                   1. FC Köln       212815.0       127945.0       231753.0
# 3                   1. FC Köln       212815.0       127945.0        36934.0
# 4                   1. FC Köln       212815.0       127945.0        36934.0
# 5                   1. FC Köln       212815.0       212377.0       231753.0
# 6                   1. FC Köln       212815.0       212377.0        36934.0
# 7                   1. FC Köln       212815.0       212377.0       231753.0
# 8                   1. FC Köln       212815.0        36934.0        28435.0
# 9                   1. FC Köln       212815.0        36934.0        28435.0
# 10                  1. FC Köln       212815.0       231753.0        36934.0
# 11                  1. FC Köln       212815.0       231753.0        36934.0
# 12                  1. FC Köln       212815.0       127945.0        36934.0
# 13                  1. FC Köln       212815.0       212377.0       231753.0
# 14                  1. FC Köln       212815.0       231753.0        36934.0
# 15                  1. FC Köln       212815.0       231753.0        36934.0
# 16                  1. FC Köln       212815.0       212377.0       231753.0
# 17                  1. FC Köln       212815.0       127945.0       231753.0
# 18                  1. FC Köln       212815.0       212377.0       231753.0
# 19             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 20             1. FSV Mainz 05       287894.0        36000.0        36806.0
# 21             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 22             1. FSV Mainz 05       287894.0       147726.0        36000.0
# 23             1. FSV Mainz 05       287894.0        94915.0       147726.0
# 24             1. FSV Mainz 05       287894.0        94915.0       193901.0
# 25             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 26             1. FSV Mainz 05       287894.0        94915.0       147726.0
# 27             1. FSV Mainz 05       287894.0       191080.0       147726.0
# 28             1. FSV Mainz 05       287894.0       191080.0       147726.0
# 29             1. FSV Mainz 05       287894.0       191080.0       147726.0
# ...                        ...            ...            ...            ...
# 3611            Zagłębie Lubin       206641.0       208315.0       118822.0
# 3612            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3613            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3614            Zagłębie Lubin       232143.0        69018.0        72479.0
# 3615            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3616            Zagłębie Lubin       232143.0       208315.0       118822.0
# 3617            Zagłębie Lubin       232143.0        69018.0       208315.0
# 3618            Zagłębie Lubin       232143.0        69018.0        72479.0
# 3619            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3620            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3621            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3622            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3623            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3624  Évian Thonon Gaillard FC       181619.0       179522.0        46708.0
# 3625  Évian Thonon Gaillard FC       181619.0       179891.0        71603.0
# 3626             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3627             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3628             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3629             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3630             Śląsk Wrocław        43313.0        13437.0       172896.0
# 3631             Śląsk Wrocław       463957.0       522276.0        13437.0
# 3632             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3633             Śląsk Wrocław        43313.0        69428.0        13437.0
# 3634             Śląsk Wrocław        43313.0        43317.0        13554.0
# 3635             Śląsk Wrocław       618737.0        13554.0        13437.0
# 3636             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3637             Śląsk Wrocław       618737.0        13554.0        13437.0
# 3638             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3639             Śląsk Wrocław        43313.0        13554.0        13437.0
# 3640             Śląsk Wrocław        43313.0       429914.0        13437.0
#
#       home_player_4  home_player_5  home_player_6  home_player_7  \
# 0          264221.0       307210.0        36086.0       167589.0
# 1          264221.0        22824.0       450976.0        36086.0
# 2          303800.0       307210.0       166449.0        36086.0
# 3          303800.0       307210.0       166449.0        36086.0
# 4          303800.0       307210.0       238438.0        36086.0
# 5           36934.0       303800.0       307210.0       450976.0
# 6          303800.0       307210.0       167589.0        36086.0
# 7          303800.0       307210.0       127945.0       167589.0
# 8          303800.0       127945.0       450976.0       307210.0
# 9          303800.0       127945.0        36086.0       307210.0
# 10         303800.0       307210.0        36086.0       127945.0
# 11          28435.0       303800.0       307210.0       127945.0
# 12         303800.0       307210.0        36086.0       167589.0
# 13         303800.0       307210.0       127945.0        36086.0
# 14          28435.0       259439.0        36086.0       307210.0
# 15          28435.0       303800.0       307210.0       127945.0
# 16         303800.0       307210.0       127945.0        36086.0
# 17         303800.0       307210.0       238438.0        36086.0
# 18         303800.0       307210.0       127945.0       450976.0
# 19         193901.0       171472.0       237542.0        59595.0
# 20         171472.0       130667.0       130118.0       201888.0
# 21         193901.0       171472.0        59595.0        95228.0
# 22         193901.0        49885.0        59595.0       162679.0
# 23          36000.0       171472.0        49885.0       162679.0
# 24         459000.0       171472.0        59595.0       162679.0
# 25         193901.0       171472.0        59595.0       162679.0
# 26         193901.0       426873.0        59595.0       162679.0
# 27         193901.0       426873.0        59595.0       162679.0
# 28          36000.0       426873.0        59595.0        95228.0
# 29         459000.0       426873.0        59595.0        95228.0
# ...             ...            ...            ...            ...
# 3611        72479.0       163618.0       116874.0        69485.0
# 3612       118822.0       163618.0       545056.0        68762.0
# 3613       545060.0       163618.0        68802.0        69485.0
# 3614       545060.0       163618.0       116874.0        68762.0
# 3615        68762.0       163618.0        69485.0       467316.0
# 3616        72479.0       163618.0       197560.0        68762.0
# 3617       118822.0       163618.0       545056.0       197560.0
# 3618       118822.0       163618.0       545056.0        69485.0
# 3619        72479.0       163618.0       545056.0        69485.0
# 3620        72479.0       163618.0        69485.0        68762.0
# 3621       545060.0       163618.0       239253.0        68762.0
# 3622       118822.0       163618.0        68762.0       545056.0
# 3623       118822.0       163618.0        68762.0       545056.0
# 3624        74169.0       610533.0       185000.0        26333.0
# 3625        46708.0        35121.0       185000.0       317062.0
# 3626        13554.0        77778.0        43317.0       179818.0
# 3627       172896.0        13554.0       181227.0        22831.0
# 3628        13554.0        77778.0       172896.0        43317.0
# 3629        13554.0        77778.0       179818.0        43317.0
# 3630        13554.0        77778.0       181227.0        22831.0
# 3631        43317.0        77778.0        69428.0       172896.0
# 3632       436553.0        77778.0       172896.0       181227.0
# 3633       436553.0        77778.0       181227.0        22831.0
# 3634            NaN       436553.0       181227.0       172896.0
# 3635       436553.0       522276.0       176704.0       181227.0
# 3636        43317.0        77778.0       172896.0       181227.0
# 3637       436553.0        77778.0       176704.0       172896.0
# 3638        43317.0        77778.0       179818.0       181227.0
# 3639        43317.0        77778.0       172896.0       181227.0
# 3640        43317.0        13554.0       172896.0       309890.0
#
#       home_player_8  home_player_9  home_player_10  home_player_11  \
# 0          127945.0       459493.0        166449.0        196366.0
# 1          127945.0       459493.0        196366.0        166449.0
# 2          167589.0       459493.0        177941.0         71605.0
# 3          167589.0       260470.0        177941.0         71605.0
# 4          167589.0       260470.0        177941.0         71605.0
# 5           36086.0        22824.0        127945.0        238438.0
# 6          127945.0       166449.0        260470.0         71605.0
# 7           36086.0       260470.0        238438.0         71605.0
# 8          259439.0       238438.0        260470.0         71605.0
# 9          259439.0       450976.0         71605.0        260470.0
# 10         450976.0       260470.0        259439.0         71605.0
# 11          36086.0       450976.0        260470.0         71605.0
# 12         238438.0       260470.0        450976.0         71605.0
# 13         167589.0       260470.0         71605.0        238438.0
# 14         127945.0       166449.0        450976.0         71605.0
# 15         450976.0       260470.0        238438.0         71605.0
# 16         167589.0       260470.0         71605.0        166449.0
# 17         450976.0       260470.0        166449.0         71605.0
# 18         260470.0        36086.0        166449.0         71605.0
# 19         287231.0        22313.0        201888.0         20694.0
# 20         237542.0        59595.0        278863.0         20694.0
# 21         178804.0       278863.0        287231.0        276760.0
# 22         180126.0       278863.0        287231.0        459499.0
# 23         287231.0       278863.0        130118.0        459499.0
# 24         287231.0       278863.0        130118.0        459499.0
# 25         130118.0       278863.0        287231.0        459499.0
# 26         178804.0       278863.0        287231.0        459499.0
# 27         178804.0       278863.0        287231.0        291425.0
# 28         130118.0       278863.0        287231.0        291425.0
# 29         130118.0       278863.0        287231.0        291425.0
# ...             ...            ...             ...             ...
# 3611       545056.0        68802.0        543298.0         25255.0
# 3612       116874.0       239253.0         68802.0         25255.0
# 3613       545056.0       116874.0        543298.0         25255.0
# 3614       239253.0       197560.0        543298.0             NaN
# 3615       197560.0        69818.0         68802.0         25255.0
# 3616       545056.0        68802.0         25255.0        543298.0
# 3617       287341.0       239253.0         68802.0        543298.0
# 3618       116874.0       287341.0         68802.0        543298.0
# 3619        68802.0       287341.0        197560.0        543298.0
# 3620       116874.0       287341.0         68802.0         25255.0
# 3621       116874.0        69818.0         68802.0         25255.0
# 3622       116874.0       239253.0         68802.0         25255.0
# 3623       116874.0       239253.0         68802.0        543298.0
# 3624       400962.0       317062.0        187669.0        210466.0
# 3625       288783.0        92263.0        210466.0        400962.0
# 3626       172896.0        22831.0         69428.0         69256.0
# 3627       179818.0       309890.0         69256.0         93453.0
# 3628       179818.0       309890.0         69256.0         93453.0
# 3629       172896.0        22831.0         69256.0         72458.0
# 3630       522276.0       179818.0        429914.0         69256.0
# 3631       181227.0       429914.0        179818.0         93453.0
# 3632       429914.0       196288.0        167491.0         93453.0
# 3633       176704.0       196288.0        167491.0         93453.0
# 3634       176704.0       196288.0         69256.0         93453.0
# 3635       172896.0        22831.0         69256.0        643982.0
# 3636       179818.0        72458.0        176704.0         93453.0
# 3637       181227.0       429914.0        196288.0        643982.0
# 3638       172896.0        69256.0        176704.0         93453.0
# 3639       179818.0       309890.0        176704.0         93453.0
# 3640       179818.0        22831.0         72458.0         69256.0
#
#                      date  home_team_goal  away_team_goal
# 0     2015-05-10 00:00:00               2               0
# 1     2015-05-23 00:00:00               2               2
# 2     2015-10-31 00:00:00               0               0
# 3     2015-11-21 00:00:00               0               0
# 4     2015-12-05 00:00:00               0               1
# 5     2015-12-19 00:00:00               2               1
# 6     2016-01-23 00:00:00               1               3
# 7     2015-08-22 00:00:00               1               1
# 8     2016-02-13 00:00:00               3               1
# 9     2016-02-26 00:00:00               0               1
# 10    2016-03-05 00:00:00               1               3
# 11    2016-03-19 00:00:00               0               1
# 12    2016-04-10 00:00:00               0               2
# 13    2015-08-29 00:00:00               2               1
# 14    2016-04-23 00:00:00               4               1
# 15    2016-05-07 00:00:00               0               0
# 16    2015-09-19 00:00:00               1               0
# 17    2015-09-25 00:00:00               1               1
# 18    2015-10-18 00:00:00               0               1
# 19    2015-05-03 00:00:00               1               2
# 20    2015-05-16 00:00:00               2               0
# 21    2015-08-15 00:00:00               0               1
# 22    2015-10-24 00:00:00               1               3
# 23    2015-11-07 00:00:00               2               0
# 24    2015-11-28 00:00:00               2               1
# 25    2015-12-11 00:00:00               0               0
# 26    2016-01-29 00:00:00               1               0
# 27    2016-02-12 00:00:00               2               1
# 28    2016-02-28 00:00:00               3               1
# 29    2016-03-06 00:00:00               0               0
# ...                   ...             ...             ...
# 3611  2015-10-24 00:00:00               0               0
# 3612  2015-11-06 00:00:00               1               3
# 3613  2015-12-01 00:00:00               0               2
# 3614  2015-12-04 00:00:00               2               0
# 3615  2015-07-25 00:00:00               0               2
# 3616  2015-12-18 00:00:00               2               4
# 3617  2016-02-21 00:00:00               1               2
# 3618  2016-03-01 00:00:00               1               0
# 3619  2016-03-13 00:00:00               1               1
# 3620  2016-04-03 00:00:00               4               1
# 3621  2015-08-14 00:00:00               2               1
# 3622  2015-08-29 00:00:00               3               1
# 3623  2015-09-18 00:00:00               4               2
# 3624  2015-05-09 00:00:00               2               3
# 3625  2015-05-16 00:00:00               1               2
# 3626  2015-07-19 00:00:00               1               4
# 3627  2015-09-25 00:00:00               1               2
# 3628  2015-10-16 00:00:00               0               1
# 3629  2015-10-31 00:00:00               1               1
# 3630  2015-11-28 00:00:00               0               0
# 3631  2015-12-11 00:00:00               2               1
# 3632  2016-02-12 00:00:00               1               0
# 3633  2016-02-26 00:00:00               0               0
# 3634  2016-03-05 00:00:00               0               2
# 3635  2016-03-19 00:00:00               0               0
# 3636  2015-08-02 00:00:00               2               0
# 3637  2016-04-09 00:00:00               2               1
# 3638  2015-08-09 00:00:00               0               0
# 3639  2015-08-22 00:00:00               1               1
# 3640  2015-09-12 00:00:00               3               1
#
# [3641 rows x 15 columns]

# %% [raw]
# The next step of my process is to create a compound dictionary that has the players as values of the teams and attributues as values of the players. Following that we can begin investigating their attributes!

# %% [markdown]
# ## Create a Function to Connect Player ID to Player Name
# To keep our code modular as possible the function below can be used to return a player's name based on ID input.
#
# The first result **player_api_id** is the test and you will see that it returns **Aaron Appindangoye** correctly.

# %%
players
# Out:
#        player_api_id             player_name
# 0             505942      Aaron Appindangoye
# 1             155782         Aaron Cresswell
# 2             162549             Aaron Doran
# 3              30572           Aaron Galindo
# 4              23780            Aaron Hughes
# 5              27316              Aaron Hunt
# 6             564793              Aaron Kuhl
# 7              30895            Aaron Lennon
# 8             528212            Aaron Lennox
# 9             101042           Aaron Meijers
# 10             23889           Aaron Mokoena
# 11            231592              Aaron Mooy
# 12            163222          Aaron Muirhead
# 13             40719            Aaron Niguez
# 14             75489            Aaron Ramsey
# 15            597948           Aaron Splaine
# 16            161644   Aaron Taylor-Sinclair
# 17             23499         Aaron Wilbraham
# 18            120919       Aatif Chahechouhe
# 19             46447               Abasse Ba
# 20            167027       Abdelaziz Barrada
# 21            245653   Abdelfettah Boukhriss
# 22            128456  Abdelhamid El Kaoutari
# 23             42664      Abdelkader Ghezzal
# 24            425950         Abdellah Zoubir
# 25             38423      Abdelmajid Oulmers
# 26              3264      Abdelmalek Cherrad
# 27            467485  Abdelmalek El Hasnaoui
# 28            306735     Abdelouahed Chakhsi
# 29             41659        Abderrazak Jadid
# ...              ...                     ...
# 11030         244155                 Zezinho
# 11031          19696               Zhi Zheng
# 11032         290868             Zhi-Gin Lam
# 11033         169594             Zie Diabate
# 11034         244953            Ziggy Gordon
# 11035         200607         Ziguy Badibanga
# 11036         642618        Zinedine Machach
# 11037         277772              Zinho Gano
# 11038         246332             Ziri Hammar
# 11039         532766                    Zizo
# 11040          27305       Zlatan Bajramovic
# 11041          35724      Zlatan Ibrahimovic
# 11042          12574      Zlatan Ljubijankic
# 11043          39494            Zlatko Dedic
# 11044          17233           Zlatko Janjic
# 11045          42860        Zlatko Junuzovic
# 11046          37128           Zola Matumona
# 11047          24737             Zoltan Gera
# 11048         107281          Zoltan Stieber
# 11049          39801          Zoltan Szelesi
# 11050         491794         Zoran Josipovic
# 11051          56929          Zoran Rendulic
# 11052          99031             Zoran Tosic
# 11053         192132      Zouhaier Dhaouadhi
# 11054         282473          Zouhair Feddal
# 11055          26357          Zoumana Camara
# 11056         111182            Zsolt Laczko
# 11057          36491               Zsolt Low
# 11058          35506     Zurab Khizanishvili
# 11059          39902      Zvjezdan Misimovic
#
# [11060 rows x 2 columns]

# %%
#Reusable function to translate api key to player name

def player_id_to_name(id): 
    return(players[players['player_api_id'] == id].iloc[0,1])

player_id_to_name(505942)
# Out:
# 'Aaron Appindangoye'

# %% [markdown]
# ## Creating Compound Dictionary of Teams, Players, & Attributes
#
# Build a for loop that builds a teams dictionary with team as the key and players as the values.
#
# This is our goal:
# ```
# teams = {"team 1": {"Player 1": {"Dribbling": 4,
#                                  "Attack": 5,
#                                  "Speed": 9},
#                     "Player 2": {"Dribbling": 6,
#                                  "Attack": 10,
#                                  "Speed": 3},
#                     "Player 3": {"Dribbling": 2,
#                                  "Attack": 5,
#                                  "Speed": 8},
#                     },
#          "team 2": {"Player 1": {"Dribbling": 9,
#                                  "Attack": 6,
#                                  "Speed": 2},
#                     "Player 2": {"Dribbling": 10,
#                                  "Attack": 2,
#                                  "Speed": 8},
#                     "Player 3": {"Dribbling": 5,
#                                  "Attack": 5,
#                                  "Speed": 5},
#                     }
#             }
# ```

# %% [markdown]
# ### Creating dictionary of teams and starting players from most recent season
#
# #### Step 1: Create a list of teams

# %%
#Create a list of the teams to iterate
team_names = league_teams.values.tolist()
merged_team_names = list(itertools.chain(*team_names)) #Flatten list of lists
team_names = merged_team_names
print(len(team_names))
pprint.pprint(team_names)
# Out:
# 299
# ['KRC Genk',
#  'Beerschot AC',
#  'SV Zulte-Waregem',
#  'Sporting Lokeren',
#  'KSV Cercle Brugge',
#  'RSC Anderlecht',
#  'KAA Gent',
#  'RAEC Mons',
#  'FCV Dender EH',
#  'Standard de Liège',
#  'KV Mechelen',
#  'Club Brugge KV',
#  'KSV Roeselare',
#  'KV Kortrijk',
#  'Tubize',
#  'Royal Excel Mouscron',
#  'KVC Westerlo',
#  'Sporting Charleroi',
#  'Sint-Truidense VV',
#  'Lierse SK',
#  'KAS Eupen',
#  'Oud-Heverlee Leuven',
#  'Waasland-Beveren',
#  'KV Oostende',
#  'Royal Excel Mouscron',
#  'Manchester United',
#  'Newcastle United',
#  'Arsenal',
#  'West Bromwich Albion',
#  'Sunderland',
#  'Liverpool',
#  'West Ham United',
#  'Wigan Athletic',
#  'Aston Villa',
#  'Manchester City',
#  'Everton',
#  'Blackburn Rovers',
#  'Middlesbrough',
#  'Tottenham Hotspur',
#  'Bolton Wanderers',
#  'Stoke City',
#  'Hull City',
#  'Fulham',
#  'Chelsea',
#  'Portsmouth',
#  'Birmingham City',
#  'Wolverhampton Wanderers',
#  'Burnley',
#  'Blackpool',
#  'Swansea City',
#  'Queens Park Rangers',
#  'Norwich City',
#  'Southampton',
#  'Reading',
#  'Crystal Palace',
#  'Cardiff City',
#  'Leicester City',
#  'Bournemouth',
#  'Watford',
#  'AJ Auxerre',
#  'FC Nantes',
#  'Girondins de Bordeaux',
#  'SM Caen',
#  'Le Havre AC',
#  'OGC Nice',
#  'Le Mans FC',
#  'FC Lorient',
#  'Olympique Lyonnais',
#  'Toulouse FC',
#  'AS Monaco',
#  'Paris Saint-Germain',
#  'AS Nancy-Lorraine',
#  'LOSC Lille',
#  'Stade Rennais FC',
#  'Olympique de Marseille',
#  'FC Sochaux-Montbéliard',
#  'Grenoble Foot 38',
#  'Valenciennes FC',
#  'AS Saint-Étienne',
#  'RC Lens',
#  'Montpellier Hérault SC',
#  "US Boulogne Cote D'Opale",
#  'AC Arles-Avignon',
#  'Stade Brestois 29',
#  'AC Ajaccio',
#  'Évian Thonon Gaillard FC',
#  'Dijon FCO',
#  'Stade de Reims',
#  'SC Bastia',
#  'ES Troyes AC',
#  'En Avant de Guingamp',
#  'FC Metz',
#  'Angers SCO',
#  'GFC Ajaccio',
#  'FC Bayern Munich',
#  'Hamburger SV',
#  'Bayer 04 Leverkusen',
#  'Borussia Dortmund',
#  'FC Schalke 04',
#  'Hannover 96',
#  'VfL Wolfsburg',
#  '1. FC Köln',
#  'Eintracht Frankfurt',
#  'Hertha BSC Berlin',
#  'DSC Arminia Bielefeld',
#  'SV Werder Bremen',
#  'FC Energie Cottbus',
#  'TSG 1899 Hoffenheim',
#  'Borussia Mönchengladbach',
#  'VfB Stuttgart',
#  'Karlsruher SC',
#  'VfL Bochum',
#  'SC Freiburg',
#  '1. FC Nürnberg',
#  '1. FSV Mainz 05',
#  '1. FC Kaiserslautern',
#  'FC St. Pauli',
#  'FC Augsburg',
#  'Fortuna Düsseldorf',
#  'SpVgg Greuther Fürth',
#  'Eintracht Braunschweig',
#  'SC Paderborn 07',
#  'FC Ingolstadt 04',
#  'SV Darmstadt 98',
#  'Atalanta',
#  'Siena',
#  'Cagliari',
#  'Lazio',
#  'Catania',
#  'Genoa',
#  'Chievo Verona',
#  'Reggio Calabria',
#  'Fiorentina',
#  'Juventus',
#  'Milan',
#  'Bologna',
#  'Roma',
#  'Napoli',
#  'Sampdoria',
#  'Inter',
#  'Torino',
#  'Lecce',
#  'Udinese',
#  'Palermo',
#  'Bari',
#  'Livorno',
#  'Parma',
#  'Cesena',
#  'Brescia',
#  'Novara',
#  'Pescara',
#  'Hellas Verona',
#  'Sassuolo',
#  'Empoli',
#  'Frosinone',
#  'Carpi',
#  'Vitesse',
#  'FC Groningen',
#  'Roda JC Kerkrade',
#  'FC Twente',
#  'Willem II',
#  'Ajax',
#  'N.E.C.',
#  'De Graafschap',
#  'FC Utrecht',
#  'PSV',
#  'Heracles Almelo',
#  'Feyenoord',
#  'Sparta Rotterdam',
#  'ADO Den Haag',
#  'FC Volendam',
#  'SC Heerenveen',
#  'AZ',
#  'NAC Breda',
#  'RKC Waalwijk',
#  'VVV-Venlo',
#  'Excelsior',
#  'PEC Zwolle',
#  'SC Cambuur',
#  'Go Ahead Eagles',
#  'FC Dordrecht',
#  'Wisła Kraków',
#  'Polonia Bytom',
#  'Polonia Bytom',
#  'Ruch Chorzów',
#  'Legia Warszawa',
#  'P. Warszawa',
#  'Śląsk Wrocław',
#  'Lechia Gdańsk',
#  'Widzew Łódź',
#  'Odra Wodzisław',
#  'Lech Poznań',
#  'GKS Bełchatów',
#  'Arka Gdynia',
#  'Jagiellonia Białystok',
#  'Piast Gliwice',
#  'Cracovia',
#  'Korona Kielce',
#  'Zagłębie Lubin',
#  'Widzew Łódź',
#  'Podbeskidzie Bielsko-Biała',
#  'Pogoń Szczecin',
#  'Zawisza Bydgoszcz',
#  'Górnik Łęczna',
#  'Termalica Bruk-Bet Nieciecza',
#  'FC Porto',
#  'CF Os Belenenses',
#  'Sporting CP',
#  'Trofense',
#  'Vitória Guimarães',
#  'Vitória Setúbal',
#  'FC Paços de Ferreira',
#  'SC Braga',
#  'Amadora',
#  'Académica de Coimbra',
#  'Rio Ave FC',
#  'SL Benfica',
#  'Leixões SC',
#  'CD Nacional',
#  'Naval 1° de Maio',
#  'CS Marítimo',
#  'União de Leiria, SAD',
#  'S.C. Olhanense',
#  'Portimonense',
#  'SC Beira Mar',
#  'Feirense',
#  'Gil Vicente FC',
#  'Moreirense FC',
#  'Estoril Praia',
#  'FC Arouca',
#  'FC Penafiel',
#  'Boavista FC',
#  'Uniao da Madeira',
#  'Tondela',
#  'Falkirk',
#  'Rangers',
#  'Heart of Midlothian',
#  'Motherwell',
#  'Kilmarnock',
#  'Hibernian',
#  'Aberdeen',
#  'Inverness Caledonian Thistle',
#  'Celtic',
#  'St. Mirren',
#  'Hamilton Academical FC',
#  'Dundee United',
#  'St. Johnstone FC',
#  'Dunfermline Athletic',
#  'Dundee FC',
#  'Ross County FC',
#  'Partick Thistle F.C.',
#  'Valencia CF',
#  'RCD Mallorca',
#  'CA Osasuna',
#  'Villarreal CF',
#  'RC Deportivo de La Coruña',
#  'Real Madrid CF',
#  'CD Numancia',
#  'FC Barcelona',
#  'Racing Santander',
#  'Sevilla FC',
#  'Real Sporting de Gijón',
#  'Getafe CF',
#  'Real Betis Balompié',
#  'RC Recreativo',
#  'RCD Espanyol',
#  'Real Valladolid',
#  'Athletic Club de Bilbao',
#  'UD Almería',
#  'Atlético Madrid',
#  'Málaga CF',
#  'Xerez Club Deportivo',
#  'Real Zaragoza',
#  'CD Tenerife',
#  'Hércules Club de Fútbol',
#  'Levante UD',
#  'Real Sociedad',
#  'Granada CF',
#  'Rayo Vallecano',
#  'RC Celta de Vigo',
#  'Elche CF',
#  'SD Eibar',
#  'Córdoba CF',
#  'UD Las Palmas',
#  'Grasshopper Club Zürich',
#  'AC Bellinzona',
#  'BSC Young Boys',
#  'FC Basel',
#  'FC Aarau',
#  'FC Sion',
#  'FC Luzern',
#  'FC Vaduz',
#  'Neuchâtel Xamax',
#  'FC Zürich',
#  'FC St. Gallen',
#  'FC Thun',
#  'Servette FC',
#  'FC Lausanne-Sports',
#  'Lugano']

# %% [markdown]
# #### Step 2: Create a function to get each starting player of a team
# *Note the original SQL query already constrained the data to most recent season*

# %%
def get_team_players(x):
    #Gather all the players that have started in the match data. 
    all_team_players = matches[matches['team_long_name'] == x].iloc[:,2:12].values.astype(int).tolist()
    merged_team_players = list(itertools.chain(*all_team_players)) #flattens list of lists
    all_team_players = [] #resets variable for append function below

    #this for loops takes all the players api numbers, flattens to unique numbers, and stores them in variable
    for i in merged_team_players:  
        name = i
        if name not in all_team_players:
            all_team_players.append(name)
        else:
            pass
    return(all_team_players)

print(get_team_players('1. FC Köln'))
# Out:
# [36395, 36934, 264221, 307210, 36086, 167589, 127945, 459493, 166449, 196366, 22824, 450976, 231753, 303800, 177941, 71605, 260470, 238438, 212377, 28435, 259439]

# %% [markdown]
# #### Step 3: Create a dictionary using players as the values of each team
# **Goal:** To create the example dictionary below

# %%
teams = {}
teams['blue'] = {'stevie': {"Dribbling": 4,
                            "Attack": 5,
                            "Speed": 9},
                 'robbie': {"Dribbling": 6,
                            "Attack": 10,
                            "Speed": 3},
                 'joey':   {"Dribbling": 2,
                            "Attack": 5,
                            "Speed": 8}
                }

print('Original Goal')                  
pp.pprint(teams)
print()
# Out:
# Original Goal
# {   'blue': {   'joey': {'Attack': 5, 'Dribbling': 2, 'Speed': 8},
#                 'robbie': {'Attack': 10, 'Dribbling': 6, 'Speed': 3},
#                 'stevie': {'Attack': 5, 'Dribbling': 4, 'Speed': 9}}}

# %% [markdown]
# The code below is how I achieved the goal.
#
# A roadblock I ran into was that my team_names variable was returning single item lists that needed to be converted into a string for itterating.

# %%
#print('The output of team_names[0] is: '+ str(team_names[0])+'\n')
#print('The type of team_names[0] is: '+ str(type(str(team_names)))) #It was a LIST!!!! Now string
#print('The output of get_team_players("KRC Genk") is: \n')
#print(get_team_players('KRC Genk'))

teams = {}
for i in range(len(team_names)):   #Currently only returns first 5
    try:
        player_apis = get_team_players(str(team_names[i])) #Had to convert from list
        player_names = {}
        for api in player_apis:
            player_name = player_id_to_name(api)
            player_names[player_name] = player_att[player_att['player_api_id'] == api].iloc[1,:].transform(dict)
        teams[team_names[i]] = player_names
    except:
        #print('Team had no players registered')
        pass

#pp.pprint(teams)

# %% [markdown]
# **Use the cell below to test different dictionary lookups.**

# %%
teams['Hull City']["Dame N'Doye"]
# Out:
# {'id': 33945,
#  'player_fifa_api_id': 179875,
#  'player_api_id': 101969,
#  'date': '2016-01-21 00:00:00',
#  'overall_rating': 77.0,
#  'potential': 77.0,
#  'preferred_foot': 'right',
#  'attacking_work_rate': 'high',
#  'defensive_work_rate': 'medium',
#  'crossing': 56.0,
#  'finishing': 75.0,
#  'heading_accuracy': 77.0,
#  'short_passing': 63.0,
#  'volleys': 71.0,
#  'dribbling': 74.0,
#  'curve': 69.0,
#  'free_kick_accuracy': 70.0,
#  'long_passing': 38.0,
#  'ball_control': 74.0,
#  'acceleration': 78.0,
#  'sprint_speed': 78.0,
#  'agility': 74.0,
#  'reactions': 75.0,
#  'balance': 56.0,
#  'shot_power': 85.0,
#  'jumping': 70.0,
#  'stamina': 79.0,
#  'strength': 84.0,
#  'long_shots': 74.0,
#  'aggression': 72.0,
#  'interceptions': 40.0,
#  'positioning': 79.0,
#  'vision': 64.0,
#  'penalties': 60.0,
#  'marking': 35.0,
#  'standing_tackle': 38.0,
#  'sliding_tackle': 19.0,
#  'gk_diving': 14.0,
#  'gk_handling': 13.0,
#  'gk_kicking': 9.0,
#  'gk_positioning': 8.0,
#  'gk_reflexes': 16.0}

# %% [markdown]
# # Picking Top Teams
# We now have a nice dictionary of the teams, their registered players, and their attributes. Now let's write a command to discover the team with the most wins. Let's use some visualization to help us determine if we want data from the top 3, top 5, etc. out of the 299 teams.
#
# This should be based on winning percent vs. total sum.

# %%
matches['final_status'] = 'NaN'
matches.head()
# Out:
#   team_long_name  home_player_1  home_player_2  home_player_3  home_player_4  \
# 0     1. FC Köln       212815.0        36395.0        36934.0       264221.0
# 1     1. FC Köln       212815.0        36395.0        36934.0       264221.0
# 2     1. FC Köln       212815.0       127945.0       231753.0       303800.0
# 3     1. FC Köln       212815.0       127945.0        36934.0       303800.0
# 4     1. FC Köln       212815.0       127945.0        36934.0       303800.0
#
#    home_player_5  home_player_6  home_player_7  home_player_8  home_player_9  \
# 0       307210.0        36086.0       167589.0       127945.0       459493.0
# 1        22824.0       450976.0        36086.0       127945.0       459493.0
# 2       307210.0       166449.0        36086.0       167589.0       459493.0
# 3       307210.0       166449.0        36086.0       167589.0       260470.0
# 4       307210.0       238438.0        36086.0       167589.0       260470.0
#
#    home_player_10  home_player_11                 date  home_team_goal  \
# 0        166449.0        196366.0  2015-05-10 00:00:00               2
# 1        196366.0        166449.0  2015-05-23 00:00:00               2
# 2        177941.0         71605.0  2015-10-31 00:00:00               0
# 3        177941.0         71605.0  2015-11-21 00:00:00               0
# 4        177941.0         71605.0  2015-12-05 00:00:00               0
#
#    away_team_goal final_status
# 0               0          NaN
# 1               2          NaN
# 2               0          NaN
# 3               0          NaN
# 4               1          NaN

# %% [markdown]
# The code below appends additional columns. `'final_status'` uses the goal data to determine who won. `'points_awarded'` then delivers a point system for 'win' and 'tie'. This number will be used to determine the top teams.

# %%
matches['final_status'] = "NaN"
matches['points_awarded'] = 0
matches.loc[matches['home_team_goal'] > matches['away_team_goal'], ['final_status','points_awarded']] = ['win',2]
matches.loc[matches['home_team_goal'] == matches['away_team_goal'], ['final_status','points_awarded']] = ['tie',1]
matches.loc[matches['home_team_goal'] < matches['away_team_goal'], 'final_status'] = 'lose'
matches.head(25)
# Out:
#      team_long_name  home_player_1  home_player_2  home_player_3  \
# 0        1. FC Köln       212815.0        36395.0        36934.0
# 1        1. FC Köln       212815.0        36395.0        36934.0
# 2        1. FC Köln       212815.0       127945.0       231753.0
# 3        1. FC Köln       212815.0       127945.0        36934.0
# 4        1. FC Köln       212815.0       127945.0        36934.0
# 5        1. FC Köln       212815.0       212377.0       231753.0
# 6        1. FC Köln       212815.0       212377.0        36934.0
# 7        1. FC Köln       212815.0       212377.0       231753.0
# 8        1. FC Köln       212815.0        36934.0        28435.0
# 9        1. FC Köln       212815.0        36934.0        28435.0
# 10       1. FC Köln       212815.0       231753.0        36934.0
# 11       1. FC Köln       212815.0       231753.0        36934.0
# 12       1. FC Köln       212815.0       127945.0        36934.0
# 13       1. FC Köln       212815.0       212377.0       231753.0
# 14       1. FC Köln       212815.0       231753.0        36934.0
# 15       1. FC Köln       212815.0       231753.0        36934.0
# 16       1. FC Köln       212815.0       212377.0       231753.0
# 17       1. FC Köln       212815.0       127945.0       231753.0
# 18       1. FC Köln       212815.0       212377.0       231753.0
# 19  1. FSV Mainz 05       287894.0        94915.0        36000.0
# 20  1. FSV Mainz 05       287894.0        36000.0        36806.0
# 21  1. FSV Mainz 05       287894.0        94915.0        36000.0
# 22  1. FSV Mainz 05       287894.0       147726.0        36000.0
# 23  1. FSV Mainz 05       287894.0        94915.0       147726.0
# 24  1. FSV Mainz 05       287894.0        94915.0       193901.0
#
#     home_player_4  home_player_5  home_player_6  home_player_7  home_player_8  \
# 0        264221.0       307210.0        36086.0       167589.0       127945.0
# 1        264221.0        22824.0       450976.0        36086.0       127945.0
# 2        303800.0       307210.0       166449.0        36086.0       167589.0
# 3        303800.0       307210.0       166449.0        36086.0       167589.0
# 4        303800.0       307210.0       238438.0        36086.0       167589.0
# 5         36934.0       303800.0       307210.0       450976.0        36086.0
# 6        303800.0       307210.0       167589.0        36086.0       127945.0
# 7        303800.0       307210.0       127945.0       167589.0        36086.0
# 8        303800.0       127945.0       450976.0       307210.0       259439.0
# 9        303800.0       127945.0        36086.0       307210.0       259439.0
# 10       303800.0       307210.0        36086.0       127945.0       450976.0
# 11        28435.0       303800.0       307210.0       127945.0        36086.0
# 12       303800.0       307210.0        36086.0       167589.0       238438.0
# 13       303800.0       307210.0       127945.0        36086.0       167589.0
# 14        28435.0       259439.0        36086.0       307210.0       127945.0
# 15        28435.0       303800.0       307210.0       127945.0       450976.0
# 16       303800.0       307210.0       127945.0        36086.0       167589.0
# 17       303800.0       307210.0       238438.0        36086.0       450976.0
# 18       303800.0       307210.0       127945.0       450976.0       260470.0
# 19       193901.0       171472.0       237542.0        59595.0       287231.0
# 20       171472.0       130667.0       130118.0       201888.0       237542.0
# 21       193901.0       171472.0        59595.0        95228.0       178804.0
# 22       193901.0        49885.0        59595.0       162679.0       180126.0
# 23        36000.0       171472.0        49885.0       162679.0       287231.0
# 24       459000.0       171472.0        59595.0       162679.0       287231.0
#
#     home_player_9  home_player_10  home_player_11                 date  \
# 0        459493.0        166449.0        196366.0  2015-05-10 00:00:00
# 1        459493.0        196366.0        166449.0  2015-05-23 00:00:00
# 2        459493.0        177941.0         71605.0  2015-10-31 00:00:00
# 3        260470.0        177941.0         71605.0  2015-11-21 00:00:00
# 4        260470.0        177941.0         71605.0  2015-12-05 00:00:00
# 5         22824.0        127945.0        238438.0  2015-12-19 00:00:00
# 6        166449.0        260470.0         71605.0  2016-01-23 00:00:00
# 7        260470.0        238438.0         71605.0  2015-08-22 00:00:00
# 8        238438.0        260470.0         71605.0  2016-02-13 00:00:00
# 9        450976.0         71605.0        260470.0  2016-02-26 00:00:00
# 10       260470.0        259439.0         71605.0  2016-03-05 00:00:00
# 11       450976.0        260470.0         71605.0  2016-03-19 00:00:00
# 12       260470.0        450976.0         71605.0  2016-04-10 00:00:00
# 13       260470.0         71605.0        238438.0  2015-08-29 00:00:00
# 14       166449.0        450976.0         71605.0  2016-04-23 00:00:00
# 15       260470.0        238438.0         71605.0  2016-05-07 00:00:00
# 16       260470.0         71605.0        166449.0  2015-09-19 00:00:00
# 17       260470.0        166449.0         71605.0  2015-09-25 00:00:00
# 18        36086.0        166449.0         71605.0  2015-10-18 00:00:00
# 19        22313.0        201888.0         20694.0  2015-05-03 00:00:00
# 20        59595.0        278863.0         20694.0  2015-05-16 00:00:00
# 21       278863.0        287231.0        276760.0  2015-08-15 00:00:00
# 22       278863.0        287231.0        459499.0  2015-10-24 00:00:00
# 23       278863.0        130118.0        459499.0  2015-11-07 00:00:00
# 24       278863.0        130118.0        459499.0  2015-11-28 00:00:00
#
#     home_team_goal  away_team_goal final_status  points_awarded
# 0                2               0          win               2
# 1                2               2          tie               1
# 2                0               0          tie               1
# 3                0               0          tie               1
# 4                0               1         lose               0
# 5                2               1          win               2
# 6                1               3         lose               0
# 7                1               1          tie               1
# 8                3               1          win               2
# 9                0               1         lose               0
# 10               1               3         lose               0
# 11               0               1         lose               0
# 12               0               2         lose               0
# 13               2               1          win               2
# 14               4               1          win               2
# 15               0               0          tie               1
# 16               1               0          win               2
# 17               1               1          tie               1
# 18               0               1         lose               0
# 19               1               2         lose               0
# 20               2               0          win               2
# 21               0               1         lose               0
# 22               1               3         lose               0
# 23               2               0          win               2
# 24               2               1          win               2

# %% [markdown]
# Now that we have the points for each team. The next step is to figure out how many games they each played.

# %%
data = {'team_name': matches.groupby(['team_long_name']),
        'games_played': matches.groupby(['team_long_name'])['date'].count().values.tolist(),
       }
matches.groupby(['team_long_name']).count()
# Out:
#                               home_player_1  home_player_2  home_player_3  \
# team_long_name
# 1. FC Köln                               19             19             19
# 1. FSV Mainz 05                          19             19             19
# ADO Den Haag                             18             18             18
# AS Monaco                                21             21             21
# AS Saint-Étienne                         21             21             21
# AZ                                       18             18             18
# Aberdeen                                 21             21             21
# Académica de Coimbra                     19             19             19
# Ajax                                     18             18             18
# Angers SCO                               19             19             19
# Arsenal                                  22             22             22
# Aston Villa                              22             22             22
# Atalanta                                 22             22             22
# Athletic Club de Bilbao                  21             21             21
# Atlético Madrid                          21             21             21
# BSC Young Boys                           21             21             21
# Bayer 04 Leverkusen                      19             19             19
# Boavista FC                              19             19             19
# Bologna                                  19             19             19
# Borussia Dortmund                        19             19             19
# Borussia Mönchengladbach                 19             19             19
# Bournemouth                              19             19             19
# Burnley                                   1              1              1
# CD Nacional                              19             19             19
# CF Os Belenenses                         19             19             19
# CS Marítimo                              17             19             19
# Cagliari                                  3              3              3
# Carpi                                    19             18             19
# Celtic                                   21             21             21
# Cesena                                    2              2              2
# ...                                     ...            ...            ...
# Standard de Liège                        15             15             15
# Stoke City                               21             21             21
# Sunderland                               21             21             21
# Swansea City                             21             20             21
# TSG 1899 Hoffenheim                      19             19             19
# Termalica Bruk-Bet Nieciecza             15             15             15
# Tondela                                  17             11             16
# Torino                                   22             22             22
# Tottenham Hotspur                        21             21             21
# Toulouse FC                              21             21             21
# UD Almería                                3              3              3
# UD Las Palmas                            19             19             19
# Udinese                                  21             21             21
# Uniao da Madeira                         17             17             17
# Valencia CF                              21             21             21
# VfB Stuttgart                            19             19             19
# VfL Wolfsburg                            19             19             19
# Villarreal CF                            21             21             21
# Vitesse                                  18             18             18
# Vitória Guimarães                        19             19             19
# Vitória Setúbal                          19             19             19
# Waasland-Beveren                         15             15             15
# Watford                                  19             19             19
# West Bromwich Albion                     20             20             20
# West Ham United                          21             20             21
# Willem II                                18             18             18
# Wisła Kraków                             15             15             15
# Zagłębie Lubin                           15             15             15
# Évian Thonon Gaillard FC                  2              2              2
# Śląsk Wrocław                            15             15             15
#
#                               home_player_4  home_player_5  home_player_6  \
# team_long_name
# 1. FC Köln                               19             19             19
# 1. FSV Mainz 05                          19             19             19
# ADO Den Haag                             18             18             18
# AS Monaco                                21             21             21
# AS Saint-Étienne                         21             21             21
# AZ                                       18             18             18
# Aberdeen                                 21             21             21
# Académica de Coimbra                     19             19             19
# Ajax                                     18             18             18
# Angers SCO                               19             19             19
# Arsenal                                  22             22             22
# Aston Villa                              22             22             22
# Atalanta                                 22             22             22
# Athletic Club de Bilbao                  21             21             21
# Atlético Madrid                          21             21             21
# BSC Young Boys                           21             21             21
# Bayer 04 Leverkusen                      19             19             19
# Boavista FC                              19             19             19
# Bologna                                  19             19             19
# Borussia Dortmund                        19             19             19
# Borussia Mönchengladbach                 19             19             19
# Bournemouth                              19             19             19
# Burnley                                   1              1              1
# CD Nacional                              19             19             19
# CF Os Belenenses                         19             19             19
# CS Marítimo                              19             19             18
# Cagliari                                  3              3              3
# Carpi                                    16             17             19
# Celtic                                   21             21             21
# Cesena                                    2              2              2
# ...                                     ...            ...            ...
# Standard de Liège                        15             15             15
# Stoke City                               21             21             21
# Sunderland                               21             21             21
# Swansea City                             21             21             21
# TSG 1899 Hoffenheim                      19             19             19
# Termalica Bruk-Bet Nieciecza             15             15             15
# Tondela                                  15             16             17
# Torino                                   22             22             22
# Tottenham Hotspur                        21             21             21
# Toulouse FC                              21             21             21
# UD Almería                                3              3              3
# UD Las Palmas                            19             19             19
# Udinese                                  21             21             21
# Uniao da Madeira                         17             17             17
# Valencia CF                              21             21             21
# VfB Stuttgart                            19             19             19
# VfL Wolfsburg                            19             19             19
# Villarreal CF                            21             21             21
# Vitesse                                  18             18             18
# Vitória Guimarães                        19             19             19
# Vitória Setúbal                          19             19             19
# Waasland-Beveren                         15             15             15
# Watford                                  19             19             19
# West Bromwich Albion                     20             20             20
# West Ham United                          21             21             21
# Willem II                                18             18             18
# Wisła Kraków                             15             15             15
# Zagłębie Lubin                           15             15             15
# Évian Thonon Gaillard FC                  2              2              2
# Śląsk Wrocław                            14             15             15
#
#                               home_player_7  home_player_8  home_player_9  \
# team_long_name
# 1. FC Köln                               19             19             19
# 1. FSV Mainz 05                          19             19             19
# ADO Den Haag                             18             18             18
# AS Monaco                                21             21             21
# AS Saint-Étienne                         21             21             21
# AZ                                       18             18             18
# Aberdeen                                 21             21             21
# Académica de Coimbra                     19             19             19
# Ajax                                     18             18             18
# Angers SCO                               19             19             19
# Arsenal                                  22             22             22
# Aston Villa                              22             22             22
# Atalanta                                 22             22             22
# Athletic Club de Bilbao                  21             21             21
# Atlético Madrid                          21             21             21
# BSC Young Boys                           21             21             21
# Bayer 04 Leverkusen                      19             19             19
# Boavista FC                              19             19             19
# Bologna                                  19             19             19
# Borussia Dortmund                        19             19             19
# Borussia Mönchengladbach                 19             19             19
# Bournemouth                              19             19             19
# Burnley                                   1              1              1
# CD Nacional                              19             19             19
# CF Os Belenenses                         19             19             19
# CS Marítimo                              19             19             19
# Cagliari                                  3              3              3
# Carpi                                    19             19             19
# Celtic                                   21             21             21
# Cesena                                    2              2              2
# ...                                     ...            ...            ...
# Standard de Liège                        15             15             15
# Stoke City                               21             21             21
# Sunderland                               21             21             21
# Swansea City                             21             21             21
# TSG 1899 Hoffenheim                      19             19             19
# Termalica Bruk-Bet Nieciecza             15             15             15
# Tondela                                  17             16             15
# Torino                                   22             22             22
# Tottenham Hotspur                        21             21             21
# Toulouse FC                              21             21             21
# UD Almería                                3              3              3
# UD Las Palmas                            18             19             18
# Udinese                                  21             21             21
# Uniao da Madeira                         17             17             17
# Valencia CF                              21             21             21
# VfB Stuttgart                            19             19             19
# VfL Wolfsburg                            19             19             19
# Villarreal CF                            21             21             21
# Vitesse                                  18             18             18
# Vitória Guimarães                        19             19             19
# Vitória Setúbal                          19             19             19
# Waasland-Beveren                         15             15             15
# Watford                                  19             19             19
# West Bromwich Albion                     20             20             20
# West Ham United                          21             21             21
# Willem II                                18             18             18
# Wisła Kraków                             15             15             14
# Zagłębie Lubin                           15             15             15
# Évian Thonon Gaillard FC                  2              2              2
# Śląsk Wrocław                            15             15             15
#
#                               home_player_10  home_player_11  date  \
# team_long_name
# 1. FC Köln                                19              19    19
# 1. FSV Mainz 05                           19              19    19
# ADO Den Haag                              18              18    18
# AS Monaco                                 21              21    21
# AS Saint-Étienne                          15              20    21
# AZ                                        18              18    18
# Aberdeen                                  21              21    21
# Académica de Coimbra                      19              19    19
# Ajax                                      18              18    18
# Angers SCO                                19              19    19
# Arsenal                                   22              22    22
# Aston Villa                               22              22    22
# Atalanta                                  22              22    22
# Athletic Club de Bilbao                   21              21    21
# Atlético Madrid                           21              21    21
# BSC Young Boys                            21              21    21
# Bayer 04 Leverkusen                       19              19    19
# Boavista FC                               19              18    19
# Bologna                                   19              19    19
# Borussia Dortmund                         19              19    19
# Borussia Mönchengladbach                  19              19    19
# Bournemouth                               19              19    19
# Burnley                                    1               1     1
# CD Nacional                               19              19    19
# CF Os Belenenses                          19              19    19
# CS Marítimo                               19              19    19
# Cagliari                                   3               3     3
# Carpi                                     19              19    19
# Celtic                                    21              21    21
# Cesena                                     2               1     2
# ...                                      ...             ...   ...
# Standard de Liège                         15              15    15
# Stoke City                                21              21    21
# Sunderland                                21              21    21
# Swansea City                              21              21    21
# TSG 1899 Hoffenheim                       19              19    19
# Termalica Bruk-Bet Nieciecza              15              15    15
# Tondela                                   17              16    17
# Torino                                    22              22    22
# Tottenham Hotspur                         21              21    21
# Toulouse FC                               21              21    21
# UD Almería                                 3               3     3
# UD Las Palmas                             18              19    19
# Udinese                                   21              21    21
# Uniao da Madeira                          17              17    17
# Valencia CF                               21              21    21
# VfB Stuttgart                             19              19    19
# VfL Wolfsburg                             19              19    19
# Villarreal CF                             21              21    21
# Vitesse                                   18              18    18
# Vitória Guimarães                         19              18    19
# Vitória Setúbal                           19              19    19
# Waasland-Beveren                          15              15    15
# Watford                                   19              19    19
# West Bromwich Albion                      20              20    20
# West Ham United                           21              21    21
# Willem II                                 18              18    18
# Wisła Kraków                              15              15    15
# Zagłębie Lubin                            15              14    15
# Évian Thonon Gaillard FC                   2               2     2
# Śląsk Wrocław                             15              15    15
#
#                               home_team_goal  away_team_goal  final_status  \
# team_long_name
# 1. FC Köln                                19              19            19
# 1. FSV Mainz 05                           19              19            19
# ADO Den Haag                              18              18            18
# AS Monaco                                 21              21            21
# AS Saint-Étienne                          21              21            21
# AZ                                        18              18            18
# Aberdeen                                  21              21            21
# Académica de Coimbra                      19              19            19
# Ajax                                      18              18            18
# Angers SCO                                19              19            19
# Arsenal                                   22              22            22
# Aston Villa                               22              22            22
# Atalanta                                  22              22            22
# Athletic Club de Bilbao                   21              21            21
# Atlético Madrid                           21              21            21
# BSC Young Boys                            21              21            21
# Bayer 04 Leverkusen                       19              19            19
# Boavista FC                               19              19            19
# Bologna                                   19              19            19
# Borussia Dortmund                         19              19            19
# Borussia Mönchengladbach                  19              19            19
# Bournemouth                               19              19            19
# Burnley                                    1               1             1
# CD Nacional                               19              19            19
# CF Os Belenenses                          19              19            19
# CS Marítimo                               19              19            19
# Cagliari                                   3               3             3
# Carpi                                     19              19            19
# Celtic                                    21              21            21
# Cesena                                     2               2             2
# ...                                      ...             ...           ...
# Standard de Liège                         15              15            15
# Stoke City                                21              21            21
# Sunderland                                21              21            21
# Swansea City                              21              21            21
# TSG 1899 Hoffenheim                       19              19            19
# Termalica Bruk-Bet Nieciecza              15              15            15
# Tondela                                   17              17            17
# Torino                                    22              22            22
# Tottenham Hotspur                         21              21            21
# Toulouse FC                               21              21            21
# UD Almería                                 3               3             3
# UD Las Palmas                             19              19            19
# Udinese                                   21              21            21
# Uniao da Madeira                          17              17            17
# Valencia CF                               21              21            21
# VfB Stuttgart                             19              19            19
# VfL Wolfsburg                             19              19            19
# Villarreal CF                             21              21            21
# Vitesse                                   18              18            18
# Vitória Guimarães                         19              19            19
# Vitória Setúbal                           19              19            19
# Waasland-Beveren                          15              15            15
# Watford                                   19              19            19
# West Bromwich Albion                      20              20            20
# West Ham United                           21              21            21
# Willem II                                 18              18            18
# Wisła Kraków                              15              15            15
# Zagłębie Lubin                            15              15            15
# Évian Thonon Gaillard FC                   2               2             2
# Śląsk Wrocław                             15              15            15
#
#                               points_awarded
# team_long_name
# 1. FC Köln                                19
# 1. FSV Mainz 05                           19
# ADO Den Haag                              18
# AS Monaco                                 21
# AS Saint-Étienne                          21
# AZ                                        18
# Aberdeen                                  21
# Académica de Coimbra                      19
# Ajax                                      18
# Angers SCO                                19
# Arsenal                                   22
# Aston Villa                               22
# Atalanta                                  22
# Athletic Club de Bilbao                   21
# Atlético Madrid                           21
# BSC Young Boys                            21
# Bayer 04 Leverkusen                       19
# Boavista FC                               19
# Bologna                                   19
# Borussia Dortmund                         19
# Borussia Mönchengladbach                  19
# Bournemouth                               19
# Burnley                                    1
# CD Nacional                               19
# CF Os Belenenses                          19
# CS Marítimo                               19
# Cagliari                                   3
# Carpi                                     19
# Celtic                                    21
# Cesena                                     2
# ...                                      ...
# Standard de Liège                         15
# Stoke City                                21
# Sunderland                                21
# Swansea City                              21
# TSG 1899 Hoffenheim                       19
# Termalica Bruk-Bet Nieciecza              15
# Tondela                                   17
# Torino                                    22
# Tottenham Hotspur                         21
# Toulouse FC                               21
# UD Almería                                 3
# UD Las Palmas                             19
# Udinese                                   21
# Uniao da Madeira                          17
# Valencia CF                               21
# VfB Stuttgart                             19
# VfL Wolfsburg                             19
# Villarreal CF                             21
# Vitesse                                   18
# Vitória Guimarães                         19
# Vitória Setúbal                           19
# Waasland-Beveren                          15
# Watford                                   19
# West Bromwich Albion                      20
# West Ham United                           21
# Willem II                                 18
# Wisła Kraków                              15
# Zagłębie Lubin                            15
# Évian Thonon Gaillard FC                   2
# Śląsk Wrocław                             15
#
# [209 rows x 16 columns]

# %% [markdown]
# ### Create Team Points

# %%
team_points = matches.groupby(['team_long_name']).sum()[['points_awarded']]
team_points
# Out:
#                               points_awarded
# team_long_name
# 1. FC Köln                                18
# 1. FSV Mainz 05                           22
# ADO Den Haag                              16
# AS Monaco                                 30
# AS Saint-Étienne                          28
# AZ                                        24
# Aberdeen                                  28
# Académica de Coimbra                      16
# Ajax                                      31
# Angers SCO                                20
# Arsenal                                   31
# Aston Villa                               13
# Atalanta                                  23
# Athletic Club de Bilbao                   29
# Atlético Madrid                           34
# BSC Young Boys                            32
# Bayer 04 Leverkusen                       27
# Boavista FC                               15
# Bologna                                   15
# Borussia Dortmund                         35
# Borussia Mönchengladbach                  29
# Bournemouth                               15
# Burnley                                    1
# CD Nacional                               23
# CF Os Belenenses                          18
# CS Marítimo                               19
# Cagliari                                   4
# Carpi                                     17
# Celtic                                    36
# Cesena                                     0
# ...                                      ...
# Standard de Liège                         18
# Stoke City                                24
# Sunderland                                21
# Swansea City                              24
# TSG 1899 Hoffenheim                       21
# Termalica Bruk-Bet Nieciecza              14
# Tondela                                   10
# Torino                                    22
# Tottenham Hotspur                         28
# Toulouse FC                               21
# UD Almería                                 1
# UD Las Palmas                             21
# Udinese                                   16
# Uniao da Madeira                          18
# Valencia CF                               22
# VfB Stuttgart                             17
# VfL Wolfsburg                             26
# Villarreal CF                             32
# Vitesse                                   19
# Vitória Guimarães                         20
# Vitória Setúbal                           15
# Waasland-Beveren                          13
# Watford                                   18
# West Bromwich Albion                      19
# West Ham United                           27
# Willem II                                 14
# Wisła Kraków                              14
# Zagłębie Lubin                            16
# Évian Thonon Gaillard FC                   0
# Śląsk Wrocław                             16
#
# [209 rows x 1 columns]

# %% [markdown]
# ### Create Games Played

# %%
team_games_played = matches.groupby(['team_long_name']).count()[['date']]
team_games_played.rename(columns={'date':'games_played'}, inplace=True) #proper rename
team_games_played
# Out:
#                               games_played
# team_long_name
# 1. FC Köln                              19
# 1. FSV Mainz 05                         19
# ADO Den Haag                            18
# AS Monaco                               21
# AS Saint-Étienne                        21
# AZ                                      18
# Aberdeen                                21
# Académica de Coimbra                    19
# Ajax                                    18
# Angers SCO                              19
# Arsenal                                 22
# Aston Villa                             22
# Atalanta                                22
# Athletic Club de Bilbao                 21
# Atlético Madrid                         21
# BSC Young Boys                          21
# Bayer 04 Leverkusen                     19
# Boavista FC                             19
# Bologna                                 19
# Borussia Dortmund                       19
# Borussia Mönchengladbach                19
# Bournemouth                             19
# Burnley                                  1
# CD Nacional                             19
# CF Os Belenenses                        19
# CS Marítimo                             19
# Cagliari                                 3
# Carpi                                   19
# Celtic                                  21
# Cesena                                   2
# ...                                    ...
# Standard de Liège                       15
# Stoke City                              21
# Sunderland                              21
# Swansea City                            21
# TSG 1899 Hoffenheim                     19
# Termalica Bruk-Bet Nieciecza            15
# Tondela                                 17
# Torino                                  22
# Tottenham Hotspur                       21
# Toulouse FC                             21
# UD Almería                               3
# UD Las Palmas                           19
# Udinese                                 21
# Uniao da Madeira                        17
# Valencia CF                             21
# VfB Stuttgart                           19
# VfL Wolfsburg                           19
# Villarreal CF                           21
# Vitesse                                 18
# Vitória Guimarães                       19
# Vitória Setúbal                         19
# Waasland-Beveren                        15
# Watford                                 19
# West Bromwich Albion                    20
# West Ham United                         21
# Willem II                               18
# Wisła Kraków                            15
# Zagłębie Lubin                          15
# Évian Thonon Gaillard FC                 2
# Śląsk Wrocław                           15
#
# [209 rows x 1 columns]

# %% [markdown]
# ### Create Performance Score Column
#
# This is a custom agregation that originally assined 2 points/win and 1 point/tie. Some teams played more games than others in the season so using a total sum would not be accurate. The underlaying of `performance_score` is the percent of `'points_awarded' / 'games_played'` then simplifies the data by transforming it into an number.
#
# There were a number of teams missing data with only a few games matches recorded. As seen in the code below I permanently removed them from the `team_totals` dataframe and have decided to be considered in the running for top team, 10 games or more have to had been played.

# %%
team_totals = team_games_played.join(team_points)
team_totals['performance_score'] = ((team_totals['points_awarded'] / team_totals['games_played'])*100).astype(int)
team_totals.sort_values('performance_score', ascending=False, inplace=True)
team_totals = team_totals[team_totals['games_played'] >= 10] 
team_totals
# Out:
#                           games_played  points_awarded  performance_score
# team_long_name
# Club Brugge KV                      15              28                186
# Napoli                              21              39                185
# Borussia Dortmund                   19              35                184
# SL Benfica                          19              34                178
# Paris Saint-Germain                 21              37                176
# Juventus                            21              37                176
# Piast Gliwice                       15              26                173
# FC Bayern Munich                    19              33                173
# Sporting CP                         19              33                173
# PSV                                 18              31                172
# Ajax                                18              31                172
# FC Barcelona                        21              36                171
# Real Madrid CF                      21              36                171
# Celtic                              21              36                171
# RSC Anderlecht                      15              25                166
# FC Basel                            21              35                166
# Leicester City                      22              36                163
# Atlético Madrid                     21              34                161
# KAA Gent                            15              24                160
# Roma                                22              35                159
# FC Porto                            19              30                157
# KRC Genk                            15              23                153
# Villarreal CF                       21              32                152
# BSC Young Boys                      21              32                152
# Borussia Mönchengladbach            19              29                152
# Fiorentina                          22              33                150
# Olympique Lyonnais                  21              31                147
# SC Braga                            19              28                147
# Sevilla FC                          21              31                147
# KV Oostende                         15              22                146
# ...                                ...             ...                ...
# FC Zürich                           22              18                 81
# Crystal Palace                      21              17                 80
# Everton                             21              17                 80
# Sint-Truidense VV                   15              12                 80
# Hamilton Academical FC              21              17                 80
# Polonia Bytom                       15              12                 80
# Boavista FC                         19              15                 78
# Vitória Setúbal                     19              15                 78
# Bournemouth                         19              15                 78
# Bologna                             19              15                 78
# Hellas Verona                       22              17                 77
# Willem II                           18              14                 77
# Palermo                             21              16                 76
# Udinese                             21              16                 76
# Royal Excel Mouscron                15              11                 73
# Moreirense FC                       19              14                 73
# Korona Kielce                       15              11                 73
# Sporting Lokeren                    15              11                 73
# Excelsior                           18              13                 72
# Roda JC Kerkrade                    17              12                 70
# De Graafschap                       17              12                 70
# FC Augsburg                         19              13                 68
# Dundee United                       21              14                 66
# Aston Villa                         22              13                 59
# Tondela                             17              10                 58
# SV Darmstadt 98                     17              10                 58
# Kilmarnock                          21              12                 57
# Hannover 96                         19              11                 57
# SC Cambuur                          18               9                 50
# ES Troyes AC                        19               9                 47
#
# [188 rows x 3 columns]

# %% [markdown]
# Some of the teams have very little recorded data so they will not be considered for our top teams. As a rather barbaric quality test I googled a couple of the top teams to see if they are still top placers (since data is from 2016). An example is that Napoli is currently 2nd in the Italian league (05/25/19). I will consider our `'performance_score'` number as an accurate indicator and continue moving forward.
#
# Two key variables that have been created are:
# * Teams (with players & attributes)
# * Team_Totals (indicating top teams)

# %%
teams['Napoli']['Christian Maggio']['crossing']
# Out:
# 79.0

# %% [markdown]
# To access the nested directory keys we need to provide a key to access the nested keys. To avoid a brittle code that relies on hard-coding a teams nameHowever, because not all teams have registered players in this database there is no garuntee that the first returned team will have a players dictionary to dive into. To combat this I am using the code below that states a team needs to have 10 registered players to be valid. We will then use that. Even though we are dealing with an unordered dictionary this code will work for our purposes no matter the order.
#
# **Syntax Goal:** list(teams\[valid_team]\[any player on team].keys())

# %%
team_player_count = 0
valid_team_index = 0
while team_player_count < 10: #11 Players on a team
    for i in range(len(teams.keys())):
        team_player_count = len(teams[list(teams.keys())[i]])
        if team_player_count > 10:
            valid_team_index = i
            break
            
valid_team = list(teams.keys())[valid_team_index]
pp.pprint(teams[valid_team])
# Out:
# {   'Alejandro Pozuelo': {   'acceleration': 77.0,
#                              'aggression': 60.0,
#                              'agility': 76.0,
#                              'attacking_work_rate': 'high',
#                              'balance': 82.0,
#                              'ball_control': 74.0,
#                              'crossing': 63.0,
#                              'curve': 72.0,
#                              'date': '2016-04-28 00:00:00',
#                              'defensive_work_rate': 'medium',
#                              'dribbling': 76.0,
#                              'finishing': 60.0,
#                              'free_kick_accuracy': 59.0,
#                              'gk_diving': 10.0,
#                              'gk_handling': 8.0,
#                              'gk_kicking': 14.0,
#                              'gk_positioning': 10.0,
#                              'gk_reflexes': 8.0,
#                              'heading_accuracy': 39.0,
#                              'id': 5621,
#                              'interceptions': 58.0,
#                              'jumping': 71.0,
#                              'long_passing': 64.0,
#                              'long_shots': 58.0,
#                              'marking': 37.0,
#                              'overall_rating': 72.0,
#                              'penalties': 66.0,
#                              'player_api_id': 282470,
#                              'player_fifa_api_id': 203895,
#                              'positioning': 71.0,
#                              'potential': 75.0,
#                              'preferred_foot': 'right',
#                              'reactions': 70.0,
#                              'short_passing': 76.0,
#                              'shot_power': 64.0,
#                              'sliding_tackle': 50.0,
#                              'sprint_speed': 74.0,
#                              'stamina': 77.0,
#                              'standing_tackle': 58.0,
#                              'strength': 51.0,
#                              'vision': 76.0,
#                              'volleys': 49.0},
#     'Brian Hamalainen': {   'acceleration': 79.0,
#                             'aggression': 67.0,
#                             'agility': 65.0,
#                             'attacking_work_rate': 'medium',
#                             'balance': 65.0,
#                             'ball_control': 66.0,
#                             'crossing': 70.0,
#                             'curve': 69.0,
#                             'date': '2016-03-24 00:00:00',
#                             'defensive_work_rate': 'high',
#                             'dribbling': 65.0,
#                             'finishing': 26.0,
#                             'free_kick_accuracy': 71.0,
#                             'gk_diving': 7.0,
#                             'gk_handling': 7.0,
#                             'gk_kicking': 16.0,
#                             'gk_positioning': 6.0,
#                             'gk_reflexes': 6.0,
#                             'heading_accuracy': 63.0,
#                             'id': 23401,
#                             'interceptions': 63.0,
#                             'jumping': 76.0,
#                             'long_passing': 65.0,
#                             'long_shots': 57.0,
#                             'marking': 69.0,
#                             'overall_rating': 68.0,
#                             'penalties': 57.0,
#                             'player_api_id': 80678,
#                             'player_fifa_api_id': 172529,
#                             'positioning': 44.0,
#                             'potential': 69.0,
#                             'preferred_foot': 'left',
#                             'reactions': 68.0,
#                             'short_passing': 66.0,
#                             'shot_power': 71.0,
#                             'sliding_tackle': 67.0,
#                             'sprint_speed': 75.0,
#                             'stamina': 70.0,
#                             'standing_tackle': 69.0,
#                             'strength': 73.0,
#                             'vision': 59.0,
#                             'volleys': 62.0},
#     'Bryan Heynen': {   'acceleration': 65.0,
#                         'aggression': 62.0,
#                         'agility': 72.0,
#                         'attacking_work_rate': 'low',
#                         'balance': 78.0,
#                         'ball_control': 67.0,
#                         'crossing': 55.0,
#                         'curve': 56.0,
#                         'date': '2016-03-24 00:00:00',
#                         'defensive_work_rate': 'medium',
#                         'dribbling': 65.0,
#                         'finishing': 41.0,
#                         'free_kick_accuracy': 47.0,
#                         'gk_diving': 7.0,
#                         'gk_handling': 12.0,
#                         'gk_kicking': 6.0,
#                         'gk_positioning': 8.0,
#                         'gk_reflexes': 10.0,
#                         'heading_accuracy': 55.0,
#                         'id': 24443,
#                         'interceptions': 57.0,
#                         'jumping': 64.0,
#                         'long_passing': 65.0,
#                         'long_shots': 54.0,
#                         'marking': 50.0,
#                         'overall_rating': 64.0,
#                         'penalties': 43.0,
#                         'player_api_id': 659493,
#                         'player_fifa_api_id': 229659,
#                         'positioning': 54.0,
#                         'potential': 76.0,
#                         'preferred_foot': 'right',
#                         'reactions': 58.0,
#                         'short_passing': 69.0,
#                         'shot_power': 57.0,
#                         'sliding_tackle': 56.0,
#                         'sprint_speed': 69.0,
#                         'stamina': 67.0,
#                         'standing_tackle': 62.0,
#                         'strength': 55.0,
#                         'vision': 67.0,
#                         'volleys': 48.0},
#     'Christian Kabasele': {   'acceleration': 77.0,
#                               'aggression': 77.0,
#                               'agility': 63.0,
#                               'attacking_work_rate': 'low',
#                               'balance': 64.0,
#                               'ball_control': 64.0,
#                               'crossing': 47.0,
#                               'curve': 34.0,
#                               'date': '2016-04-21 00:00:00',
#                               'defensive_work_rate': 'high',
#                               'dribbling': 59.0,
#                               'finishing': 53.0,
#                               'free_kick_accuracy': 27.0,
#                               'gk_diving': 14.0,
#                               'gk_handling': 11.0,
#                               'gk_kicking': 6.0,
#                               'gk_positioning': 14.0,
#                               'gk_reflexes': 16.0,
#                               'heading_accuracy': 76.0,
#                               'id': 29317,
#                               'interceptions': 71.0,
#                               'jumping': 81.0,
#                               'long_passing': 57.0,
#                               'long_shots': 44.0,
#                               'marking': 74.0,
#                               'overall_rating': 75.0,
#                               'penalties': 53.0,
#                               'player_api_id': 149219,
#                               'player_fifa_api_id': 190324,
#                               'positioning': 57.0,
#                               'potential': 78.0,
#                               'preferred_foot': 'right',
#                               'reactions': 69.0,
#                               'short_passing': 60.0,
#                               'shot_power': 57.0,
#                               'sliding_tackle': 80.0,
#                               'sprint_speed': 78.0,
#                               'stamina': 78.0,
#                               'standing_tackle': 76.0,
#                               'strength': 83.0,
#                               'vision': 36.0,
#                               'volleys': 52.0},
#     'Derrick Tshimanga': {   'acceleration': 86.0,
#                              'aggression': 72.0,
#                              'agility': 81.0,
#                              'attacking_work_rate': 'medium',
#                              'balance': 83.0,
#                              'ball_control': 71.0,
#                              'crossing': 66.0,
#                              'curve': 52.0,
#                              'date': '2016-03-17 00:00:00',
#                              'defensive_work_rate': 'high',
#                              'dribbling': 72.0,
#                              'finishing': 54.0,
#                              'free_kick_accuracy': 48.0,
#                              'gk_diving': 14.0,
#                              'gk_handling': 16.0,
#                              'gk_kicking': 6.0,
#                              'gk_positioning': 6.0,
#                              'gk_reflexes': 8.0,
#                              'heading_accuracy': 63.0,
#                              'id': 43201,
#                              'interceptions': 67.0,
#                              'jumping': 82.0,
#                              'long_passing': 62.0,
#                              'long_shots': 53.0,
#                              'marking': 71.0,
#                              'overall_rating': 71.0,
#                              'penalties': 48.0,
#                              'player_api_id': 166675,
#                              'player_fifa_api_id': 188756,
#                              'positioning': 64.0,
#                              'potential': 71.0,
#                              'preferred_foot': 'left',
#                              'reactions': 69.0,
#                              'short_passing': 66.0,
#                              'shot_power': 64.0,
#                              'sliding_tackle': 72.0,
#                              'sprint_speed': 88.0,
#                              'stamina': 73.0,
#                              'standing_tackle': 71.0,
#                              'strength': 71.0,
#                              'vision': 59.0,
#                              'volleys': 52.0},
#     'Igor de Camargo': {   'acceleration': 51.0,
#                            'aggression': 77.0,
#                            'agility': 60.0,
#                            'attacking_work_rate': 'medium',
#                            'balance': 51.0,
#                            'ball_control': 71.0,
#                            'crossing': 57.0,
#                            'curve': 63.0,
#                            'date': '2016-04-21 00:00:00',
#                            'defensive_work_rate': 'low',
#                            'dribbling': 66.0,
#                            'finishing': 73.0,
#                            'free_kick_accuracy': 57.0,
#                            'gk_diving': 8.0,
#                            'gk_handling': 8.0,
#                            'gk_kicking': 14.0,
#                            'gk_positioning': 8.0,
#                            'gk_reflexes': 15.0,
#                            'heading_accuracy': 82.0,
#                            'id': 72313,
#                            'interceptions': 48.0,
#                            'jumping': 74.0,
#                            'long_passing': 57.0,
#                            'long_shots': 70.0,
#                            'marking': 41.0,
#                            'overall_rating': 72.0,
#                            'penalties': 70.0,
#                            'player_api_id': 25957,
#                            'player_fifa_api_id': 49674,
#                            'positioning': 76.0,
#                            'potential': 72.0,
#                            'preferred_foot': 'right',
#                            'reactions': 72.0,
#                            'short_passing': 70.0,
#                            'shot_power': 74.0,
#                            'sliding_tackle': 38.0,
#                            'sprint_speed': 53.0,
#                            'stamina': 72.0,
#                            'standing_tackle': 51.0,
#                            'strength': 84.0,
#                            'vision': 67.0,
#                            'volleys': 66.0},
#     'Jere Uronen': {   'acceleration': 73.0,
#                        'aggression': 73.0,
#                        'agility': 72.0,
#                        'attacking_work_rate': 'medium',
#                        'balance': 73.0,
#                        'ball_control': 67.0,
#                        'crossing': 70.0,
#                        'curve': 73.0,
#                        'date': '2016-04-28 00:00:00',
#                        'defensive_work_rate': 'medium',
#                        'dribbling': 61.0,
#                        'finishing': 41.0,
#                        'free_kick_accuracy': 70.0,
#                        'gk_diving': 7.0,
#                        'gk_handling': 10.0,
#                        'gk_kicking': 8.0,
#                        'gk_positioning': 10.0,
#                        'gk_reflexes': 8.0,
#                        'heading_accuracy': 49.0,
#                        'id': 80378,
#                        'interceptions': 64.0,
#                        'jumping': 67.0,
#                        'long_passing': 64.0,
#                        'long_shots': 66.0,
#                        'marking': 68.0,
#                        'overall_rating': 67.0,
#                        'penalties': 48.0,
#                        'player_api_id': 261654,
#                        'player_fifa_api_id': 207593,
#                        'positioning': 48.0,
#                        'potential': 75.0,
#                        'preferred_foot': 'left',
#                        'reactions': 67.0,
#                        'short_passing': 65.0,
#                        'shot_power': 80.0,
#                        'sliding_tackle': 67.0,
#                        'sprint_speed': 71.0,
#                        'stamina': 74.0,
#                        'standing_tackle': 66.0,
#                        'strength': 60.0,
#                        'vision': 62.0,
#                        'volleys': 54.0},
#     'Julien Gorius': {   'acceleration': 57.0,
#                          'aggression': 55.0,
#                          'agility': 63.0,
#                          'attacking_work_rate': 'high',
#                          'balance': 65.0,
#                          'ball_control': 73.0,
#                          'crossing': 75.0,
#                          'curve': 75.0,
#                          'date': '2015-09-21 00:00:00',
#                          'defensive_work_rate': 'high',
#                          'dribbling': 69.0,
#                          'finishing': 68.0,
#                          'free_kick_accuracy': 75.0,
#                          'gk_diving': 6.0,
#                          'gk_handling': 10.0,
#                          'gk_kicking': 12.0,
#                          'gk_positioning': 7.0,
#                          'gk_reflexes': 10.0,
#                          'heading_accuracy': 58.0,
#                          'id': 91820,
#                          'interceptions': 70.0,
#                          'jumping': 62.0,
#                          'long_passing': 74.0,
#                          'long_shots': 74.0,
#                          'marking': 53.0,
#                          'overall_rating': 72.0,
#                          'penalties': 83.0,
#                          'player_api_id': 37112,
#                          'player_fifa_api_id': 158271,
#                          'positioning': 73.0,
#                          'potential': 72.0,
#                          'preferred_foot': 'right',
#                          'reactions': 70.0,
#                          'short_passing': 72.0,
#                          'shot_power': 73.0,
#                          'sliding_tackle': 61.0,
#                          'sprint_speed': 54.0,
#                          'stamina': 77.0,
#                          'standing_tackle': 63.0,
#                          'strength': 65.0,
#                          'vision': 75.0,
#                          'volleys': 74.0},
#     'Kara Mbodji': {   'acceleration': 68.0,
#                        'aggression': 78.0,
#                        'agility': 52.0,
#                        'attacking_work_rate': 'medium',
#                        'balance': 42.0,
#                        'ball_control': 67.0,
#                        'crossing': 49.0,
#                        'curve': 45.0,
#                        'date': '2016-03-24 00:00:00',
#                        'defensive_work_rate': 'medium',
#                        'dribbling': 61.0,
#                        'finishing': 45.0,
#                        'free_kick_accuracy': 55.0,
#                        'gk_diving': 11.0,
#                        'gk_handling': 7.0,
#                        'gk_kicking': 16.0,
#                        'gk_positioning': 9.0,
#                        'gk_reflexes': 12.0,
#                        'heading_accuracy': 78.0,
#                        'id': 93318,
#                        'interceptions': 68.0,
#                        'jumping': 80.0,
#                        'long_passing': 62.0,
#                        'long_shots': 58.0,
#                        'marking': 72.0,
#                        'overall_rating': 74.0,
#                        'penalties': 62.0,
#                        'player_api_id': 195448,
#                        'player_fifa_api_id': 198584,
#                        'positioning': 47.0,
#                        'potential': 76.0,
#                        'preferred_foot': 'right',
#                        'reactions': 71.0,
#                        'short_passing': 64.0,
#                        'shot_power': 78.0,
#                        'sliding_tackle': 71.0,
#                        'sprint_speed': 78.0,
#                        'stamina': 81.0,
#                        'standing_tackle': 74.0,
#                        'strength': 88.0,
#                        'vision': 57.0,
#                        'volleys': 49.0},
#     'Leon Bailey': {   'acceleration': 94.0,
#                        'aggression': 57.0,
#                        'agility': 92.0,
#                        'attacking_work_rate': 'high',
#                        'balance': 77.0,
#                        'ball_control': 73.0,
#                        'crossing': 72.0,
#                        'curve': 71.0,
#                        'date': '2016-05-19 00:00:00',
#                        'defensive_work_rate': 'medium',
#                        'dribbling': 76.0,
#                        'finishing': 60.0,
#                        'free_kick_accuracy': 70.0,
#                        'gk_diving': 12.0,
#                        'gk_handling': 13.0,
#                        'gk_kicking': 6.0,
#                        'gk_positioning': 15.0,
#                        'gk_reflexes': 14.0,
#                        'heading_accuracy': 57.0,
#                        'id': 100747,
#                        'interceptions': 21.0,
#                        'jumping': 55.0,
#                        'long_passing': 59.0,
#                        'long_shots': 68.0,
#                        'marking': 32.0,
#                        'overall_rating': 71.0,
#                        'penalties': 61.0,
#                        'player_api_id': 671331,
#                        'player_fifa_api_id': 229906,
#                        'positioning': 60.0,
#                        'potential': 85.0,
#                        'preferred_foot': 'left',
#                        'reactions': 63.0,
#                        'short_passing': 66.0,
#                        'shot_power': 73.0,
#                        'sliding_tackle': 18.0,
#                        'sprint_speed': 92.0,
#                        'stamina': 67.0,
#                        'standing_tackle': 27.0,
#                        'strength': 56.0,
#                        'vision': 66.0,
#                        'volleys': 56.0},
#     'Mbwana Samata': {   'acceleration': 81.0,
#                          'aggression': 45.0,
#                          'agility': 78.0,
#                          'attacking_work_rate': 'medium',
#                          'balance': 65.0,
#                          'ball_control': 63.0,
#                          'crossing': 63.0,
#                          'curve': 65.0,
#                          'date': '2016-04-21 00:00:00',
#                          'defensive_work_rate': 'medium',
#                          'dribbling': 68.0,
#                          'finishing': 71.0,
#                          'free_kick_accuracy': 57.0,
#                          'gk_diving': 12.0,
#                          'gk_handling': 14.0,
#                          'gk_kicking': 9.0,
#                          'gk_positioning': 7.0,
#                          'gk_reflexes': 9.0,
#                          'heading_accuracy': 66.0,
#                          'id': 121885,
#                          'interceptions': 18.0,
#                          'jumping': 82.0,
#                          'long_passing': 45.0,
#                          'long_shots': 67.0,
#                          'marking': 15.0,
#                          'overall_rating': 67.0,
#                          'penalties': 67.0,
#                          'player_api_id': 437329,
#                          'player_fifa_api_id': 218066,
#                          'positioning': 64.0,
#                          'potential': 72.0,
#                          'preferred_foot': 'right',
#                          'reactions': 58.0,
#                          'short_passing': 63.0,
#                          'shot_power': 70.0,
#                          'sliding_tackle': 13.0,
#                          'sprint_speed': 80.0,
#                          'stamina': 57.0,
#                          'standing_tackle': 18.0,
#                          'strength': 65.0,
#                          'vision': 56.0,
#                          'volleys': 66.0},
#     'Neeskens Kebano': {   'acceleration': 84.0,
#                            'aggression': 49.0,
#                            'agility': 81.0,
#                            'attacking_work_rate': 'high',
#                            'balance': 85.0,
#                            'ball_control': 78.0,
#                            'crossing': 71.0,
#                            'curve': 70.0,
#                            'date': '2016-04-21 00:00:00',
#                            'defensive_work_rate': 'medium',
#                            'dribbling': 79.0,
#                            'finishing': 73.0,
#                            'free_kick_accuracy': 71.0,
#                            'gk_diving': 15.0,
#                            'gk_handling': 12.0,
#                            'gk_kicking': 16.0,
#                            'gk_positioning': 15.0,
#                            'gk_reflexes': 15.0,
#                            'heading_accuracy': 57.0,
#                            'id': 130760,
#                            'interceptions': 38.0,
#                            'jumping': 82.0,
#                            'long_passing': 64.0,
#                            'long_shots': 72.0,
#                            'marking': 25.0,
#                            'overall_rating': 75.0,
#                            'penalties': 74.0,
#                            'player_api_id': 240478,
#                            'player_fifa_api_id': 202940,
#                            'positioning': 73.0,
#                            'potential': 79.0,
#                            'preferred_foot': 'right',
#                            'reactions': 74.0,
#                            'short_passing': 71.0,
#                            'shot_power': 74.0,
#                            'sliding_tackle': 21.0,
#                            'sprint_speed': 80.0,
#                            'stamina': 76.0,
#                            'standing_tackle': 27.0,
#                            'strength': 68.0,
#                            'vision': 75.0,
#                            'volleys': 69.0},
#     'Nikos Karelis': {   'acceleration': 80.0,
#                          'aggression': 72.0,
#                          'agility': 73.0,
#                          'attacking_work_rate': 'high',
#                          'balance': 81.0,
#                          'ball_control': 73.0,
#                          'crossing': 67.0,
#                          'curve': 61.0,
#                          'date': '2016-03-17 00:00:00',
#                          'defensive_work_rate': 'medium',
#                          'dribbling': 72.0,
#                          'finishing': 76.0,
#                          'free_kick_accuracy': 63.0,
#                          'gk_diving': 9.0,
#                          'gk_handling': 8.0,
#                          'gk_kicking': 12.0,
#                          'gk_positioning': 13.0,
#                          'gk_reflexes': 7.0,
#                          'heading_accuracy': 61.0,
#                          'id': 134144,
#                          'interceptions': 27.0,
#                          'jumping': 62.0,
#                          'long_passing': 62.0,
#                          'long_shots': 72.0,
#                          'marking': 25.0,
#                          'overall_rating': 73.0,
#                          'penalties': 67.0,
#                          'player_api_id': 110948,
#                          'player_fifa_api_id': 210947,
#                          'positioning': 75.0,
#                          'potential': 78.0,
#                          'preferred_foot': 'left',
#                          'reactions': 73.0,
#                          'short_passing': 68.0,
#                          'shot_power': 77.0,
#                          'sliding_tackle': 36.0,
#                          'sprint_speed': 77.0,
#                          'stamina': 68.0,
#                          'standing_tackle': 31.0,
#                          'strength': 78.0,
#                          'vision': 62.0,
#                          'volleys': 71.0},
#     'Onyinye Ndidi,26': {   'acceleration': 76.0,
#                             'aggression': 72.0,
#                             'agility': 67.0,
#                             'attacking_work_rate': 'None',
#                             'balance': 63.0,
#                             'ball_control': 61.0,
#                             'crossing': 48.0,
#                             'curve': 53.0,
#                             'date': '2016-04-21 00:00:00',
#                             'defensive_work_rate': '0',
#                             'dribbling': 56.0,
#                             'finishing': 34.0,
#                             'free_kick_accuracy': 29.0,
#                             'gk_diving': 13.0,
#                             'gk_handling': 14.0,
#                             'gk_kicking': 7.0,
#                             'gk_positioning': 7.0,
#                             'gk_reflexes': 13.0,
#                             'heading_accuracy': 68.0,
#                             'id': 136477,
#                             'interceptions': 65.0,
#                             'jumping': 74.0,
#                             'long_passing': 65.0,
#                             'long_shots': 44.0,
#                             'marking': 63.0,
#                             'overall_rating': 67.0,
#                             'penalties': 35.0,
#                             'player_api_id': 533228,
#                             'player_fifa_api_id': 226790,
#                             'positioning': 23.0,
#                             'potential': 79.0,
#                             'preferred_foot': 'right',
#                             'reactions': 66.0,
#                             'short_passing': 68.0,
#                             'shot_power': 56.0,
#                             'sliding_tackle': 67.0,
#                             'sprint_speed': 78.0,
#                             'stamina': 84.0,
#                             'standing_tackle': 68.0,
#                             'strength': 73.0,
#                             'vision': 63.0,
#                             'volleys': 28.0},
#     'Ruslan Malinovsky': {   'acceleration': 69.0,
#                              'aggression': 65.0,
#                              'agility': 64.0,
#                              'attacking_work_rate': 'medium',
#                              'balance': 65.0,
#                              'ball_control': 72.0,
#                              'crossing': 70.0,
#                              'curve': 73.0,
#                              'date': '2016-03-10 00:00:00',
#                              'defensive_work_rate': 'medium',
#                              'dribbling': 71.0,
#                              'finishing': 71.0,
#                              'free_kick_accuracy': 74.0,
#                              'gk_diving': 6.0,
#                              'gk_handling': 6.0,
#                              'gk_kicking': 12.0,
#                              'gk_positioning': 15.0,
#                              'gk_reflexes': 13.0,
#                              'heading_accuracy': 69.0,
#                              'id': 155054,
#                              'interceptions': 41.0,
#                              'jumping': 69.0,
#                              'long_passing': 71.0,
#                              'long_shots': 75.0,
#                              'marking': 37.0,
#                              'overall_rating': 71.0,
#                              'penalties': 66.0,
#                              'player_api_id': 459658,
#                              'player_fifa_api_id': 231969,
#                              'positioning': 68.0,
#                              'potential': 77.0,
#                              'preferred_foot': 'left',
#                              'reactions': 71.0,
#                              'short_passing': 72.0,
#                              'shot_power': 76.0,
#                              'sliding_tackle': 46.0,
#                              'sprint_speed': 68.0,
#                              'stamina': 67.0,
#                              'standing_tackle': 49.0,
#                              'strength': 68.0,
#                              'vision': 72.0,
#                              'volleys': 72.0},
#     'Sandy Walsh': {   'acceleration': 69.0,
#                        'aggression': 67.0,
#                        'agility': 68.0,
#                        'attacking_work_rate': 'medium',
#                        'balance': 68.0,
#                        'ball_control': 62.0,
#                        'crossing': 63.0,
#                        'curve': 34.0,
#                        'date': '2016-03-17 00:00:00',
#                        'defensive_work_rate': 'high',
#                        'dribbling': 62.0,
#                        'finishing': 22.0,
#                        'free_kick_accuracy': 47.0,
#                        'gk_diving': 11.0,
#                        'gk_handling': 10.0,
#                        'gk_kicking': 7.0,
#                        'gk_positioning': 12.0,
#                        'gk_reflexes': 13.0,
#                        'heading_accuracy': 65.0,
#                        'id': 157655,
#                        'interceptions': 68.0,
#                        'jumping': 70.0,
#                        'long_passing': 61.0,
#                        'long_shots': 25.0,
#                        'marking': 68.0,
#                        'overall_rating': 67.0,
#                        'penalties': 44.0,
#                        'player_api_id': 354175,
#                        'player_fifa_api_id': 205618,
#                        'positioning': 54.0,
#                        'potential': 76.0,
#                        'preferred_foot': 'right',
#                        'reactions': 64.0,
#                        'short_passing': 64.0,
#                        'shot_power': 44.0,
#                        'sliding_tackle': 65.0,
#                        'sprint_speed': 73.0,
#                        'stamina': 82.0,
#                        'standing_tackle': 67.0,
#                        'strength': 62.0,
#                        'vision': 53.0,
#                        'volleys': 32.0},
#     'Sebastien Dewaest': {   'acceleration': 50.0,
#                              'aggression': 81.0,
#                              'agility': 41.0,
#                              'attacking_work_rate': 'medium',
#                              'balance': 38.0,
#                              'ball_control': 56.0,
#                              'crossing': 39.0,
#                              'curve': 33.0,
#                              'date': '2016-04-21 00:00:00',
#                              'defensive_work_rate': 'high',
#                              'dribbling': 28.0,
#                              'finishing': 33.0,
#                              'free_kick_accuracy': 39.0,
#                              'gk_diving': 16.0,
#                              'gk_handling': 7.0,
#                              'gk_kicking': 12.0,
#                              'gk_positioning': 16.0,
#                              'gk_reflexes': 10.0,
#                              'heading_accuracy': 77.0,
#                              'id': 159982,
#                              'interceptions': 71.0,
#                              'jumping': 67.0,
#                              'long_passing': 49.0,
#                              'long_shots': 35.0,
#                              'marking': 74.0,
#                              'overall_rating': 74.0,
#                              'penalties': 40.0,
#                              'player_api_id': 280083,
#                              'player_fifa_api_id': 184183,
#                              'positioning': 37.0,
#                              'potential': 77.0,
#                              'preferred_foot': 'right',
#                              'reactions': 69.0,
#                              'short_passing': 54.0,
#                              'shot_power': 72.0,
#                              'sliding_tackle': 72.0,
#                              'sprint_speed': 65.0,
#                              'stamina': 77.0,
#                              'standing_tackle': 76.0,
#                              'strength': 89.0,
#                              'vision': 38.0,
#                              'volleys': 22.0},
#     'Siebe Schrijvers': {   'acceleration': 76.0,
#                             'aggression': 58.0,
#                             'agility': 83.0,
#                             'attacking_work_rate': 'high',
#                             'balance': 78.0,
#                             'ball_control': 73.0,
#                             'crossing': 66.0,
#                             'curve': 54.0,
#                             'date': '2016-04-28 00:00:00',
#                             'defensive_work_rate': 'medium',
#                             'dribbling': 71.0,
#                             'finishing': 68.0,
#                             'free_kick_accuracy': 67.0,
#                             'gk_diving': 8.0,
#                             'gk_handling': 6.0,
#                             'gk_kicking': 6.0,
#                             'gk_positioning': 14.0,
#                             'gk_reflexes': 14.0,
#                             'heading_accuracy': 54.0,
#                             'id': 162474,
#                             'interceptions': 35.0,
#                             'jumping': 71.0,
#                             'long_passing': 63.0,
#                             'long_shots': 72.0,
#                             'marking': 22.0,
#                             'overall_rating': 69.0,
#                             'penalties': 63.0,
#                             'player_api_id': 354494,
#                             'player_fifa_api_id': 209780,
#                             'positioning': 68.0,
#                             'potential': 81.0,
#                             'preferred_foot': 'right',
#                             'reactions': 66.0,
#                             'short_passing': 67.0,
#                             'shot_power': 67.0,
#                             'sliding_tackle': 25.0,
#                             'sprint_speed': 73.0,
#                             'stamina': 66.0,
#                             'standing_tackle': 34.0,
#                             'strength': 46.0,
#                             'vision': 66.0,
#                             'volleys': 73.0},
#     'Thomas Buffel': {   'acceleration': 65.0,
#                          'aggression': 65.0,
#                          'agility': 67.0,
#                          'attacking_work_rate': 'medium',
#                          'balance': 73.0,
#                          'ball_control': 73.0,
#                          'crossing': 76.0,
#                          'curve': 66.0,
#                          'date': '2016-03-24 00:00:00',
#                          'defensive_work_rate': 'low',
#                          'dribbling': 74.0,
#                          'finishing': 72.0,
#                          'free_kick_accuracy': 67.0,
#                          'gk_diving': 13.0,
#                          'gk_handling': 8.0,
#                          'gk_kicking': 8.0,
#                          'gk_positioning': 15.0,
#                          'gk_reflexes': 15.0,
#                          'heading_accuracy': 53.0,
#                          'id': 170234,
#                          'interceptions': 59.0,
#                          'jumping': 60.0,
#                          'long_passing': 69.0,
#                          'long_shots': 66.0,
#                          'marking': 43.0,
#                          'overall_rating': 71.0,
#                          'penalties': 71.0,
#                          'player_api_id': 32863,
#                          'player_fifa_api_id': 156535,
#                          'positioning': 68.0,
#                          'potential': 71.0,
#                          'preferred_foot': 'right',
#                          'reactions': 66.0,
#                          'short_passing': 71.0,
#                          'shot_power': 64.0,
#                          'sliding_tackle': 47.0,
#                          'sprint_speed': 67.0,
#                          'stamina': 72.0,
#                          'standing_tackle': 52.0,
#                          'strength': 54.0,
#                          'vision': 74.0,
#                          'volleys': 68.0},
#     'Timothy Castagne': {   'acceleration': 77.0,
#                             'aggression': 65.0,
#                             'agility': 71.0,
#                             'attacking_work_rate': 'high',
#                             'balance': 68.0,
#                             'ball_control': 67.0,
#                             'crossing': 71.0,
#                             'curve': 32.0,
#                             'date': '2016-02-04 00:00:00',
#                             'defensive_work_rate': 'high',
#                             'dribbling': 58.0,
#                             'finishing': 18.0,
#                             'free_kick_accuracy': 33.0,
#                             'gk_diving': 14.0,
#                             'gk_handling': 9.0,
#                             'gk_kicking': 15.0,
#                             'gk_positioning': 10.0,
#                             'gk_reflexes': 15.0,
#                             'heading_accuracy': 62.0,
#                             'id': 172253,
#                             'interceptions': 64.0,
#                             'jumping': 70.0,
#                             'long_passing': 63.0,
#                             'long_shots': 27.0,
#                             'marking': 67.0,
#                             'overall_rating': 69.0,
#                             'penalties': 27.0,
#                             'player_api_id': 465750,
#                             'player_fifa_api_id': 222501,
#                             'positioning': 47.0,
#                             'potential': 78.0,
#                             'preferred_foot': 'right',
#                             'reactions': 63.0,
#                             'short_passing': 65.0,
#                             'shot_power': 37.0,
#                             'sliding_tackle': 69.0,
#                             'sprint_speed': 80.0,
#                             'stamina': 78.0,
#                             'standing_tackle': 71.0,
#                             'strength': 67.0,
#                             'vision': 52.0,
#                             'volleys': 28.0},
#     'Tornike Okriashvili': {   'acceleration': 80.0,
#                                'aggression': 37.0,
#                                'agility': 74.0,
#                                'attacking_work_rate': 'high',
#                                'balance': 70.0,
#                                'ball_control': 76.0,
#                                'crossing': 66.0,
#                                'curve': 64.0,
#                                'date': '2015-09-25 00:00:00',
#                                'defensive_work_rate': 'low',
#                                'dribbling': 77.0,
#                                'finishing': 63.0,
#                                'free_kick_accuracy': 64.0,
#                                'gk_diving': 11.0,
#                                'gk_handling': 7.0,
#                                'gk_kicking': 11.0,
#                                'gk_positioning': 7.0,
#                                'gk_reflexes': 11.0,
#                                'heading_accuracy': 39.0,
#                                'id': 174613,
#                                'interceptions': 22.0,
#                                'jumping': 51.0,
#                                'long_passing': 64.0,
#                                'long_shots': 62.0,
#                                'marking': 33.0,
#                                'overall_rating': 70.0,
#                                'penalties': 47.0,
#                                'player_api_id': 173730,
#                                'player_fifa_api_id': 216428,
#                                'positioning': 68.0,
#                                'potential': 74.0,
#                                'preferred_foot': 'right',
#                                'reactions': 70.0,
#                                'short_passing': 67.0,
#                                'shot_power': 65.0,
#                                'sliding_tackle': 36.0,
#                                'sprint_speed': 73.0,
#                                'stamina': 60.0,
#                                'standing_tackle': 29.0,
#                                'strength': 54.0,
#                                'vision': 67.0,
#                                'volleys': 49.0},
#     'Yoni Buyens': {   'acceleration': 65.0,
#                        'aggression': 81.0,
#                        'agility': 64.0,
#                        'attacking_work_rate': 'high',
#                        'balance': 67.0,
#                        'ball_control': 67.0,
#                        'crossing': 59.0,
#                        'curve': 55.0,
#                        'date': '2016-03-24 00:00:00',
#                        'defensive_work_rate': 'high',
#                        'dribbling': 62.0,
#                        'finishing': 58.0,
#                        'free_kick_accuracy': 56.0,
#                        'gk_diving': 15.0,
#                        'gk_handling': 8.0,
#                        'gk_kicking': 9.0,
#                        'gk_positioning': 14.0,
#                        'gk_reflexes': 6.0,
#                        'heading_accuracy': 74.0,
#                        'id': 182250,
#                        'interceptions': 74.0,
#                        'jumping': 77.0,
#                        'long_passing': 67.0,
#                        'long_shots': 69.0,
#                        'marking': 64.0,
#                        'overall_rating': 70.0,
#                        'penalties': 72.0,
#                        'player_api_id': 38969,
#                        'player_fifa_api_id': 178136,
#                        'positioning': 74.0,
#                        'potential': 70.0,
#                        'preferred_foot': 'right',
#                        'reactions': 72.0,
#                        'short_passing': 72.0,
#                        'shot_power': 75.0,
#                        'sliding_tackle': 68.0,
#                        'sprint_speed': 69.0,
#                        'stamina': 88.0,
#                        'standing_tackle': 73.0,
#                        'strength': 75.0,
#                        'vision': 69.0,
#                        'volleys': 57.0}}

# %%
attribute_list = list(teams[valid_team][list(teams[valid_team].keys())[1]])
print(attribute_list)
# Out:
# ['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']

# %% [markdown]
# The next section of this will be to make a function that returns the team's average attributes. We will then chart the top 5 teams and visually look for common attribute combinations.

# %%
#get team averages definition
#to build this I found the soluction using our valid_team variable, then tried it with a hard-coded input in the teams dictionary. After both work I copy the code and cleaned up for the function.
def average_team_attributes(team):
    team_stats = pd.DataFrame.from_dict(teams[team])
    team_stats = team_stats.T
    return(team_stats.mean(axis = 0))

average_team_attributes('Aberdeen')
# Out:
# acceleration              69.333333
# aggression                61.000000
# agility                   67.791667
# balance                   69.250000
# ball_control              64.333333
# crossing                  53.000000
# curve                     46.375000
# dribbling                 60.500000
# finishing                 45.750000
# free_kick_accuracy        45.916667
# gk_diving                 10.791667
# gk_handling               11.416667
# gk_kicking                10.708333
# gk_positioning            11.000000
# gk_reflexes               11.416667
# heading_accuracy          57.916667
# id                    101197.083333
# interceptions             49.375000
# jumping                   67.000000
# long_passing              56.125000
# long_shots                46.833333
# marking                   48.750000
# overall_rating            65.000000
# penalties                 51.375000
# player_api_id         167867.791667
# player_fifa_api_id    180780.583333
# positioning               48.500000
# potential                 69.166667
# reactions                 60.291667
# short_passing             63.041667
# shot_power                54.375000
# sliding_tackle            48.541667
# sprint_speed              70.541667
# stamina                   67.791667
# standing_tackle           51.208333
# strength                  64.541667
# vision                    55.291667
# volleys                   40.458333
# dtype: float64

# %%
def build_final_dataframe(list_of_teams):
    frame = {}
    team_exclusions = []
    for i in list_of_teams:
        try:
            frame[i] = average_team_attributes(i)
        except:
            team_exclusions.append(i)
            pass
    all_teams = pd.DataFrame(frame)
    return all_teams.drop(['player_api_id','player_fifa_api_id','id'])

    
averages_all_teams = build_final_dataframe(team_totals.index.tolist()) 
averages_all_teams
# Out:
#                     1. FC Köln  1. FSV Mainz 05  ADO Den Haag  AS Monaco  \
# acceleration         70.904762        70.464286     67.318182  72.535714
# aggression           66.809524        66.714286     60.363636  68.571429
# agility              69.000000        70.321429     63.818182  70.571429
# balance              65.238095        69.571429     60.590909  68.142857
# ball_control         70.666667        69.750000     67.227273  74.392857
# crossing             59.476190        63.964286     55.045455  64.642857
# curve                58.142857        59.428571     54.136364  62.000000
# dribbling            65.333333        67.464286     63.727273  72.500000
# finishing            52.285714        52.535714     52.545455  60.250000
# free_kick_accuracy   48.571429        55.892857     46.636364  52.035714
# gk_diving            11.047619        11.035714      9.954545  10.678571
# gk_handling          11.095238        11.428571     11.272727  10.964286
# gk_kicking           10.714286        11.214286     10.590909  10.214286
# gk_positioning       10.571429        11.428571     10.590909  10.357143
# gk_reflexes          11.761905        11.142857     11.545455  11.250000
# heading_accuracy     65.190476        64.678571     59.090909  64.857143
# interceptions        55.714286        58.928571     48.227273  58.035714
# jumping              69.428571        70.678571     69.727273  67.750000
# long_passing         60.571429        66.500000     57.909091  63.714286
# long_shots           54.619048        58.785714     53.818182  62.214286
# marking              56.714286        57.535714     48.136364  53.535714
# overall_rating       73.857143        73.357143     68.363636  75.428571
# penalties            56.476190        57.750000     55.363636  58.321429
# positioning          58.428571        61.000000     58.000000  66.928571
# potential            77.000000        76.357143     71.500000  81.321429
# reactions            72.809524        71.857143     64.545455  73.678571
# short_passing        70.571429        71.928571     63.500000  71.750000
# shot_power           67.190476        69.000000     63.545455  70.821429
# sliding_tackle       57.333333        57.392857     48.681818  53.428571
# sprint_speed         71.476190        72.464286     69.818182  72.785714
# stamina              72.476190        74.321429     68.590909  71.214286
# standing_tackle      59.666667        60.607143     50.500000  57.607143
# strength             69.571429        69.107143     68.318182  72.250000
# vision               60.095238        63.500000     57.863636  65.714286
# volleys              53.619048        53.178571     50.863636  54.678571
#
#                            AZ   Aberdeen  Académica de Coimbra   Ajax  \
# acceleration        71.793103  69.333333             68.192308  72.65
# aggression          59.896552  61.000000             66.846154  64.85
# agility             70.206897  67.791667             68.884615  71.40
# balance             67.965517  69.250000             67.730769  65.70
# ball_control        69.620690  64.333333             66.961538  75.15
# crossing            56.137931  53.000000             59.307692  64.15
# curve               61.241379  46.375000             56.576923  62.45
# dribbling           67.172414  60.500000             63.653846  71.90
# finishing           51.413793  45.750000             49.769231  57.75
# free_kick_accuracy  51.862069  45.916667             51.615385  52.90
# gk_diving           10.172414  10.791667             11.192308  10.35
# gk_handling         10.172414  11.416667              9.846154  11.00
# gk_kicking          11.586207  10.708333             11.192308  11.10
# gk_positioning      10.206897  11.000000             11.346154  12.00
# gk_reflexes         11.000000  11.416667             11.000000  11.45
# heading_accuracy    57.000000  57.916667             58.307692  64.00
# interceptions       53.034483  49.375000             52.884615  57.40
# jumping             63.931034  67.000000             66.692308  65.45
# long_passing        58.758621  56.125000             57.423077  64.95
# long_shots          58.758621  46.833333             56.038462  59.25
# marking             52.275862  48.750000             48.923077  52.65
# overall_rating      70.068966  65.000000             68.307692  74.70
# penalties           53.655172  51.375000             54.576923  54.45
# positioning         59.724138  48.500000             58.230769  64.20
# potential           75.758621  69.166667             71.730769  81.45
# reactions           65.068966  60.291667             65.923077  72.50
# short_passing       67.482759  63.041667             64.076923  71.65
# shot_power          66.448276  54.375000             68.923077  69.65
# sliding_tackle      52.034483  48.541667             50.115385  52.50
# sprint_speed        71.448276  70.541667             68.615385  74.35
# stamina             70.482759  67.791667             69.153846  71.60
# standing_tackle     53.689655  51.208333             53.230769  59.35
# strength            64.724138  64.541667             65.269231  67.95
# vision              60.448276  55.291667             56.307692  66.65
# volleys             52.862069  40.458333             50.384615  57.25
#
#                     Angers SCO    Arsenal    ...      Valencia CF  \
# acceleration         63.904762  75.636364    ...        75.041667
# aggression           63.809524  72.500000    ...        72.375000
# agility              65.476190  74.863636    ...        74.125000
# balance              64.809524  71.727273    ...        69.875000
# ball_control         68.238095  77.454545    ...        76.541667
# crossing             57.428571  69.318182    ...        66.333333
# curve                53.285714  64.863636    ...        67.916667
# dribbling            61.809524  74.409091    ...        71.333333
# finishing            48.904762  61.545455    ...        61.916667
# free_kick_accuracy   48.571429  59.454545    ...        59.416667
# gk_diving            10.904762   9.409091    ...        10.500000
# gk_handling          10.809524  11.000000    ...         8.958333
# gk_kicking           10.714286   9.818182    ...        11.333333
# gk_positioning       10.761905  10.090909    ...        10.166667
# gk_reflexes          11.523810  10.363636    ...        11.291667
# heading_accuracy     64.142857  63.500000    ...        66.458333
# interceptions        53.285714  60.136364    ...        62.500000
# jumping              69.619048  69.090909    ...        72.625000
# long_passing         59.428571  67.954545    ...        66.875000
# long_shots           54.476190  64.772727    ...        66.125000
# marking              52.333333  58.000000    ...        58.333333
# overall_rating       68.809524  79.318182    ...        78.875000
# penalties            55.380952  64.681818    ...        61.666667
# positioning          55.238095  68.590909    ...        65.666667
# potential            70.761905  82.636364    ...        82.916667
# reactions            65.952381  77.272727    ...        75.500000
# short_passing        67.285714  77.045455    ...        75.166667
# shot_power           61.619048  71.227273    ...        73.958333
# sliding_tackle       49.285714  59.272727    ...        60.875000
# sprint_speed         66.476190  74.409091    ...        75.250000
# stamina              70.476190  77.772727    ...        74.833333
# standing_tackle      53.666667  62.181818    ...        61.875000
# strength             71.761905  70.909091    ...        71.875000
# vision               60.047619  70.545455    ...        65.541667
# volleys              45.857143  58.545455    ...        59.208333
#
#                     VfB Stuttgart  VfL Wolfsburg  Villarreal CF  Vitesse  \
# acceleration            69.285714      70.318182      73.692308    71.64
# aggression              71.333333      68.318182      65.730769    60.28
# agility                 65.285714      67.136364      72.923077    70.88
# balance                 62.952381      64.136364      71.346154    70.28
# ball_control            69.333333      74.545455      76.230769    72.24
# crossing                60.238095      66.090909      67.884615    60.48
# curve                   58.714286      61.545455      67.423077    62.00
# dribbling               65.095238      70.363636      71.038462    66.76
# finishing               54.238095      61.272727      60.500000    53.24
# free_kick_accuracy      53.952381      56.727273      55.884615    56.52
# gk_diving               11.714286      11.954545      10.153846     9.72
# gk_handling             11.142857      10.136364      12.192308    11.56
# gk_kicking              11.238095      10.045455      10.769231     9.96
# gk_positioning          11.142857      10.545455       8.846154    11.40
# gk_reflexes             10.190476      11.318182      10.153846     9.96
# heading_accuracy        65.523810      69.136364      64.884615    58.88
# interceptions           59.333333      61.409091      58.884615    53.88
# jumping                 66.476190      68.454545      72.923077    65.52
# long_passing            62.666667      68.727273      67.461538    66.12
# long_shots              55.428571      69.045455      62.730769    59.80
# marking                 57.714286      54.954545      51.538462    52.20
# overall_rating          74.380952      77.954545      77.461538    70.40
# penalties               56.285714      63.636364      58.192308    57.40
# positioning             60.857143      65.772727      67.076923    56.88
# potential               77.285714      80.227273      81.115385    75.68
# reactions               73.095238      78.045455      76.884615    65.36
# short_passing           69.761905      75.681818      75.923077    71.00
# shot_power              69.428571      77.500000      69.346154    69.28
# sliding_tackle          59.000000      58.136364      53.192308    52.28
# sprint_speed            71.428571      71.363636      72.923077    70.64
# stamina                 73.428571      72.363636      69.346154    71.12
# standing_tackle         61.809524      60.045455      56.384615    53.44
# strength                72.761905      73.045455      68.346154    65.96
# vision                  60.142857      67.363636      66.653846    61.24
# volleys                 54.428571      62.772727      58.538462    51.88
#
#                     Vitória Setúbal  Waasland-Beveren    Watford  \
# acceleration              71.275862         67.666667  72.105263
# aggression                63.931034         59.777778  70.631579
# agility                   68.034483         66.611111  67.736842
# balance                   66.689655         64.611111  66.473684
# ball_control              66.517241         65.222222  71.263158
# crossing                  57.862069         57.666667  63.315789
# curve                     54.724138         55.444444  61.526316
# dribbling                 64.517241         63.166667  67.789474
# finishing                 52.482759         51.222222  55.894737
# free_kick_accuracy        48.758621         53.111111  54.578947
# gk_diving                  9.379310         11.222222  10.947368
# gk_handling               11.620690         10.333333  11.263158
# gk_kicking                10.517241          9.888889  10.263158
# gk_positioning             9.482759         10.500000  11.789474
# gk_reflexes               10.689655         10.388889  11.210526
# heading_accuracy          61.758621         56.222222  66.000000
# interceptions             50.068966         48.444444  61.736842
# jumping                   67.724138         64.222222  69.210526
# long_passing              57.931034         56.777778  65.631579
# long_shots                58.137931         55.277778  63.684211
# marking                   48.172414         41.277778  59.736842
# overall_rating            68.931034         65.555556  74.473684
# penalties                 56.310345         54.833333  58.631579
# positioning               56.862069         56.222222  60.052632
# potential                 72.758621         69.888889  75.210526
# reactions                 66.172414         62.500000  72.315789
# short_passing             64.137931         62.611111  71.526316
# shot_power                67.689655         65.500000  71.631579
# sliding_tackle            50.896552         44.166667  63.421053
# sprint_speed              72.379310         67.000000  72.263158
# stamina                   70.310345         65.555556  75.315789
# standing_tackle           51.344828         48.277778  66.105263
# strength                  66.344828         67.611111  75.210526
# vision                    57.827586         57.388889  62.052632
# volleys                   51.103448         52.444444  53.894737
#
#                     West Bromwich Albion  Willem II
# acceleration                       66.35      67.64
# aggression                         72.25      58.20
# agility                            63.30      64.68
# balance                            61.40      65.28
# ball_control                       70.95      66.92
# crossing                           60.65      58.88
# curve                              54.25      56.20
# dribbling                          64.10      64.88
# finishing                          62.25      52.48
# free_kick_accuracy                 51.60      47.72
# gk_diving                           9.10      11.20
# gk_handling                        11.40      12.28
# gk_kicking                         11.25      11.24
# gk_positioning                     12.30      11.20
# gk_reflexes                        10.55      10.72
# heading_accuracy                   71.30      61.56
# interceptions                      58.50      55.64
# jumping                            67.65      66.28
# long_passing                       62.85      60.08
# long_shots                         58.80      53.48
# marking                            57.55      48.64
# overall_rating                     73.65      67.64
# penalties                          65.45      55.68
# positioning                        61.40      59.00
# potential                          75.85      70.64
# reactions                          72.40      65.52
# short_passing                      69.00      64.08
# shot_power                         68.65      63.44
# sliding_tackle                     56.25      48.40
# sprint_speed                       65.70      68.04
# stamina                            71.25      68.80
# standing_tackle                    58.55      50.12
# strength                           73.25      66.76
# vision                             62.10      58.96
# volleys                            53.50      49.92
#
# [35 rows x 139 columns]

# %%
team_totals.index[0:5]
# Out:
# Index(['Club Brugge KV', 'Napoli', 'Borussia Dortmund', 'SL Benfica',
#        'Paris Saint-Germain'],
#       dtype='object', name='team_long_name')

# %%
number_of_top_teams = 5
averages_top_teams = build_final_dataframe(team_totals.index[0:6])
averages_top_teams
# Out:
#                     Borussia Dortmund  Club Brugge KV   Juventus     Napoli  \
# acceleration                75.181818       65.730769  77.037037  75.388889
# aggression                  63.909091       61.692308  70.407407  70.000000
# agility                     75.045455       65.884615  76.148148  71.555556
# balance                     71.363636       60.307692  71.370370  67.666667
# ball_control                75.272727       68.615385  76.777778  76.277778
# crossing                    68.090909       59.807692  66.814815  66.388889
# curve                       65.909091       54.961538  68.740741  62.500000
# dribbling                   72.863636       63.846154  75.074074  70.555556
# finishing                   59.681818       57.423077  57.851852  58.055556
# free_kick_accuracy          59.318182       52.461538  57.925926  57.388889
# gk_diving                   10.318182       10.769231   6.481481   9.388889
# gk_handling                 10.272727       10.538462   6.074074   8.333333
# gk_kicking                  10.590909       10.692308   6.444444   9.166667
# gk_positioning              10.181818       10.384615   6.111111   9.777778
# gk_reflexes                 10.227273       10.615385   6.888889   9.833333
# heading_accuracy            63.863636       64.653846  68.259259  67.333333
# interceptions               68.090909       53.692308  65.037037  62.111111
# jumping                     71.772727       69.153846  76.296296  70.888889
# long_passing                70.909091       62.038462  66.555556  68.888889
# long_shots                  63.272727       56.269231  68.518519  65.277778
# marking                     58.772727       48.653846  61.259259  57.055556
# overall_rating              78.727273       71.461538  79.962963  78.444444
# penalties                   61.727273       62.038462  65.074074  58.722222
# positioning                 65.818182       60.846154  67.370370  63.722222
# potential                   82.272727       76.192308  82.000000  80.000000
# reactions                   78.181818       69.846154  77.592593  76.944444
# short_passing               75.772727       68.269231  73.666667  74.388889
# shot_power                  71.863636       64.576923  75.703704  72.055556
# sliding_tackle              62.818182       50.269231  66.740741  62.333333
# sprint_speed                74.863636       70.038462  79.259259  76.888889
# stamina                     75.909091       72.961538  75.888889  77.055556
# standing_tackle             62.454545       51.461538  65.851852  64.166667
# strength                    67.590909       70.230769  75.000000  70.777778
# vision                      70.272727       63.115385  67.407407  64.111111
# volleys                     61.681818       51.807692  65.666667  58.833333
#
#                     Paris Saint-Germain
# acceleration                  72.916667
# aggression                    72.458333
# agility                       74.541667
# balance                       68.625000
# ball_control                  77.416667
# crossing                      68.125000
# curve                         63.791667
# dribbling                     73.625000
# finishing                     59.500000
# free_kick_accuracy            55.416667
# gk_diving                     10.125000
# gk_handling                    9.875000
# gk_kicking                    10.208333
# gk_positioning                10.375000
# gk_reflexes                   11.083333
# heading_accuracy              68.083333
# interceptions                 65.333333
# jumping                       75.208333
# long_passing                  71.041667
# long_shots                    62.833333
# marking                       62.416667
# overall_rating                78.291667
# penalties                     62.041667
# positioning                   66.750000
# potential                     82.416667
# reactions                     75.958333
# short_passing                 77.500000
# shot_power                    71.208333
# sliding_tackle                64.958333
# sprint_speed                  73.208333
# stamina                       75.541667
# standing_tackle               68.166667
# strength                      69.500000
# vision                        70.833333
# volleys                       59.375000

# %% [markdown]
# ## Time to Visualize Our Two DataFrame Averages
# averages_all_teams
#
# averages_top_teams

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
joined_averages = pd.concat([averages_all_teams.mean(axis = 1), averages_top_teams.mean(axis = 1)], axis=1)
joined_averages.columns = ['All Teams','Top Teams']
joined_averages['% Diff'] = ((1-(joined_averages['All Teams']/joined_averages['Top Teams']))*100).round(0)
joined_averages.sort_values('% Diff', ascending=False, inplace=True)
joined_averages
# Out:
#                     All Teams  Top Teams  % Diff
# sliding_tackle      54.291691  61.423964    12.0
# volleys             53.206841  59.472902    11.0
# interceptions       56.398186  62.852940    10.0
# vision              61.136356  67.147993     9.0
# reactions           69.054530  75.704668     9.0
# marking             52.514383  57.631611     9.0
# standing_tackle     56.939278  62.420254     9.0
# crossing            60.613370  65.845461     8.0
# curve               58.208347  63.180607     8.0
# dribbling           65.820371  71.192884     8.0
# long_shots          58.371223  63.234318     8.0
# long_passing        62.487755  67.886733     8.0
# positioning         60.161136  64.901386     7.0
# potential           75.087780  80.576340     7.0
# overall_rating      71.641976  77.377577     7.0
# short_passing       68.566894  73.919503     7.0
# penalties           57.352501  61.920739     7.0
# finishing           54.171811  58.502461     7.0
# ball_control        69.586031  74.872067     7.0
# sprint_speed        70.414982  74.851716     6.0
# stamina             71.255790  75.471348     6.0
# shot_power          67.137919  71.081630     6.0
# jumping             68.530452  72.664018     6.0
# heading_accuracy    62.693488  66.438682     6.0
# free_kick_accuracy  52.936673  56.502240     6.0
# agility             68.402584  72.635088     6.0
# acceleration        69.819869  73.251036     5.0
# aggression          65.687117  67.693428     3.0
# balance             66.580349  67.866673     2.0
# strength            69.112414  70.619891     2.0
# gk_reflexes         10.568733   9.729643    -9.0
# gk_kicking          10.652687   9.420532   -13.0
# gk_diving           10.611112   9.416557   -13.0
# gk_positioning      10.647019   9.366064   -14.0
# gk_handling         10.682197   9.018719   -18.0

# %%
plt.figure();
joined_averages[['All Teams','Top Teams']].plot(kind='barh', figsize=(10,30));
