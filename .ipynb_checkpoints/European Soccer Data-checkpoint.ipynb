# %% [markdown]
# # Attributes of Winning Teams
# ## Exploring the Data of the EU Soccer League
#
# The goal of this analysis will be to see if there are common attributes amoung the top performing leagues in the European Soccer League. Data is from a Kaggle post,[European Soccer Database](https://www.kaggle.com/hugomathien/soccer) by Hugomathien.
#
# The process of discovery will be the following
# 1. Create SQL Queries to gather/organize original data
#     * Which teams the players belong too (most recent year)
#     * Join the player attributes to those teams (most recent performance scores)
#     * Which teams placed top on the league (most recent year)
# 2. Read the SQL Queries into Pandas for further manipulation
# 3. Provide exploratory visualization showing the combined attributes of each top-performing team
# 4. Make a judgement if there are common attributes that matter most to success

# %% [markdown]
# ## Setting Up Environment
#
# First I want to make sure I have my enviroments set up. I have a work station with three monitors but I am not always there so I want to make sure I can do analysis on the fly on my Chromebook. To do this I have set up a cloud instance with [Amazon SageMaker](https://docs.aws.amazon.com/sagemaker/latest/dg/whatis.html). I started the project on my workstation and then createe my [GitHub Repo](https://github.com/GarrettMarkScott/European_Soccer_Exploring). In the process of doing this I quickly learned that the 300mb database (SQLite) was too large for a simple git push command. This forced me to create a .gitignore file that I placed the database in. I then was able to clone the git repo into my Jupyter Cloud Instance and simply upload the SQLite database into the same directory in my cloud instance. Now I can push/pull from both machines without large file transfers.
#
# I used the below code to check to make sure my environment was working.

# %%
#These are the general items for simple loading

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import itertools
import pprint

pp = pprint.PrettyPrinter(indent=4)

conn = sqlite3.connect('soccer_data.sqlite')
tables = pd.read_sql('SELECT * FROM sqlite_master WHERE type="table";', conn)
countries = pd.read_sql('SELECT * FROM Country;', conn)
players = pd.read_sql('SELECT player_api_id, player_name FROM Player;', conn)
player_att = pd.read_sql('SELECT * FROM Player_Attributes;',conn)
league_teams = pd.read_sql('SELECT team_long_name FROM Team', conn)
player_att.columns.tolist() #I use this line for previewing original data
# Out:
# ['id',
#  'player_fifa_api_id',
#  'player_api_id',
#  'date',
#  'overall_rating',
#  'potential',
#  'preferred_foot',
#  'attacking_work_rate',
#  'defensive_work_rate',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'free_kick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes']

# %% [markdown]
# ## Matching Players to Teams
#
# Next was time to create the SQL queries to organize the raw data a little bit so it was easier to work with. I was able to borrow my girlfriends mac and load the SQLite datebase into [DB Browser for SQLite] for quick SQL Queries (since chromebook can't run programs).
#
# I spent quite a bit of time trying to figure out how to merge the players to teams. As seen in the screenshot below there was not a common key between player and team. My assumption is that this is due to players switching various teams over their career.
#
# ![Table Screenshot](https://i.imgur.com/KCpqgS5.jpg)
#
# I checked the *player_fifa_api_id* but that had 11,060 DISTINCT rows. I was able to create the query below that used the Match table data to see which players were associated with each match. Due to there being substitutions throughout the match, it is assumed that these 11 players are the starting roster for each team during the 2007-2008 season (May-August).
#
# This turned out to be a pretty big challege because I did not relize DB Browser for SQLite seemingly does not have a formal Date type but rather stores date types as a *Timestring* format. If anyone has any information regarding this and how to deal with it in the best/cleanest way I have made a [Stack Overflow Post](https://stackoverflow.com/questions/56202599/converting-timestrings-to-datetime-db-browser)

# %%
#Matches from most recent season and the starting players (in ID format)
#Is there an easy solution to use parameters for date range?
matches = pd.read_sql_query('''SELECT t.team_long_name, m.home_player_1, m.home_player_2, 
                                      m.home_player_3,m.home_player_4, m.home_player_5,
                                      m.home_player_6, m.home_player_7, m.home_player_8,
                                      m.home_player_9, m.home_player_10, m.home_player_11,
                                      m.date, m.home_team_goal, m.away_team_goal 
                                 FROM Team t 
                                 JOIN Match m ON t.team_api_id = m.home_team_api_id 
                                WHERE DATE(m.date) BETWEEN "2015-05-01" and "2016-05-25" 
                                ORDER BY t.team_long_name;''', conn, )
matches
# Out:
#                 team_long_name  home_player_1  home_player_2  home_player_3  \
# 0                   1. FC Köln       212815.0        36395.0        36934.0
# 1                   1. FC Köln       212815.0        36395.0        36934.0
# 2                   1. FC Köln       212815.0       127945.0       231753.0
# 3                   1. FC Köln       212815.0       127945.0        36934.0
# 4                   1. FC Köln       212815.0       127945.0        36934.0
# 5                   1. FC Köln       212815.0       212377.0       231753.0
# 6                   1. FC Köln       212815.0       212377.0        36934.0
# 7                   1. FC Köln       212815.0       212377.0       231753.0
# 8                   1. FC Köln       212815.0        36934.0        28435.0
# 9                   1. FC Köln       212815.0        36934.0        28435.0
# 10                  1. FC Köln       212815.0       231753.0        36934.0
# 11                  1. FC Köln       212815.0       231753.0        36934.0
# 12                  1. FC Köln       212815.0       127945.0        36934.0
# 13                  1. FC Köln       212815.0       212377.0       231753.0
# 14                  1. FC Köln       212815.0       231753.0        36934.0
# 15                  1. FC Köln       212815.0       231753.0        36934.0
# 16                  1. FC Köln       212815.0       212377.0       231753.0
# 17                  1. FC Köln       212815.0       127945.0       231753.0
# 18                  1. FC Köln       212815.0       212377.0       231753.0
# 19             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 20             1. FSV Mainz 05       287894.0        36000.0        36806.0
# 21             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 22             1. FSV Mainz 05       287894.0       147726.0        36000.0
# 23             1. FSV Mainz 05       287894.0        94915.0       147726.0
# 24             1. FSV Mainz 05       287894.0        94915.0       193901.0
# 25             1. FSV Mainz 05       287894.0        94915.0        36000.0
# 26             1. FSV Mainz 05       287894.0        94915.0       147726.0
# 27             1. FSV Mainz 05       287894.0       191080.0       147726.0
# 28             1. FSV Mainz 05       287894.0       191080.0       147726.0
# 29             1. FSV Mainz 05       287894.0       191080.0       147726.0
# ...                        ...            ...            ...            ...
# 3611            Zagłębie Lubin       206641.0       208315.0       118822.0
# 3612            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3613            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3614            Zagłębie Lubin       232143.0        69018.0        72479.0
# 3615            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3616            Zagłębie Lubin       232143.0       208315.0       118822.0
# 3617            Zagłębie Lubin       232143.0        69018.0       208315.0
# 3618            Zagłębie Lubin       232143.0        69018.0        72479.0
# 3619            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3620            Zagłębie Lubin       232143.0        69018.0       118822.0
# 3621            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3622            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3623            Zagłębie Lubin       206641.0        69018.0        72479.0
# 3624  Évian Thonon Gaillard FC       181619.0       179522.0        46708.0
# 3625  Évian Thonon Gaillard FC       181619.0       179891.0        71603.0
# 3626             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3627             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3628             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3629             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3630             Śląsk Wrocław        43313.0        13437.0       172896.0
# 3631             Śląsk Wrocław       463957.0       522276.0        13437.0
# 3632             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3633             Śląsk Wrocław        43313.0        69428.0        13437.0
# 3634             Śląsk Wrocław        43313.0        43317.0        13554.0
# 3635             Śląsk Wrocław       618737.0        13554.0        13437.0
# 3636             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3637             Śląsk Wrocław       618737.0        13554.0        13437.0
# 3638             Śląsk Wrocław        43313.0       522276.0        13437.0
# 3639             Śląsk Wrocław        43313.0        13554.0        13437.0
# 3640             Śląsk Wrocław        43313.0       429914.0        13437.0
#
#       home_player_4  home_player_5  home_player_6  home_player_7  \
# 0          264221.0       307210.0        36086.0       167589.0
# 1          264221.0        22824.0       450976.0        36086.0
# 2          303800.0       307210.0       166449.0        36086.0
# 3          303800.0       307210.0       166449.0        36086.0
# 4          303800.0       307210.0       238438.0        36086.0
# 5           36934.0       303800.0       307210.0       450976.0
# 6          303800.0       307210.0       167589.0        36086.0
# 7          303800.0       307210.0       127945.0       167589.0
# 8          303800.0       127945.0       450976.0       307210.0
# 9          303800.0       127945.0        36086.0       307210.0
# 10         303800.0       307210.0        36086.0       127945.0
# 11          28435.0       303800.0       307210.0       127945.0
# 12         303800.0       307210.0        36086.0       167589.0
# 13         303800.0       307210.0       127945.0        36086.0
# 14          28435.0       259439.0        36086.0       307210.0
# 15          28435.0       303800.0       307210.0       127945.0
# 16         303800.0       307210.0       127945.0        36086.0
# 17         303800.0       307210.0       238438.0        36086.0
# 18         303800.0       307210.0       127945.0       450976.0
# 19         193901.0       171472.0       237542.0        59595.0
# 20         171472.0       130667.0       130118.0       201888.0
# 21         193901.0       171472.0        59595.0        95228.0
# 22         193901.0        49885.0        59595.0       162679.0
# 23          36000.0       171472.0        49885.0       162679.0
# 24         459000.0       171472.0        59595.0       162679.0
# 25         193901.0       171472.0        59595.0       162679.0
# 26         193901.0       426873.0        59595.0       162679.0
# 27         193901.0       426873.0        59595.0       162679.0
# 28          36000.0       426873.0        59595.0        95228.0
# 29         459000.0       426873.0        59595.0        95228.0
# ...             ...            ...            ...            ...
# 3611        72479.0       163618.0       116874.0        69485.0
# 3612       118822.0       163618.0       545056.0        68762.0
# 3613       545060.0       163618.0        68802.0        69485.0
# 3614       545060.0       163618.0       116874.0        68762.0
# 3615        68762.0       163618.0        69485.0       467316.0
# 3616        72479.0       163618.0       197560.0        68762.0
# 3617       118822.0       163618.0       545056.0       197560.0
# 3618       118822.0       163618.0       545056.0        69485.0
# 3619        72479.0       163618.0       545056.0        69485.0
# 3620        72479.0       163618.0        69485.0        68762.0
# 3621       545060.0       163618.0       239253.0        68762.0
# 3622       118822.0       163618.0        68762.0       545056.0
# 3623       118822.0       163618.0        68762.0       545056.0
# 3624        74169.0       610533.0       185000.0        26333.0
# 3625        46708.0        35121.0       185000.0       317062.0
# 3626        13554.0        77778.0        43317.0       179818.0
# 3627       172896.0        13554.0       181227.0        22831.0
# 3628        13554.0        77778.0       172896.0        43317.0
# 3629        13554.0        77778.0       179818.0        43317.0
# 3630        13554.0        77778.0       181227.0        22831.0
# 3631        43317.0        77778.0        69428.0       172896.0
# 3632       436553.0        77778.0       172896.0       181227.0
# 3633       436553.0        77778.0       181227.0        22831.0
# 3634            NaN       436553.0       181227.0       172896.0
# 3635       436553.0       522276.0       176704.0       181227.0
# 3636        43317.0        77778.0       172896.0       181227.0
# 3637       436553.0        77778.0       176704.0       172896.0
# 3638        43317.0        77778.0       179818.0       181227.0
# 3639        43317.0        77778.0       172896.0       181227.0
# 3640        43317.0        13554.0       172896.0       309890.0
#
#       home_player_8  home_player_9  home_player_10  home_player_11  \
# 0          127945.0       459493.0        166449.0        196366.0
# 1          127945.0       459493.0        196366.0        166449.0
# 2          167589.0       459493.0        177941.0         71605.0
# 3          167589.0       260470.0        177941.0         71605.0
# 4          167589.0       260470.0        177941.0         71605.0
# 5           36086.0        22824.0        127945.0        238438.0
# 6          127945.0       166449.0        260470.0         71605.0
# 7           36086.0       260470.0        238438.0         71605.0
# 8          259439.0       238438.0        260470.0         71605.0
# 9          259439.0       450976.0         71605.0        260470.0
# 10         450976.0       260470.0        259439.0         71605.0
# 11          36086.0       450976.0        260470.0         71605.0
# 12         238438.0       260470.0        450976.0         71605.0
# 13         167589.0       260470.0         71605.0        238438.0
# 14         127945.0       166449.0        450976.0         71605.0
# 15         450976.0       260470.0        238438.0         71605.0
# 16         167589.0       260470.0         71605.0        166449.0
# 17         450976.0       260470.0        166449.0         71605.0
# 18         260470.0        36086.0        166449.0         71605.0
# 19         287231.0        22313.0        201888.0         20694.0
# 20         237542.0        59595.0        278863.0         20694.0
# 21         178804.0       278863.0        287231.0        276760.0
# 22         180126.0       278863.0        287231.0        459499.0
# 23         287231.0       278863.0        130118.0        459499.0
# 24         287231.0       278863.0        130118.0        459499.0
# 25         130118.0       278863.0        287231.0        459499.0
# 26         178804.0       278863.0        287231.0        459499.0
# 27         178804.0       278863.0        287231.0        291425.0
# 28         130118.0       278863.0        287231.0        291425.0
# 29         130118.0       278863.0        287231.0        291425.0
# ...             ...            ...             ...             ...
# 3611       545056.0        68802.0        543298.0         25255.0
# 3612       116874.0       239253.0         68802.0         25255.0
# 3613       545056.0       116874.0        543298.0         25255.0
# 3614       239253.0       197560.0        543298.0             NaN
# 3615       197560.0        69818.0         68802.0         25255.0
# 3616       545056.0        68802.0         25255.0        543298.0
# 3617       287341.0       239253.0         68802.0        543298.0
# 3618       116874.0       287341.0         68802.0        543298.0
# 3619        68802.0       287341.0        197560.0        543298.0
# 3620       116874.0       287341.0         68802.0         25255.0
# 3621       116874.0        69818.0         68802.0         25255.0
# 3622       116874.0       239253.0         68802.0         25255.0
# 3623       116874.0       239253.0         68802.0        543298.0
# 3624       400962.0       317062.0        187669.0        210466.0
# 3625       288783.0        92263.0        210466.0        400962.0
# 3626       172896.0        22831.0         69428.0         69256.0
# 3627       179818.0       309890.0         69256.0         93453.0
# 3628       179818.0       309890.0         69256.0         93453.0
# 3629       172896.0        22831.0         69256.0         72458.0
# 3630       522276.0       179818.0        429914.0         69256.0
# 3631       181227.0       429914.0        179818.0         93453.0
# 3632       429914.0       196288.0        167491.0         93453.0
# 3633       176704.0       196288.0        167491.0         93453.0
# 3634       176704.0       196288.0         69256.0         93453.0
# 3635       172896.0        22831.0         69256.0        643982.0
# 3636       179818.0        72458.0        176704.0         93453.0
# 3637       181227.0       429914.0        196288.0        643982.0
# 3638       172896.0        69256.0        176704.0         93453.0
# 3639       179818.0       309890.0        176704.0         93453.0
# 3640       179818.0        22831.0         72458.0         69256.0
#
#                      date  home_team_goal  away_team_goal
# 0     2015-05-10 00:00:00               2               0
# 1     2015-05-23 00:00:00               2               2
# 2     2015-10-31 00:00:00               0               0
# 3     2015-11-21 00:00:00               0               0
# 4     2015-12-05 00:00:00               0               1
# 5     2015-12-19 00:00:00               2               1
# 6     2016-01-23 00:00:00               1               3
# 7     2015-08-22 00:00:00               1               1
# 8     2016-02-13 00:00:00               3               1
# 9     2016-02-26 00:00:00               0               1
# 10    2016-03-05 00:00:00               1               3
# 11    2016-03-19 00:00:00               0               1
# 12    2016-04-10 00:00:00               0               2
# 13    2015-08-29 00:00:00               2               1
# 14    2016-04-23 00:00:00               4               1
# 15    2016-05-07 00:00:00               0               0
# 16    2015-09-19 00:00:00               1               0
# 17    2015-09-25 00:00:00               1               1
# 18    2015-10-18 00:00:00               0               1
# 19    2015-05-03 00:00:00               1               2
# 20    2015-05-16 00:00:00               2               0
# 21    2015-08-15 00:00:00               0               1
# 22    2015-10-24 00:00:00               1               3
# 23    2015-11-07 00:00:00               2               0
# 24    2015-11-28 00:00:00               2               1
# 25    2015-12-11 00:00:00               0               0
# 26    2016-01-29 00:00:00               1               0
# 27    2016-02-12 00:00:00               2               1
# 28    2016-02-28 00:00:00               3               1
# 29    2016-03-06 00:00:00               0               0
# ...                   ...             ...             ...
# 3611  2015-10-24 00:00:00               0               0
# 3612  2015-11-06 00:00:00               1               3
# 3613  2015-12-01 00:00:00               0               2
# 3614  2015-12-04 00:00:00               2               0
# 3615  2015-07-25 00:00:00               0               2
# 3616  2015-12-18 00:00:00               2               4
# 3617  2016-02-21 00:00:00               1               2
# 3618  2016-03-01 00:00:00               1               0
# 3619  2016-03-13 00:00:00               1               1
# 3620  2016-04-03 00:00:00               4               1
# 3621  2015-08-14 00:00:00               2               1
# 3622  2015-08-29 00:00:00               3               1
# 3623  2015-09-18 00:00:00               4               2
# 3624  2015-05-09 00:00:00               2               3
# 3625  2015-05-16 00:00:00               1               2
# 3626  2015-07-19 00:00:00               1               4
# 3627  2015-09-25 00:00:00               1               2
# 3628  2015-10-16 00:00:00               0               1
# 3629  2015-10-31 00:00:00               1               1
# 3630  2015-11-28 00:00:00               0               0
# 3631  2015-12-11 00:00:00               2               1
# 3632  2016-02-12 00:00:00               1               0
# 3633  2016-02-26 00:00:00               0               0
# 3634  2016-03-05 00:00:00               0               2
# 3635  2016-03-19 00:00:00               0               0
# 3636  2015-08-02 00:00:00               2               0
# 3637  2016-04-09 00:00:00               2               1
# 3638  2015-08-09 00:00:00               0               0
# 3639  2015-08-22 00:00:00               1               1
# 3640  2015-09-12 00:00:00               3               1
#
# [3641 rows x 15 columns]

# %% [raw]
# The next step of my process is to create a compound dictionary that has the players as values of the teams and attributues as values of the players. Following that we can begin investigating their attributes!

# %% [markdown]
# ## Create a Function to Connect Player ID to Player Name
# To keep our code modular as possible the function below can be used to return a player's name based on ID input.
#
# The first result **player_api_id** is the test and you will see that it returns **Aaron Appindangoye** correctly.

# %%
players
# Out:
#        player_api_id             player_name
# 0             505942      Aaron Appindangoye
# 1             155782         Aaron Cresswell
# 2             162549             Aaron Doran
# 3              30572           Aaron Galindo
# 4              23780            Aaron Hughes
# 5              27316              Aaron Hunt
# 6             564793              Aaron Kuhl
# 7              30895            Aaron Lennon
# 8             528212            Aaron Lennox
# 9             101042           Aaron Meijers
# 10             23889           Aaron Mokoena
# 11            231592              Aaron Mooy
# 12            163222          Aaron Muirhead
# 13             40719            Aaron Niguez
# 14             75489            Aaron Ramsey
# 15            597948           Aaron Splaine
# 16            161644   Aaron Taylor-Sinclair
# 17             23499         Aaron Wilbraham
# 18            120919       Aatif Chahechouhe
# 19             46447               Abasse Ba
# 20            167027       Abdelaziz Barrada
# 21            245653   Abdelfettah Boukhriss
# 22            128456  Abdelhamid El Kaoutari
# 23             42664      Abdelkader Ghezzal
# 24            425950         Abdellah Zoubir
# 25             38423      Abdelmajid Oulmers
# 26              3264      Abdelmalek Cherrad
# 27            467485  Abdelmalek El Hasnaoui
# 28            306735     Abdelouahed Chakhsi
# 29             41659        Abderrazak Jadid
# ...              ...                     ...
# 11030         244155                 Zezinho
# 11031          19696               Zhi Zheng
# 11032         290868             Zhi-Gin Lam
# 11033         169594             Zie Diabate
# 11034         244953            Ziggy Gordon
# 11035         200607         Ziguy Badibanga
# 11036         642618        Zinedine Machach
# 11037         277772              Zinho Gano
# 11038         246332             Ziri Hammar
# 11039         532766                    Zizo
# 11040          27305       Zlatan Bajramovic
# 11041          35724      Zlatan Ibrahimovic
# 11042          12574      Zlatan Ljubijankic
# 11043          39494            Zlatko Dedic
# 11044          17233           Zlatko Janjic
# 11045          42860        Zlatko Junuzovic
# 11046          37128           Zola Matumona
# 11047          24737             Zoltan Gera
# 11048         107281          Zoltan Stieber
# 11049          39801          Zoltan Szelesi
# 11050         491794         Zoran Josipovic
# 11051          56929          Zoran Rendulic
# 11052          99031             Zoran Tosic
# 11053         192132      Zouhaier Dhaouadhi
# 11054         282473          Zouhair Feddal
# 11055          26357          Zoumana Camara
# 11056         111182            Zsolt Laczko
# 11057          36491               Zsolt Low
# 11058          35506     Zurab Khizanishvili
# 11059          39902      Zvjezdan Misimovic
#
# [11060 rows x 2 columns]

# %%
#Reusable function to translate api key to player name

def player_id_to_name(id): 
    return(players[players['player_api_id'] == id].iloc[0,1])

player_id_to_name(505942)
# Out:
# 'Aaron Appindangoye'

# %% [markdown]
# ## Creating Compound Dictionary of Teams, Players, & Attributes
#
# Build a for loop that builds a teams dictionary with team as the key and players as the values.
#
# This is our goal:
# ```
# teams = {"team 1": {"Player 1": {"Dribbling": 4,
#                                  "Attack": 5,
#                                  "Speed": 9},
#                     "Player 2": {"Dribbling": 6,
#                                  "Attack": 10,
#                                  "Speed": 3},
#                     "Player 3": {"Dribbling": 2,
#                                  "Attack": 5,
#                                  "Speed": 8},
#                     },
#          "team 2": {"Player 1": {"Dribbling": 9,
#                                  "Attack": 6,
#                                  "Speed": 2},
#                     "Player 2": {"Dribbling": 10,
#                                  "Attack": 2,
#                                  "Speed": 8},
#                     "Player 3": {"Dribbling": 5,
#                                  "Attack": 5,
#                                  "Speed": 5},
#                     }
#             }
# ```

# %% [markdown]
# ### Creating dictionary of teams and starting players from most recent season
#
# #### Step 1: Create a list of teams

# %%
#Create a list of the teams to iterate
team_names = league_teams.values.tolist()
merged_team_names = list(itertools.chain(*team_names)) #Flatten list of lists
team_names = merged_team_names
print(len(team_names))
pprint.pprint(team_names)
# Out:
# 299
# ['KRC Genk',
#  'Beerschot AC',
#  'SV Zulte-Waregem',
#  'Sporting Lokeren',
#  'KSV Cercle Brugge',
#  'RSC Anderlecht',
#  'KAA Gent',
#  'RAEC Mons',
#  'FCV Dender EH',
#  'Standard de Liège',
#  'KV Mechelen',
#  'Club Brugge KV',
#  'KSV Roeselare',
#  'KV Kortrijk',
#  'Tubize',
#  'Royal Excel Mouscron',
#  'KVC Westerlo',
#  'Sporting Charleroi',
#  'Sint-Truidense VV',
#  'Lierse SK',
#  'KAS Eupen',
#  'Oud-Heverlee Leuven',
#  'Waasland-Beveren',
#  'KV Oostende',
#  'Royal Excel Mouscron',
#  'Manchester United',
#  'Newcastle United',
#  'Arsenal',
#  'West Bromwich Albion',
#  'Sunderland',
#  'Liverpool',
#  'West Ham United',
#  'Wigan Athletic',
#  'Aston Villa',
#  'Manchester City',
#  'Everton',
#  'Blackburn Rovers',
#  'Middlesbrough',
#  'Tottenham Hotspur',
#  'Bolton Wanderers',
#  'Stoke City',
#  'Hull City',
#  'Fulham',
#  'Chelsea',
#  'Portsmouth',
#  'Birmingham City',
#  'Wolverhampton Wanderers',
#  'Burnley',
#  'Blackpool',
#  'Swansea City',
#  'Queens Park Rangers',
#  'Norwich City',
#  'Southampton',
#  'Reading',
#  'Crystal Palace',
#  'Cardiff City',
#  'Leicester City',
#  'Bournemouth',
#  'Watford',
#  'AJ Auxerre',
#  'FC Nantes',
#  'Girondins de Bordeaux',
#  'SM Caen',
#  'Le Havre AC',
#  'OGC Nice',
#  'Le Mans FC',
#  'FC Lorient',
#  'Olympique Lyonnais',
#  'Toulouse FC',
#  'AS Monaco',
#  'Paris Saint-Germain',
#  'AS Nancy-Lorraine',
#  'LOSC Lille',
#  'Stade Rennais FC',
#  'Olympique de Marseille',
#  'FC Sochaux-Montbéliard',
#  'Grenoble Foot 38',
#  'Valenciennes FC',
#  'AS Saint-Étienne',
#  'RC Lens',
#  'Montpellier Hérault SC',
#  "US Boulogne Cote D'Opale",
#  'AC Arles-Avignon',
#  'Stade Brestois 29',
#  'AC Ajaccio',
#  'Évian Thonon Gaillard FC',
#  'Dijon FCO',
#  'Stade de Reims',
#  'SC Bastia',
#  'ES Troyes AC',
#  'En Avant de Guingamp',
#  'FC Metz',
#  'Angers SCO',
#  'GFC Ajaccio',
#  'FC Bayern Munich',
#  'Hamburger SV',
#  'Bayer 04 Leverkusen',
#  'Borussia Dortmund',
#  'FC Schalke 04',
#  'Hannover 96',
#  'VfL Wolfsburg',
#  '1. FC Köln',
#  'Eintracht Frankfurt',
#  'Hertha BSC Berlin',
#  'DSC Arminia Bielefeld',
#  'SV Werder Bremen',
#  'FC Energie Cottbus',
#  'TSG 1899 Hoffenheim',
#  'Borussia Mönchengladbach',
#  'VfB Stuttgart',
#  'Karlsruher SC',
#  'VfL Bochum',
#  'SC Freiburg',
#  '1. FC Nürnberg',
#  '1. FSV Mainz 05',
#  '1. FC Kaiserslautern',
#  'FC St. Pauli',
#  'FC Augsburg',
#  'Fortuna Düsseldorf',
#  'SpVgg Greuther Fürth',
#  'Eintracht Braunschweig',
#  'SC Paderborn 07',
#  'FC Ingolstadt 04',
#  'SV Darmstadt 98',
#  'Atalanta',
#  'Siena',
#  'Cagliari',
#  'Lazio',
#  'Catania',
#  'Genoa',
#  'Chievo Verona',
#  'Reggio Calabria',
#  'Fiorentina',
#  'Juventus',
#  'Milan',
#  'Bologna',
#  'Roma',
#  'Napoli',
#  'Sampdoria',
#  'Inter',
#  'Torino',
#  'Lecce',
#  'Udinese',
#  'Palermo',
#  'Bari',
#  'Livorno',
#  'Parma',
#  'Cesena',
#  'Brescia',
#  'Novara',
#  'Pescara',
#  'Hellas Verona',
#  'Sassuolo',
#  'Empoli',
#  'Frosinone',
#  'Carpi',
#  'Vitesse',
#  'FC Groningen',
#  'Roda JC Kerkrade',
#  'FC Twente',
#  'Willem II',
#  'Ajax',
#  'N.E.C.',
#  'De Graafschap',
#  'FC Utrecht',
#  'PSV',
#  'Heracles Almelo',
#  'Feyenoord',
#  'Sparta Rotterdam',
#  'ADO Den Haag',
#  'FC Volendam',
#  'SC Heerenveen',
#  'AZ',
#  'NAC Breda',
#  'RKC Waalwijk',
#  'VVV-Venlo',
#  'Excelsior',
#  'PEC Zwolle',
#  'SC Cambuur',
#  'Go Ahead Eagles',
#  'FC Dordrecht',
#  'Wisła Kraków',
#  'Polonia Bytom',
#  'Polonia Bytom',
#  'Ruch Chorzów',
#  'Legia Warszawa',
#  'P. Warszawa',
#  'Śląsk Wrocław',
#  'Lechia Gdańsk',
#  'Widzew Łódź',
#  'Odra Wodzisław',
#  'Lech Poznań',
#  'GKS Bełchatów',
#  'Arka Gdynia',
#  'Jagiellonia Białystok',
#  'Piast Gliwice',
#  'Cracovia',
#  'Korona Kielce',
#  'Zagłębie Lubin',
#  'Widzew Łódź',
#  'Podbeskidzie Bielsko-Biała',
#  'Pogoń Szczecin',
#  'Zawisza Bydgoszcz',
#  'Górnik Łęczna',
#  'Termalica Bruk-Bet Nieciecza',
#  'FC Porto',
#  'CF Os Belenenses',
#  'Sporting CP',
#  'Trofense',
#  'Vitória Guimarães',
#  'Vitória Setúbal',
#  'FC Paços de Ferreira',
#  'SC Braga',
#  'Amadora',
#  'Académica de Coimbra',
#  'Rio Ave FC',
#  'SL Benfica',
#  'Leixões SC',
#  'CD Nacional',
#  'Naval 1° de Maio',
#  'CS Marítimo',
#  'União de Leiria, SAD',
#  'S.C. Olhanense',
#  'Portimonense',
#  'SC Beira Mar',
#  'Feirense',
#  'Gil Vicente FC',
#  'Moreirense FC',
#  'Estoril Praia',
#  'FC Arouca',
#  'FC Penafiel',
#  'Boavista FC',
#  'Uniao da Madeira',
#  'Tondela',
#  'Falkirk',
#  'Rangers',
#  'Heart of Midlothian',
#  'Motherwell',
#  'Kilmarnock',
#  'Hibernian',
#  'Aberdeen',
#  'Inverness Caledonian Thistle',
#  'Celtic',
#  'St. Mirren',
#  'Hamilton Academical FC',
#  'Dundee United',
#  'St. Johnstone FC',
#  'Dunfermline Athletic',
#  'Dundee FC',
#  'Ross County FC',
#  'Partick Thistle F.C.',
#  'Valencia CF',
#  'RCD Mallorca',
#  'CA Osasuna',
#  'Villarreal CF',
#  'RC Deportivo de La Coruña',
#  'Real Madrid CF',
#  'CD Numancia',
#  'FC Barcelona',
#  'Racing Santander',
#  'Sevilla FC',
#  'Real Sporting de Gijón',
#  'Getafe CF',
#  'Real Betis Balompié',
#  'RC Recreativo',
#  'RCD Espanyol',
#  'Real Valladolid',
#  'Athletic Club de Bilbao',
#  'UD Almería',
#  'Atlético Madrid',
#  'Málaga CF',
#  'Xerez Club Deportivo',
#  'Real Zaragoza',
#  'CD Tenerife',
#  'Hércules Club de Fútbol',
#  'Levante UD',
#  'Real Sociedad',
#  'Granada CF',
#  'Rayo Vallecano',
#  'RC Celta de Vigo',
#  'Elche CF',
#  'SD Eibar',
#  'Córdoba CF',
#  'UD Las Palmas',
#  'Grasshopper Club Zürich',
#  'AC Bellinzona',
#  'BSC Young Boys',
#  'FC Basel',
#  'FC Aarau',
#  'FC Sion',
#  'FC Luzern',
#  'FC Vaduz',
#  'Neuchâtel Xamax',
#  'FC Zürich',
#  'FC St. Gallen',
#  'FC Thun',
#  'Servette FC',
#  'FC Lausanne-Sports',
#  'Lugano']

# %% [markdown]
# #### Step 2: Create a function to get each starting player of a team
# *Note the original SQL query already constrained the data to most recent season*

# %%
def get_team_players(x):
    #Gather all the players that have started in the match data. 
    all_team_players = matches[matches['team_long_name'] == x].iloc[:,2:12].values.astype(int).tolist()
    merged_team_players = list(itertools.chain(*all_team_players)) #flattens list of lists
    all_team_players = [] #resets variable for append function below

    #this for loops takes all the players api numbers, flattens to unique numbers, and stores them in variable
    for i in merged_team_players:  
        name = i
        if name not in all_team_players:
            all_team_players.append(name)
        else:
            pass
    return(all_team_players)

print(get_team_players('1. FC Köln'))
# Out:
# [36395, 36934, 264221, 307210, 36086, 167589, 127945, 459493, 166449, 196366, 22824, 450976, 231753, 303800, 177941, 71605, 260470, 238438, 212377, 28435, 259439]

# %% [markdown]
# #### Step 3: Create a dictionary using players as the values of each team
# **Goal:** To create the example dictionary below

# %%
teams = {}
teams['blue'] = {'stevie': {"Dribbling": 4,
                            "Attack": 5,
                            "Speed": 9},
                 'robbie': {"Dribbling": 6,
                            "Attack": 10,
                            "Speed": 3},
                 'joey':   {"Dribbling": 2,
                            "Attack": 5,
                            "Speed": 8}
                }

print('Original Goal')                  
pp.pprint(teams)
print()
# Out:
# Original Goal
# {   'blue': {   'joey': {'Attack': 5, 'Dribbling': 2, 'Speed': 8},
#                 'robbie': {'Attack': 10, 'Dribbling': 6, 'Speed': 3},
#                 'stevie': {'Attack': 5, 'Dribbling': 4, 'Speed': 9}}}

# %% [markdown]
# The code below is how I achieved the goal.
#
# A roadblock I ran into was that my team_names variable was returning single item lists that needed to be converted into a string for itterating.

# %%
#print('The output of team_names[0] is: '+ str(team_names[0])+'\n')
#print('The type of team_names[0] is: '+ str(type(str(team_names)))) #It was a LIST!!!! Now string
#print('The output of get_team_players("KRC Genk") is: \n')
#print(get_team_players('KRC Genk'))

teams = {}
for i in range(len(team_names)):   #Currently only returns first 5
    try:
        player_apis = get_team_players(str(team_names[i])) #Had to convert from list
        player_names = {}
        for api in player_apis:
            player_name = player_id_to_name(api)
            player_names[player_name] = player_att[player_att['player_api_id'] == api].iloc[1,:].transform(dict)
        teams[team_names[i]] = player_names
    except:
        #print('Team had no players registered')
        pass

#pp.pprint(teams)

# %% [markdown]
# **Use the cell below to test different dictionary lookups.**

# %%
teams['Hull City']["Dame N'Doye"]
# Out:
# {'id': 33945,
#  'player_fifa_api_id': 179875,
#  'player_api_id': 101969,
#  'date': '2016-01-21 00:00:00',
#  'overall_rating': 77.0,
#  'potential': 77.0,
#  'preferred_foot': 'right',
#  'attacking_work_rate': 'high',
#  'defensive_work_rate': 'medium',
#  'crossing': 56.0,
#  'finishing': 75.0,
#  'heading_accuracy': 77.0,
#  'short_passing': 63.0,
#  'volleys': 71.0,
#  'dribbling': 74.0,
#  'curve': 69.0,
#  'free_kick_accuracy': 70.0,
#  'long_passing': 38.0,
#  'ball_control': 74.0,
#  'acceleration': 78.0,
#  'sprint_speed': 78.0,
#  'agility': 74.0,
#  'reactions': 75.0,
#  'balance': 56.0,
#  'shot_power': 85.0,
#  'jumping': 70.0,
#  'stamina': 79.0,
#  'strength': 84.0,
#  'long_shots': 74.0,
#  'aggression': 72.0,
#  'interceptions': 40.0,
#  'positioning': 79.0,
#  'vision': 64.0,
#  'penalties': 60.0,
#  'marking': 35.0,
#  'standing_tackle': 38.0,
#  'sliding_tackle': 19.0,
#  'gk_diving': 14.0,
#  'gk_handling': 13.0,
#  'gk_kicking': 9.0,
#  'gk_positioning': 8.0,
#  'gk_reflexes': 16.0}

# %% [markdown]
# # Picking Top Teams
# We now have a nice dictionary of the teams, their registered players, and their attributes. Now let's write a command to discover the team with the most wins. Let's use some visualization to help us determine if we want data from the top 3, top 5, etc. out of the 299 teams.
#
# This should be based on winning percent vs. total sum.

# %%
matches['final_status'] = 'NaN'
matches.head()
# Out:
#   team_long_name  home_player_1  home_player_2  home_player_3  home_player_4  \
# 0     1. FC Köln       212815.0        36395.0        36934.0       264221.0
# 1     1. FC Köln       212815.0        36395.0        36934.0       264221.0
# 2     1. FC Köln       212815.0       127945.0       231753.0       303800.0
# 3     1. FC Köln       212815.0       127945.0        36934.0       303800.0
# 4     1. FC Köln       212815.0       127945.0        36934.0       303800.0
#
#    home_player_5  home_player_6  home_player_7  home_player_8  home_player_9  \
# 0       307210.0        36086.0       167589.0       127945.0       459493.0
# 1        22824.0       450976.0        36086.0       127945.0       459493.0
# 2       307210.0       166449.0        36086.0       167589.0       459493.0
# 3       307210.0       166449.0        36086.0       167589.0       260470.0
# 4       307210.0       238438.0        36086.0       167589.0       260470.0
#
#    home_player_10  home_player_11                 date  home_team_goal  \
# 0        166449.0        196366.0  2015-05-10 00:00:00               2
# 1        196366.0        166449.0  2015-05-23 00:00:00               2
# 2        177941.0         71605.0  2015-10-31 00:00:00               0
# 3        177941.0         71605.0  2015-11-21 00:00:00               0
# 4        177941.0         71605.0  2015-12-05 00:00:00               0
#
#    away_team_goal  points_awarded final_staus final_status
# 0               0               0           a          NaN
# 1               2               0           a          NaN
# 2               0               0           a          NaN
# 3               0               0           a          NaN
# 4               1               0           a          NaN

# %% [markdown]
# The code below appends additional columns. `'final_status'` uses the goal data to determine who won. `'points_awarded'` then delivers a point system for 'win' and 'tie'. This number will be used to determine the top teams.

# %%
matches['final_status'] = "NaN"
matches['points_awarded'] = 0
matches.loc[matches['home_team_goal'] > matches['away_team_goal'], ['final_status','points_awarded']] = ['win',2]
matches.loc[matches['home_team_goal'] == matches['away_team_goal'], ['final_status','points_awarded']] = ['tie',1]
matches.loc[matches['home_team_goal'] < matches['away_team_goal'], 'final_status'] = 'lose'
matches.head(25)
# Out:
#      team_long_name  home_player_1  home_player_2  home_player_3  \
# 0        1. FC Köln       212815.0        36395.0        36934.0
# 1        1. FC Köln       212815.0        36395.0        36934.0
# 2        1. FC Köln       212815.0       127945.0       231753.0
# 3        1. FC Köln       212815.0       127945.0        36934.0
# 4        1. FC Köln       212815.0       127945.0        36934.0
# 5        1. FC Köln       212815.0       212377.0       231753.0
# 6        1. FC Köln       212815.0       212377.0        36934.0
# 7        1. FC Köln       212815.0       212377.0       231753.0
# 8        1. FC Köln       212815.0        36934.0        28435.0
# 9        1. FC Köln       212815.0        36934.0        28435.0
# 10       1. FC Köln       212815.0       231753.0        36934.0
# 11       1. FC Köln       212815.0       231753.0        36934.0
# 12       1. FC Köln       212815.0       127945.0        36934.0
# 13       1. FC Köln       212815.0       212377.0       231753.0
# 14       1. FC Köln       212815.0       231753.0        36934.0
# 15       1. FC Köln       212815.0       231753.0        36934.0
# 16       1. FC Köln       212815.0       212377.0       231753.0
# 17       1. FC Köln       212815.0       127945.0       231753.0
# 18       1. FC Köln       212815.0       212377.0       231753.0
# 19  1. FSV Mainz 05       287894.0        94915.0        36000.0
# 20  1. FSV Mainz 05       287894.0        36000.0        36806.0
# 21  1. FSV Mainz 05       287894.0        94915.0        36000.0
# 22  1. FSV Mainz 05       287894.0       147726.0        36000.0
# 23  1. FSV Mainz 05       287894.0        94915.0       147726.0
# 24  1. FSV Mainz 05       287894.0        94915.0       193901.0
#
#     home_player_4  home_player_5  home_player_6  home_player_7  home_player_8  \
# 0        264221.0       307210.0        36086.0       167589.0       127945.0
# 1        264221.0        22824.0       450976.0        36086.0       127945.0
# 2        303800.0       307210.0       166449.0        36086.0       167589.0
# 3        303800.0       307210.0       166449.0        36086.0       167589.0
# 4        303800.0       307210.0       238438.0        36086.0       167589.0
# 5         36934.0       303800.0       307210.0       450976.0        36086.0
# 6        303800.0       307210.0       167589.0        36086.0       127945.0
# 7        303800.0       307210.0       127945.0       167589.0        36086.0
# 8        303800.0       127945.0       450976.0       307210.0       259439.0
# 9        303800.0       127945.0        36086.0       307210.0       259439.0
# 10       303800.0       307210.0        36086.0       127945.0       450976.0
# 11        28435.0       303800.0       307210.0       127945.0        36086.0
# 12       303800.0       307210.0        36086.0       167589.0       238438.0
# 13       303800.0       307210.0       127945.0        36086.0       167589.0
# 14        28435.0       259439.0        36086.0       307210.0       127945.0
# 15        28435.0       303800.0       307210.0       127945.0       450976.0
# 16       303800.0       307210.0       127945.0        36086.0       167589.0
# 17       303800.0       307210.0       238438.0        36086.0       450976.0
# 18       303800.0       307210.0       127945.0       450976.0       260470.0
# 19       193901.0       171472.0       237542.0        59595.0       287231.0
# 20       171472.0       130667.0       130118.0       201888.0       237542.0
# 21       193901.0       171472.0        59595.0        95228.0       178804.0
# 22       193901.0        49885.0        59595.0       162679.0       180126.0
# 23        36000.0       171472.0        49885.0       162679.0       287231.0
# 24       459000.0       171472.0        59595.0       162679.0       287231.0
#
#     home_player_9  home_player_10  home_player_11                 date  \
# 0        459493.0        166449.0        196366.0  2015-05-10 00:00:00
# 1        459493.0        196366.0        166449.0  2015-05-23 00:00:00
# 2        459493.0        177941.0         71605.0  2015-10-31 00:00:00
# 3        260470.0        177941.0         71605.0  2015-11-21 00:00:00
# 4        260470.0        177941.0         71605.0  2015-12-05 00:00:00
# 5         22824.0        127945.0        238438.0  2015-12-19 00:00:00
# 6        166449.0        260470.0         71605.0  2016-01-23 00:00:00
# 7        260470.0        238438.0         71605.0  2015-08-22 00:00:00
# 8        238438.0        260470.0         71605.0  2016-02-13 00:00:00
# 9        450976.0         71605.0        260470.0  2016-02-26 00:00:00
# 10       260470.0        259439.0         71605.0  2016-03-05 00:00:00
# 11       450976.0        260470.0         71605.0  2016-03-19 00:00:00
# 12       260470.0        450976.0         71605.0  2016-04-10 00:00:00
# 13       260470.0         71605.0        238438.0  2015-08-29 00:00:00
# 14       166449.0        450976.0         71605.0  2016-04-23 00:00:00
# 15       260470.0        238438.0         71605.0  2016-05-07 00:00:00
# 16       260470.0         71605.0        166449.0  2015-09-19 00:00:00
# 17       260470.0        166449.0         71605.0  2015-09-25 00:00:00
# 18        36086.0        166449.0         71605.0  2015-10-18 00:00:00
# 19        22313.0        201888.0         20694.0  2015-05-03 00:00:00
# 20        59595.0        278863.0         20694.0  2015-05-16 00:00:00
# 21       278863.0        287231.0        276760.0  2015-08-15 00:00:00
# 22       278863.0        287231.0        459499.0  2015-10-24 00:00:00
# 23       278863.0        130118.0        459499.0  2015-11-07 00:00:00
# 24       278863.0        130118.0        459499.0  2015-11-28 00:00:00
#
#     home_team_goal  away_team_goal final_status  points_awarded
# 0                2               0          win               2
# 1                2               2          tie               1
# 2                0               0          tie               1
# 3                0               0          tie               1
# 4                0               1         lose               0
# 5                2               1          win               2
# 6                1               3         lose               0
# 7                1               1          tie               1
# 8                3               1          win               2
# 9                0               1         lose               0
# 10               1               3         lose               0
# 11               0               1         lose               0
# 12               0               2         lose               0
# 13               2               1          win               2
# 14               4               1          win               2
# 15               0               0          tie               1
# 16               1               0          win               2
# 17               1               1          tie               1
# 18               0               1         lose               0
# 19               1               2         lose               0
# 20               2               0          win               2
# 21               0               1         lose               0
# 22               1               3         lose               0
# 23               2               0          win               2
# 24               2               1          win               2

# %% [markdown]
# Now that we have the points for each team. The next step is to figure out how many games they each played.

# %%
data = {'team_name': matches.groupby(['team_long_name']),
        'games_played': matches.groupby(['team_long_name'])['date'].count().values.tolist(),
       }
matches.groupby(['team_long_name'])

# %% [markdown]
# ### Create Team Points

# %%
team_points = matches.groupby(['team_long_name']).sum()[['points_awarded']]
#team_points

# %% [markdown]
# ### Create Games Played

# %%
team_games_played = matches.groupby(['team_long_name']).count()[['date']]
team_games_played.rename(columns={'date':'games_played'}, inplace=True) #proper rename
#team_games_played

# %% [markdown]
# ### Create Performance Score Column
#
# This is a custom agregation that originally assined 2 points/win and 1 point/tie. Some teams played more games than others in the season so using a total sum would not be accurate. The underlaying of `performance_score` is the percent of `'points_awarded' / 'games_played'` then simplifies the data by transforming it into an number.

# %%
team_totals = team_games_played.merge(team_points, on=('team_long_name'))
team_totals['performance_score'] = ((team_totals['points_awarded'] / team_totals['games_played'])*100).astype(int)
team_totals.sort_values('performance_score', ascending=False)
# Out:
#                           games_played  points_awarded  performance_score
# team_long_name
# FC Dordrecht                         1               2                200
# Queens Park Rangers                  1               2                200
# St. Mirren                           1               2                200
# Club Brugge KV                      15              28                186
# Napoli                              21              39                185
# Borussia Dortmund                   19              35                184
# SL Benfica                          19              34                178
# Paris Saint-Germain                 21              37                176
# Juventus                            21              37                176
# Piast Gliwice                       15              26                173
# FC Bayern Munich                    19              33                173
# Sporting CP                         19              33                173
# PSV                                 18              31                172
# Ajax                                18              31                172
# FC Barcelona                        21              36                171
# Real Madrid CF                      21              36                171
# Celtic                              21              36                171
# RSC Anderlecht                      15              25                166
# FC Basel                            21              35                166
# Leicester City                      22              36                163
# Atlético Madrid                     21              34                161
# KAA Gent                            15              24                160
# Roma                                22              35                159
# FC Porto                            19              30                157
# KRC Genk                            15              23                153
# Villarreal CF                       21              32                152
# BSC Young Boys                      21              32                152
# Borussia Mönchengladbach            19              29                152
# Fiorentina                          22              33                150
# FC Penafiel                          2               3                150
# ...                                ...             ...                ...
# Hellas Verona                       22              17                 77
# Willem II                           18              14                 77
# Palermo                             21              16                 76
# Udinese                             21              16                 76
# Royal Excel Mouscron                15              11                 73
# Moreirense FC                       19              14                 73
# Korona Kielce                       15              11                 73
# Sporting Lokeren                    15              11                 73
# Excelsior                           18              13                 72
# Roda JC Kerkrade                    17              12                 70
# De Graafschap                       17              12                 70
# FC Augsburg                         19              13                 68
# Dundee United                       21              14                 66
# Aston Villa                         22              13                 59
# Tondela                             17              10                 58
# SV Darmstadt 98                     17              10                 58
# Kilmarnock                          21              12                 57
# Hannover 96                         19              11                 57
# SC Cambuur                          18               9                 50
# ES Troyes AC                        19               9                 47
# UD Almería                           3               1                 33
# Hull City                            3               1                 33
# Évian Thonon Gaillard FC             2               0                  0
# Elche CF                             1               0                  0
# NAC Breda                            1               0                  0
# Gil Vicente FC                       2               0                  0
# SC Paderborn 07                      2               0                  0
# FC Metz                              3               0                  0
# Cesena                               2               0                  0
# Córdoba CF                           2               0                  0
#
# [209 rows x 3 columns]

# %% [markdown]
# Some of the teams have very little recorded data so they will not be considered for our top teams. As a rather barbaric quality test I googled a couple of the top teams to see if they are still top placers (since data is from 2016). An example is that Napoli is currently 2nd in the Italian league (05/25/19). I will consider our `'performance_score'` number as an accurate indicator and continue moving forward.
#
# Two key variables that have been created are:
# * Teams (with players & attributes)
# * Team_Totals (indicating top teams)

# %%
teams['Napoli']['Christian Maggio']['crossing']
# Out:
# 79.0

# %%
fake = list(teams.keys())[22]
print(fake)
print(len(teams[fake]))
teams[fake]
# Out:
# KV Oostende
# 15
# {'Brecht Capon': {'id': 23158,
#   'player_fifa_api_id': 179811,
#   'player_api_id': 95615,
#   'date': '2016-03-24 00:00:00',
#   'overall_rating': 69.0,
#   'potential': 70.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'medium',
#   'crossing': 67.0,
#   'finishing': 64.0,
#   'heading_accuracy': 59.0,
#   'short_passing': 66.0,
#   'volleys': 61.0,
#   'dribbling': 66.0,
#   'curve': 60.0,
#   'free_kick_accuracy': 64.0,
#   'long_passing': 62.0,
#   'ball_control': 64.0,
#   'acceleration': 73.0,
#   'sprint_speed': 74.0,
#   'agility': 78.0,
#   'reactions': 68.0,
#   'balance': 74.0,
#   'shot_power': 62.0,
#   'jumping': 77.0,
#   'stamina': 78.0,
#   'strength': 64.0,
#   'long_shots': 63.0,
#   'aggression': 64.0,
#   'interceptions': 67.0,
#   'positioning': 66.0,
#   'vision': 66.0,
#   'penalties': 65.0,
#   'marking': 73.0,
#   'standing_tackle': 69.0,
#   'sliding_tackle': 67.0,
#   'gk_diving': 13.0,
#   'gk_handling': 15.0,
#   'gk_kicking': 9.0,
#   'gk_positioning': 16.0,
#   'gk_reflexes': 14.0},
#  'Antonio Milic': {'id': 15715,
#   'player_fifa_api_id': 226518,
#   'player_api_id': 298941,
#   'date': '2015-09-21 00:00:00',
#   'overall_rating': 68.0,
#   'potential': 76.0,
#   'preferred_foot': 'left',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'medium',
#   'crossing': 58.0,
#   'finishing': 34.0,
#   'heading_accuracy': 70.0,
#   'short_passing': 65.0,
#   'volleys': 37.0,
#   'dribbling': 46.0,
#   'curve': 36.0,
#   'free_kick_accuracy': 41.0,
#   'long_passing': 63.0,
#   'ball_control': 61.0,
#   'acceleration': 44.0,
#   'sprint_speed': 48.0,
#   'agility': 46.0,
#   'reactions': 66.0,
#   'balance': 44.0,
#   'shot_power': 57.0,
#   'jumping': 69.0,
#   'stamina': 69.0,
#   'strength': 76.0,
#   'long_shots': 42.0,
#   'aggression': 68.0,
#   'interceptions': 67.0,
#   'positioning': 42.0,
#   'vision': 54.0,
#   'penalties': 43.0,
#   'marking': 68.0,
#   'standing_tackle': 70.0,
#   'sliding_tackle': 66.0,
#   'gk_diving': 11.0,
#   'gk_handling': 8.0,
#   'gk_kicking': 8.0,
#   'gk_positioning': 11.0,
#   'gk_reflexes': 10.0},
#  'David Rozehnal': {'id': 40385,
#   'player_fifa_api_id': 138468,
#   'player_api_id': 30918,
#   'date': '2016-03-24 00:00:00',
#   'overall_rating': 74.0,
#   'potential': 74.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'low',
#   'defensive_work_rate': 'medium',
#   'crossing': 45.0,
#   'finishing': 29.0,
#   'heading_accuracy': 76.0,
#   'short_passing': 74.0,
#   'volleys': 33.0,
#   'dribbling': 38.0,
#   'curve': 36.0,
#   'free_kick_accuracy': 40.0,
#   'long_passing': 76.0,
#   'ball_control': 61.0,
#   'acceleration': 34.0,
#   'sprint_speed': 37.0,
#   'agility': 30.0,
#   'reactions': 71.0,
#   'balance': 45.0,
#   'shot_power': 65.0,
#   'jumping': 48.0,
#   'stamina': 69.0,
#   'strength': 77.0,
#   'long_shots': 55.0,
#   'aggression': 67.0,
#   'interceptions': 79.0,
#   'positioning': 23.0,
#   'vision': 54.0,
#   'penalties': 41.0,
#   'marking': 79.0,
#   'standing_tackle': 78.0,
#   'sliding_tackle': 75.0,
#   'gk_diving': 9.0,
#   'gk_handling': 9.0,
#   'gk_kicking': 16.0,
#   'gk_positioning': 11.0,
#   'gk_reflexes': 14.0},
#  'Jordan Lukaku': {'id': 86957,
#   'player_fifa_api_id': 207537,
#   'player_api_id': 173462,
#   'date': '2016-04-14 00:00:00',
#   'overall_rating': 72.0,
#   'potential': 80.0,
#   'preferred_foot': 'left',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'medium',
#   'crossing': 70.0,
#   'finishing': 54.0,
#   'heading_accuracy': 62.0,
#   'short_passing': 65.0,
#   'volleys': 57.0,
#   'dribbling': 74.0,
#   'curve': 53.0,
#   'free_kick_accuracy': 46.0,
#   'long_passing': 64.0,
#   'ball_control': 72.0,
#   'acceleration': 85.0,
#   'sprint_speed': 87.0,
#   'agility': 75.0,
#   'reactions': 74.0,
#   'balance': 74.0,
#   'shot_power': 68.0,
#   'jumping': 85.0,
#   'stamina': 79.0,
#   'strength': 83.0,
#   'long_shots': 56.0,
#   'aggression': 74.0,
#   'interceptions': 64.0,
#   'positioning': 61.0,
#   'vision': 66.0,
#   'penalties': 53.0,
#   'marking': 66.0,
#   'standing_tackle': 72.0,
#   'sliding_tackle': 71.0,
#   'gk_diving': 8.0,
#   'gk_handling': 7.0,
#   'gk_kicking': 14.0,
#   'gk_positioning': 15.0,
#   'gk_reflexes': 9.0},
#  'Andile Jali': {'id': 10549,
#   'player_fifa_api_id': 193234,
#   'player_api_id': 201811,
#   'date': '2016-04-21 00:00:00',
#   'overall_rating': 72.0,
#   'potential': 74.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'high',
#   'crossing': 66.0,
#   'finishing': 46.0,
#   'heading_accuracy': 42.0,
#   'short_passing': 75.0,
#   'volleys': 52.0,
#   'dribbling': 73.0,
#   'curve': 66.0,
#   'free_kick_accuracy': 68.0,
#   'long_passing': 73.0,
#   'ball_control': 75.0,
#   'acceleration': 75.0,
#   'sprint_speed': 73.0,
#   'agility': 73.0,
#   'reactions': 73.0,
#   'balance': 81.0,
#   'shot_power': 60.0,
#   'jumping': 81.0,
#   'stamina': 80.0,
#   'strength': 62.0,
#   'long_shots': 70.0,
#   'aggression': 67.0,
#   'interceptions': 75.0,
#   'positioning': 63.0,
#   'vision': 67.0,
#   'penalties': 67.0,
#   'marking': 69.0,
#   'standing_tackle': 73.0,
#   'sliding_tackle': 52.0,
#   'gk_diving': 14.0,
#   'gk_handling': 7.0,
#   'gk_kicking': 12.0,
#   'gk_positioning': 13.0,
#   'gk_reflexes': 15.0},
#  'Michiel Jonckheere': {'id': 124808,
#   'player_fifa_api_id': 199277,
#   'player_api_id': 208985,
#   'date': '2016-02-18 00:00:00',
#   'overall_rating': 66.0,
#   'potential': 67.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'high',
#   'crossing': 64.0,
#   'finishing': 57.0,
#   'heading_accuracy': 51.0,
#   'short_passing': 67.0,
#   'volleys': 67.0,
#   'dribbling': 65.0,
#   'curve': 62.0,
#   'free_kick_accuracy': 61.0,
#   'long_passing': 68.0,
#   'ball_control': 67.0,
#   'acceleration': 65.0,
#   'sprint_speed': 67.0,
#   'agility': 72.0,
#   'reactions': 65.0,
#   'balance': 72.0,
#   'shot_power': 66.0,
#   'jumping': 61.0,
#   'stamina': 73.0,
#   'strength': 49.0,
#   'long_shots': 64.0,
#   'aggression': 61.0,
#   'interceptions': 60.0,
#   'positioning': 64.0,
#   'vision': 67.0,
#   'penalties': 55.0,
#   'marking': 47.0,
#   'standing_tackle': 48.0,
#   'sliding_tackle': 44.0,
#   'gk_diving': 16.0,
#   'gk_handling': 8.0,
#   'gk_kicking': 14.0,
#   'gk_positioning': 12.0,
#   'gk_reflexes': 11.0},
#  'Sebastien Siani': {'id': 160119,
#   'player_fifa_api_id': 175896,
#   'player_api_id': 38365,
#   'date': '2016-03-10 00:00:00',
#   'overall_rating': 70.0,
#   'potential': 70.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'medium',
#   'crossing': 66.0,
#   'finishing': 61.0,
#   'heading_accuracy': 65.0,
#   'short_passing': 72.0,
#   'volleys': 57.0,
#   'dribbling': 68.0,
#   'curve': 68.0,
#   'free_kick_accuracy': 71.0,
#   'long_passing': 69.0,
#   'ball_control': 71.0,
#   'acceleration': 73.0,
#   'sprint_speed': 66.0,
#   'agility': 78.0,
#   'reactions': 72.0,
#   'balance': 77.0,
#   'shot_power': 76.0,
#   'jumping': 77.0,
#   'stamina': 78.0,
#   'strength': 70.0,
#   'long_shots': 66.0,
#   'aggression': 64.0,
#   'interceptions': 73.0,
#   'positioning': 63.0,
#   'vision': 66.0,
#   'penalties': 84.0,
#   'marking': 63.0,
#   'standing_tackle': 69.0,
#   'sliding_tackle': 65.0,
#   'gk_diving': 9.0,
#   'gk_handling': 9.0,
#   'gk_kicking': 6.0,
#   'gk_positioning': 10.0,
#   'gk_reflexes': 11.0},
#  'Fernando Canesin Matos': {'id': 55496,
#   'player_fifa_api_id': 199651,
#   'player_api_id': 265123,
#   'date': '2016-03-24 00:00:00',
#   'overall_rating': 72.0,
#   'potential': 76.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'medium',
#   'crossing': 64.0,
#   'finishing': 59.0,
#   'heading_accuracy': 47.0,
#   'short_passing': 68.0,
#   'volleys': 66.0,
#   'dribbling': 78.0,
#   'curve': 67.0,
#   'free_kick_accuracy': 61.0,
#   'long_passing': 65.0,
#   'ball_control': 76.0,
#   'acceleration': 83.0,
#   'sprint_speed': 81.0,
#   'agility': 82.0,
#   'reactions': 70.0,
#   'balance': 76.0,
#   'shot_power': 62.0,
#   'jumping': 60.0,
#   'stamina': 78.0,
#   'strength': 53.0,
#   'long_shots': 63.0,
#   'aggression': 52.0,
#   'interceptions': 39.0,
#   'positioning': 71.0,
#   'vision': 70.0,
#   'penalties': 63.0,
#   'marking': 23.0,
#   'standing_tackle': 29.0,
#   'sliding_tackle': 27.0,
#   'gk_diving': 16.0,
#   'gk_handling': 10.0,
#   'gk_kicking': 13.0,
#   'gk_positioning': 11.0,
#   'gk_reflexes': 11.0},
#  'Gohi Bi Cyriac': {'id': 65408,
#   'player_fifa_api_id': 191034,
#   'player_api_id': 166302,
#   'date': '2015-12-10 00:00:00',
#   'overall_rating': 72.0,
#   'potential': 74.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'medium',
#   'crossing': 65.0,
#   'finishing': 78.0,
#   'heading_accuracy': 67.0,
#   'short_passing': 68.0,
#   'volleys': 66.0,
#   'dribbling': 72.0,
#   'curve': 58.0,
#   'free_kick_accuracy': 60.0,
#   'long_passing': 44.0,
#   'ball_control': 71.0,
#   'acceleration': 84.0,
#   'sprint_speed': 85.0,
#   'agility': 88.0,
#   'reactions': 70.0,
#   'balance': 80.0,
#   'shot_power': 70.0,
#   'jumping': 91.0,
#   'stamina': 69.0,
#   'strength': 61.0,
#   'long_shots': 72.0,
#   'aggression': 48.0,
#   'interceptions': 24.0,
#   'positioning': 72.0,
#   'vision': 65.0,
#   'penalties': 69.0,
#   'marking': 13.0,
#   'standing_tackle': 28.0,
#   'sliding_tackle': 26.0,
#   'gk_diving': 15.0,
#   'gk_handling': 14.0,
#   'gk_kicking': 8.0,
#   'gk_positioning': 12.0,
#   'gk_reflexes': 11.0},
#  'Knowledge Musona': {'id': 97223,
#   'player_fifa_api_id': 194171,
#   'player_api_id': 206182,
#   'date': '2015-12-10 00:00:00',
#   'overall_rating': 71.0,
#   'potential': 73.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'low',
#   'crossing': 65.0,
#   'finishing': 75.0,
#   'heading_accuracy': 64.0,
#   'short_passing': 68.0,
#   'volleys': 70.0,
#   'dribbling': 76.0,
#   'curve': 69.0,
#   'free_kick_accuracy': 67.0,
#   'long_passing': 58.0,
#   'ball_control': 74.0,
#   'acceleration': 79.0,
#   'sprint_speed': 77.0,
#   'agility': 84.0,
#   'reactions': 74.0,
#   'balance': 84.0,
#   'shot_power': 74.0,
#   'jumping': 77.0,
#   'stamina': 70.0,
#   'strength': 44.0,
#   'long_shots': 71.0,
#   'aggression': 49.0,
#   'interceptions': 25.0,
#   'positioning': 71.0,
#   'vision': 63.0,
#   'penalties': 73.0,
#   'marking': 36.0,
#   'standing_tackle': 33.0,
#   'sliding_tackle': 35.0,
#   'gk_diving': 6.0,
#   'gk_handling': 7.0,
#   'gk_kicking': 8.0,
#   'gk_positioning': 15.0,
#   'gk_reflexes': 12.0},
#  'Franck Berrier': {'id': 58605,
#   'player_fifa_api_id': 163429,
#   'player_api_id': 131531,
#   'date': '2015-09-21 00:00:00',
#   'overall_rating': 73.0,
#   'potential': 73.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'low',
#   'crossing': 74.0,
#   'finishing': 64.0,
#   'heading_accuracy': 35.0,
#   'short_passing': 78.0,
#   'volleys': 64.0,
#   'dribbling': 67.0,
#   'curve': 73.0,
#   'free_kick_accuracy': 71.0,
#   'long_passing': 76.0,
#   'ball_control': 73.0,
#   'acceleration': 61.0,
#   'sprint_speed': 60.0,
#   'agility': 69.0,
#   'reactions': 71.0,
#   'balance': 77.0,
#   'shot_power': 66.0,
#   'jumping': 59.0,
#   'stamina': 62.0,
#   'strength': 45.0,
#   'long_shots': 72.0,
#   'aggression': 37.0,
#   'interceptions': 52.0,
#   'positioning': 72.0,
#   'vision': 82.0,
#   'penalties': 72.0,
#   'marking': 22.0,
#   'standing_tackle': 33.0,
#   'sliding_tackle': 30.0,
#   'gk_diving': 8.0,
#   'gk_handling': 10.0,
#   'gk_kicking': 11.0,
#   'gk_positioning': 10.0,
#   'gk_reflexes': 11.0},
#  'Kevin Vandendriessche': {'id': 96282,
#   'player_fifa_api_id': 223223,
#   'player_api_id': 418105,
#   'date': '2016-03-31 00:00:00',
#   'overall_rating': 69.0,
#   'potential': 70.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'high',
#   'crossing': 62.0,
#   'finishing': 63.0,
#   'heading_accuracy': 68.0,
#   'short_passing': 69.0,
#   'volleys': 66.0,
#   'dribbling': 60.0,
#   'curve': 42.0,
#   'free_kick_accuracy': 51.0,
#   'long_passing': 67.0,
#   'ball_control': 65.0,
#   'acceleration': 67.0,
#   'sprint_speed': 65.0,
#   'agility': 55.0,
#   'reactions': 67.0,
#   'balance': 53.0,
#   'shot_power': 80.0,
#   'jumping': 64.0,
#   'stamina': 92.0,
#   'strength': 87.0,
#   'long_shots': 67.0,
#   'aggression': 80.0,
#   'interceptions': 68.0,
#   'positioning': 74.0,
#   'vision': 69.0,
#   'penalties': 52.0,
#   'marking': 59.0,
#   'standing_tackle': 68.0,
#   'sliding_tackle': 64.0,
#   'gk_diving': 9.0,
#   'gk_handling': 9.0,
#   'gk_kicking': 14.0,
#   'gk_positioning': 10.0,
#   'gk_reflexes': 14.0},
#  'Joseph Akpala': {'id': 89292,
#   'player_fifa_api_id': 176038,
#   'player_api_id': 38440,
#   'date': '2016-03-24 00:00:00',
#   'overall_rating': 70.0,
#   'potential': 70.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'high',
#   'defensive_work_rate': 'medium',
#   'crossing': 53.0,
#   'finishing': 72.0,
#   'heading_accuracy': 69.0,
#   'short_passing': 62.0,
#   'volleys': 66.0,
#   'dribbling': 62.0,
#   'curve': 33.0,
#   'free_kick_accuracy': 49.0,
#   'long_passing': 43.0,
#   'ball_control': 57.0,
#   'acceleration': 77.0,
#   'sprint_speed': 78.0,
#   'agility': 62.0,
#   'reactions': 70.0,
#   'balance': 65.0,
#   'shot_power': 78.0,
#   'jumping': 85.0,
#   'stamina': 76.0,
#   'strength': 77.0,
#   'long_shots': 67.0,
#   'aggression': 73.0,
#   'interceptions': 32.0,
#   'positioning': 71.0,
#   'vision': 65.0,
#   'penalties': 66.0,
#   'marking': 26.0,
#   'standing_tackle': 42.0,
#   'sliding_tackle': 36.0,
#   'gk_diving': 12.0,
#   'gk_handling': 13.0,
#   'gk_kicking': 8.0,
#   'gk_positioning': 8.0,
#   'gk_reflexes': 8.0},
#  'Fredric Brillant': {'id': 59913,
#   'player_fifa_api_id': 208521,
#   'player_api_id': 149334,
#   'date': '2016-03-17 00:00:00',
#   'overall_rating': 67.0,
#   'potential': 67.0,
#   'preferred_foot': 'right',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'medium',
#   'crossing': 32.0,
#   'finishing': 24.0,
#   'heading_accuracy': 70.0,
#   'short_passing': 55.0,
#   'volleys': 22.0,
#   'dribbling': 27.0,
#   'curve': 23.0,
#   'free_kick_accuracy': 35.0,
#   'long_passing': 52.0,
#   'ball_control': 43.0,
#   'acceleration': 43.0,
#   'sprint_speed': 54.0,
#   'agility': 45.0,
#   'reactions': 62.0,
#   'balance': 41.0,
#   'shot_power': 58.0,
#   'jumping': 58.0,
#   'stamina': 65.0,
#   'strength': 75.0,
#   'long_shots': 25.0,
#   'aggression': 74.0,
#   'interceptions': 65.0,
#   'positioning': 39.0,
#   'vision': 48.0,
#   'penalties': 58.0,
#   'marking': 71.0,
#   'standing_tackle': 71.0,
#   'sliding_tackle': 65.0,
#   'gk_diving': 12.0,
#   'gk_handling': 14.0,
#   'gk_kicking': 13.0,
#   'gk_positioning': 15.0,
#   'gk_reflexes': 10.0},
#  'Bruno Godeau': {'id': 23895,
#   'player_fifa_api_id': 210361,
#   'player_api_id': 346111,
#   'date': '2016-02-04 00:00:00',
#   'overall_rating': 66.0,
#   'potential': 70.0,
#   'preferred_foot': 'left',
#   'attacking_work_rate': 'medium',
#   'defensive_work_rate': 'medium',
#   'crossing': 62.0,
#   'finishing': 29.0,
#   'heading_accuracy': 68.0,
#   'short_passing': 63.0,
#   'volleys': 27.0,
#   'dribbling': 43.0,
#   'curve': 32.0,
#   'free_kick_accuracy': 38.0,
#   'long_passing': 53.0,
#   'ball_control': 61.0,
#   'acceleration': 53.0,
#   'sprint_speed': 57.0,
#   'agility': 55.0,
#   'reactions': 63.0,
#   'balance': 57.0,
#   'shot_power': 56.0,
#   'jumping': 60.0,
#   'stamina': 67.0,
#   'strength': 69.0,
#   'long_shots': 32.0,
#   'aggression': 65.0,
#   'interceptions': 64.0,
#   'positioning': 28.0,
#   'vision': 46.0,
#   'penalties': 35.0,
#   'marking': 67.0,
#   'standing_tackle': 70.0,
#   'sliding_tackle': 66.0,
#   'gk_diving': 14.0,
#   'gk_handling': 11.0,
#   'gk_kicking': 7.0,
#   'gk_positioning': 9.0,
#   'gk_reflexes': 10.0}}

# %%
team_player_count = 0
while team_player_count = 0 
    for i in range(len(teams.keys())):
        team_player_count = len(teams[list(teams.keys())[i]])
        break
print(team_player_count)
# Out:
# 22

# %%
def recursive_items(teams):
    for key, value in teams.items():
        if type(value) is dict:
            yield from recursive_items(value)
        else:
            yield (key, value)
a
a = {'a': {1: {1: 2, 3: 4}, 2: {5: 6}}}
# Out:
# id 29390
# player_fifa_api_id 149184
# player_api_id 39535
# date 2016-04-21 00:00:00
# overall_rating 75.0
# potential 75.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 79.0
# finishing 67.0
# heading_accuracy 77.0
# short_passing 76.0
# volleys 79.0
# dribbling 73.0
# curve 72.0
# free_kick_accuracy 55.0
# long_passing 74.0
# ball_control 78.0
# acceleration 78.0
# sprint_speed 79.0
# agility 74.0
# reactions 76.0
# balance 67.0
# shot_power 78.0
# jumping 91.0
# stamina 79.0
# strength 78.0
# long_shots 71.0
# aggression 73.0
# interceptions 67.0
# positioning 74.0
# vision 58.0
# penalties 57.0
# marking 65.0
# standing_tackle 77.0
# sliding_tackle 77.0
# gk_diving 9.0
# gk_handling 5.0
# gk_kicking 9.0
# gk_positioning 11.0
# gk_reflexes 9.0
# id 146907
# player_fifa_api_id 157481
# player_api_id 34029
# date 2016-03-24 00:00:00
# overall_rating 81.0
# potential 81.0
# preferred_foot right
# attacking_work_rate low
# defensive_work_rate medium
# crossing 38.0
# finishing 27.0
# heading_accuracy 77.0
# short_passing 71.0
# volleys 31.0
# dribbling 54.0
# curve 53.0
# free_kick_accuracy 45.0
# long_passing 65.0
# ball_control 66.0
# acceleration 60.0
# sprint_speed 62.0
# agility 55.0
# reactions 78.0
# balance 56.0
# shot_power 65.0
# jumping 77.0
# stamina 62.0
# strength 82.0
# long_shots 53.0
# aggression 79.0
# interceptions 84.0
# positioning 30.0
# vision 49.0
# penalties 37.0
# marking 85.0
# standing_tackle 86.0
# sliding_tackle 82.0
# gk_diving 8.0
# gk_handling 6.0
# gk_kicking 5.0
# gk_positioning 9.0
# gk_reflexes 8.0
# id 125179
# player_fifa_api_id 189067
# player_api_id 114769
# date 2015-09-21 00:00:00
# overall_rating 74.0
# potential 74.0
# preferred_foot left
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 43.0
# finishing 37.0
# heading_accuracy 74.0
# short_passing 60.0
# volleys 22.0
# dribbling 47.0
# curve 47.0
# free_kick_accuracy 52.0
# long_passing 64.0
# ball_control 58.0
# acceleration 56.0
# sprint_speed 55.0
# agility 49.0
# reactions 66.0
# balance 54.0
# shot_power 30.0
# jumping 83.0
# stamina 61.0
# strength 79.0
# long_shots 31.0
# aggression 76.0
# interceptions 75.0
# positioning 24.0
# vision 31.0
# penalties 51.0
# marking 77.0
# standing_tackle 79.0
# sliding_tackle 76.0
# gk_diving 12.0
# gk_handling 13.0
# gk_kicking 11.0
# gk_positioning 10.0
# gk_reflexes 11.0
# id 53990
# player_fifa_api_id 201454
# player_api_id 187017
# date 2016-04-21 00:00:00
# overall_rating 78.0
# potential 81.0
# preferred_foot left
# attacking_work_rate high
# defensive_work_rate medium
# crossing 80.0
# finishing 54.0
# heading_accuracy 70.0
# short_passing 74.0
# volleys 52.0
# dribbling 74.0
# curve 73.0
# free_kick_accuracy 68.0
# long_passing 70.0
# ball_control 75.0
# acceleration 77.0
# sprint_speed 84.0
# agility 69.0
# reactions 78.0
# balance 62.0
# shot_power 80.0
# jumping 73.0
# stamina 86.0
# strength 75.0
# long_shots 69.0
# aggression 74.0
# interceptions 74.0
# positioning 64.0
# vision 58.0
# penalties 76.0
# marking 74.0
# standing_tackle 79.0
# sliding_tackle 78.0
# gk_diving 12.0
# gk_handling 7.0
# gk_kicking 8.0
# gk_positioning 8.0
# gk_reflexes 13.0
# id 87807
# player_fifa_api_id 205498
# player_api_id 282775
# date 2016-04-21 00:00:00
# overall_rating 79.0
# potential 83.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 70.0
# finishing 57.0
# heading_accuracy 56.0
# short_passing 85.0
# volleys 71.0
# dribbling 71.0
# curve 75.0
# free_kick_accuracy 76.0
# long_passing 82.0
# ball_control 82.0
# acceleration 77.0
# sprint_speed 77.0
# agility 82.0
# reactions 80.0
# balance 74.0
# shot_power 71.0
# jumping 61.0
# stamina 79.0
# strength 58.0
# long_shots 62.0
# aggression 78.0
# interceptions 78.0
# positioning 72.0
# vision 82.0
# penalties 84.0
# marking 63.0
# standing_tackle 75.0
# sliding_tackle 74.0
# gk_diving 14.0
# gk_handling 7.0
# gk_kicking 13.0
# gk_positioning 14.0
# gk_reflexes 8.0
# id 39825
# player_fifa_api_id 201505
# player_api_id 215584
# date 2016-04-21 00:00:00
# overall_rating 76.0
# potential 77.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 60.0
# finishing 54.0
# heading_accuracy 70.0
# short_passing 78.0
# volleys 56.0
# dribbling 63.0
# curve 48.0
# free_kick_accuracy 46.0
# long_passing 74.0
# ball_control 76.0
# acceleration 63.0
# sprint_speed 65.0
# agility 50.0
# reactions 74.0
# balance 67.0
# shot_power 78.0
# jumping 59.0
# stamina 83.0
# strength 83.0
# long_shots 72.0
# aggression 78.0
# interceptions 78.0
# positioning 64.0
# vision 68.0
# penalties 50.0
# marking 70.0
# standing_tackle 78.0
# sliding_tackle 76.0
# gk_diving 9.0
# gk_handling 12.0
# gk_kicking 7.0
# gk_positioning 11.0
# gk_reflexes 15.0
# id 88808
# player_fifa_api_id 185020
# player_api_id 150330
# date 2016-04-21 00:00:00
# overall_rating 81.0
# potential 81.0
# preferred_foot right
# attacking_work_rate high
# defensive_work_rate high
# crossing 75.0
# finishing 74.0
# heading_accuracy 65.0
# short_passing 75.0
# volleys 80.0
# dribbling 82.0
# curve 65.0
# free_kick_accuracy 65.0
# long_passing 51.0
# ball_control 84.0
# acceleration 89.0
# sprint_speed 90.0
# agility 83.0
# reactions 76.0
# balance 81.0
# shot_power 81.0
# jumping 73.0
# stamina 83.0
# strength 55.0
# long_shots 80.0
# aggression 54.0
# interceptions 40.0
# positioning 84.0
# vision 74.0
# penalties 64.0
# marking 24.0
# standing_tackle 32.0
# sliding_tackle 34.0
# gk_diving 8.0
# gk_handling 5.0
# gk_kicking 14.0
# gk_positioning 11.0
# gk_reflexes 11.0
# id 112976
# player_fifa_api_id 171877
# player_api_id 41658
# date 2016-01-28 00:00:00
# overall_rating 82.0
# potential 82.0
# preferred_foot right
# attacking_work_rate high
# defensive_work_rate medium
# crossing 78.0
# finishing 77.0
# heading_accuracy 74.0
# short_passing 86.0
# volleys 79.0
# dribbling 82.0
# curve 80.0
# free_kick_accuracy 72.0
# long_passing 78.0
# ball_control 85.0
# acceleration 75.0
# sprint_speed 77.0
# agility 76.0
# reactions 82.0
# balance 63.0
# shot_power 76.0
# jumping 72.0
# stamina 78.0
# strength 69.0
# long_shots 78.0
# aggression 62.0
# interceptions 62.0
# positioning 83.0
# vision 84.0
# penalties 70.0
# marking 56.0
# standing_tackle 64.0
# sliding_tackle 60.0
# gk_diving 8.0
# gk_handling 6.0
# gk_kicking 4.0
# gk_positioning 14.0
# gk_reflexes 14.0
# id 103129
# player_fifa_api_id 198219
# player_api_id 193441
# date 2016-04-21 00:00:00
# overall_rating 82.0
# potential 86.0
# preferred_foot right
# attacking_work_rate high
# defensive_work_rate medium
# crossing 79.0
# finishing 70.0
# heading_accuracy 56.0
# short_passing 80.0
# volleys 74.0
# dribbling 87.0
# curve 78.0
# free_kick_accuracy 75.0
# long_passing 72.0
# ball_control 88.0
# acceleration 93.0
# sprint_speed 85.0
# agility 95.0
# reactions 79.0
# balance 93.0
# shot_power 72.0
# jumping 55.0
# stamina 77.0
# strength 44.0
# long_shots 78.0
# aggression 34.0
# interceptions 26.0
# positioning 76.0
# vision 82.0
# penalties 63.0
# marking 16.0
# standing_tackle 24.0
# sliding_tackle 22.0
# gk_diving 8.0
# gk_handling 4.0
# gk_kicking 14.0
# gk_positioning 9.0
# gk_reflexes 10.0
# id 65773
# player_fifa_api_id 167664
# player_api_id 25759
# date 2016-04-21 00:00:00
# overall_rating 86.0
# potential 86.0
# preferred_foot right
# attacking_work_rate high
# defensive_work_rate medium
# crossing 68.0
# finishing 90.0
# heading_accuracy 78.0
# short_passing 72.0
# volleys 83.0
# dribbling 83.0
# curve 69.0
# free_kick_accuracy 62.0
# long_passing 58.0
# ball_control 86.0
# acceleration 79.0
# sprint_speed 83.0
# agility 74.0
# reactions 86.0
# balance 60.0
# shot_power 85.0
# jumping 73.0
# stamina 72.0
# strength 84.0
# long_shots 80.0
# aggression 50.0
# interceptions 20.0
# positioning 90.0
# vision 70.0
# penalties 74.0
# marking 12.0
# standing_tackle 22.0
# sliding_tackle 18.0
# gk_diving 5.0
# gk_handling 12.0
# gk_kicking 7.0
# gk_positioning 5.0
# gk_reflexes 10.0
# id 63597
# player_fifa_api_id 123610
# player_api_id 27684
# date 2016-01-07 00:00:00
# overall_rating 71.0
# potential 71.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 76.0
# finishing 58.0
# heading_accuracy 64.0
# short_passing 70.0
# volleys 50.0
# dribbling 67.0
# curve 66.0
# free_kick_accuracy 52.0
# long_passing 67.0
# ball_control 71.0
# acceleration 74.0
# sprint_speed 78.0
# agility 79.0
# reactions 70.0
# balance 62.0
# shot_power 72.0
# jumping 66.0
# stamina 78.0
# strength 69.0
# long_shots 71.0
# aggression 77.0
# interceptions 67.0
# positioning 73.0
# vision 60.0
# penalties 52.0
# marking 61.0
# standing_tackle 71.0
# sliding_tackle 70.0
# gk_diving 5.0
# gk_handling 5.0
# gk_kicking 8.0
# gk_positioning 8.0
# gk_reflexes 12.0
# id 92792
# player_fifa_api_id 201024
# player_api_id 210428
# date 2016-02-25 00:00:00
# overall_rating 79.0
# potential 83.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate 3
# crossing 30.0
# finishing 19.0
# heading_accuracy 77.0
# short_passing 56.0
# volleys 14.0
# dribbling 54.0
# curve 28.0
# free_kick_accuracy 28.0
# long_passing 48.0
# ball_control 60.0
# acceleration 69.0
# sprint_speed 78.0
# agility 53.0
# reactions 78.0
# balance 48.0
# shot_power 55.0
# jumping 78.0
# stamina 75.0
# strength 93.0
# long_shots 15.0
# aggression 86.0
# interceptions 78.0
# positioning 20.0
# vision 25.0
# penalties 33.0
# marking 80.0
# standing_tackle 82.0
# sliding_tackle 81.0
# gk_diving 7.0
# gk_handling 11.0
# gk_kicking 7.0
# gk_positioning 13.0
# gk_reflexes 5.0
# id 46537
# player_fifa_api_id 175943
# player_api_id 46104
# date 2016-04-21 00:00:00
# overall_rating 81.0
# potential 81.0
# preferred_foot right
# attacking_work_rate high
# defensive_work_rate low
# crossing 78.0
# finishing 74.0
# heading_accuracy 36.0
# short_passing 80.0
# volleys 70.0
# dribbling 87.0
# curve 80.0
# free_kick_accuracy 77.0
# long_passing 74.0
# ball_control 87.0
# acceleration 92.0
# sprint_speed 86.0
# agility 93.0
# reactions 72.0
# balance 92.0
# shot_power 78.0
# jumping 60.0
# stamina 76.0
# strength 42.0
# long_shots 80.0
# aggression 59.0
# interceptions 36.0
# positioning 76.0
# vision 80.0
# penalties 78.0
# marking 30.0
# standing_tackle 42.0
# sliding_tackle 40.0
# gk_diving 7.0
# gk_handling 10.0
# gk_kicking 8.0
# gk_positioning 10.0
# gk_reflexes 4.0
# id 108510
# player_fifa_api_id 198683
# player_api_id 172899
# date 2016-04-21 00:00:00
# overall_rating 78.0
# potential 82.0
# preferred_foot left
# attacking_work_rate high
# defensive_work_rate low
# crossing 70.0
# finishing 80.0
# heading_accuracy 74.0
# short_passing 74.0
# volleys 78.0
# dribbling 80.0
# curve 78.0
# free_kick_accuracy 82.0
# long_passing 64.0
# ball_control 84.0
# acceleration 79.0
# sprint_speed 84.0
# agility 74.0
# reactions 80.0
# balance 56.0
# shot_power 87.0
# jumping 76.0
# stamina 72.0
# strength 76.0
# long_shots 89.0
# aggression 59.0
# interceptions 18.0
# positioning 80.0
# vision 72.0
# penalties 72.0
# marking 18.0
# standing_tackle 26.0
# sliding_tackle 22.0
# gk_diving 12.0
# gk_handling 11.0
# gk_kicking 11.0
# gk_positioning 5.0
# gk_reflexes 5.0
# id 49091
# player_fifa_api_id 210864
# player_api_id 293160
# date 2016-03-10 00:00:00
# overall_rating 77.0
# potential 81.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 74.0
# finishing 45.0
# heading_accuracy 66.0
# short_passing 70.0
# volleys 35.0
# dribbling 70.0
# curve 32.0
# free_kick_accuracy 30.0
# long_passing 68.0
# ball_control 70.0
# acceleration 79.0
# sprint_speed 84.0
# agility 76.0
# reactions 78.0
# balance 69.0
# shot_power 66.0
# jumping 69.0
# stamina 85.0
# strength 69.0
# long_shots 41.0
# aggression 80.0
# interceptions 78.0
# positioning 60.0
# vision 54.0
# penalties 40.0
# marking 76.0
# standing_tackle 80.0
# sliding_tackle 80.0
# gk_diving 12.0
# gk_handling 6.0
# gk_kicking 14.0
# gk_positioning 9.0
# gk_reflexes 11.0
# id 178062
# player_fifa_api_id 205943
# player_api_id 177837
# date 2016-05-26 00:00:00
# overall_rating 76.0
# potential 78.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 46.0
# finishing 56.0
# heading_accuracy 73.0
# short_passing 68.0
# volleys 70.0
# dribbling 56.0
# curve 46.0
# free_kick_accuracy 25.0
# long_passing 70.0
# ball_control 66.0
# acceleration 70.0
# sprint_speed 73.0
# agility 58.0
# reactions 70.0
# balance 72.0
# shot_power 82.0
# jumping 73.0
# stamina 69.0
# strength 76.0
# long_shots 72.0
# aggression 76.0
# interceptions 78.0
# positioning 36.0
# vision 46.0
# penalties 51.0
# marking 80.0
# standing_tackle 82.0
# sliding_tackle 78.0
# gk_diving 7.0
# gk_handling 11.0
# gk_kicking 10.0
# gk_positioning 14.0
# gk_reflexes 13.0
# id 9092
# player_fifa_api_id 199914
# player_api_id 188652
# date 2016-03-24 00:00:00
# overall_rating 80.0
# potential 82.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate high
# crossing 70.0
# finishing 60.0
# heading_accuracy 59.0
# short_passing 82.0
# volleys 56.0
# dribbling 77.0
# curve 65.0
# free_kick_accuracy 49.0
# long_passing 76.0
# ball_control 78.0
# acceleration 79.0
# sprint_speed 76.0
# agility 79.0
# reactions 84.0
# balance 82.0
# shot_power 70.0
# jumping 69.0
# stamina 94.0
# strength 73.0
# long_shots 62.0
# aggression 86.0
# interceptions 84.0
# positioning 78.0
# vision 79.0
# penalties 53.0
# marking 76.0
# standing_tackle 84.0
# sliding_tackle 83.0
# gk_diving 13.0
# gk_handling 13.0
# gk_kicking 5.0
# gk_positioning 5.0
# gk_reflexes 8.0
# id 127165
# player_fifa_api_id 188876
# player_api_id 41688
# date 2016-04-21 00:00:00
# overall_rating 76.0
# potential 76.0
# preferred_foot right
# attacking_work_rate medium
# defensive_work_rate medium
# crossing 81.0
# finishing 46.0
# heading_accuracy 66.0
# short_passing 82.0
# volleys 59.0
# dribbling 63.0
# curve 70.0
# free_kick_accuracy 74.0
# long_passing 85.0
# ball_control 79.0
# acceleration 68.0
# sprint_speed 68.0
# agility 69.0
# reactions 78.0
# balance 60.0
# shot_power 71.0
# jumping 68.0
# stamina 78.0
# strength 69.0
# long_shots 71.0
# aggression 79.0
# interceptions 75.0
# positioning 63.0
# vision 82.0
# penalties 52.0
# marking 64.0
# standing_tackle 72.0
# sliding_tackle 71.0
# gk_diving 13.0
# gk_handling 6.0
# gk_kicking 10.0
# gk_positioning 10.0
# gk_reflexes 10.0

# %%
#create list of attributes for itteration 
teams.keys()
# Out:
# dict_keys(['KRC Genk', 'Beerschot AC', 'SV Zulte-Waregem', 'Sporting Lokeren', 'KSV Cercle Brugge', 'RSC Anderlecht', 'KAA Gent', 'RAEC Mons', 'FCV Dender EH', 'Standard de Liège', 'KV Mechelen', 'Club Brugge KV', 'KSV Roeselare', 'KV Kortrijk', 'Tubize', 'Royal Excel Mouscron', 'KVC Westerlo', 'Sporting Charleroi', 'Sint-Truidense VV', 'Lierse SK', 'KAS Eupen', 'Waasland-Beveren', 'KV Oostende', 'Manchester United', 'Newcastle United', 'Arsenal', 'West Bromwich Albion', 'Sunderland', 'Liverpool', 'Wigan Athletic', 'Aston Villa', 'Manchester City', 'Blackburn Rovers', 'Middlesbrough', 'Tottenham Hotspur', 'Bolton Wanderers', 'Stoke City', 'Hull City', 'Fulham', 'Chelsea', 'Portsmouth', 'Birmingham City', 'Wolverhampton Wanderers', 'Burnley', 'Blackpool', 'Queens Park Rangers', 'Norwich City', 'Southampton', 'Reading', 'Crystal Palace', 'Cardiff City', 'Leicester City', 'Bournemouth', 'Watford', 'AJ Auxerre', 'Girondins de Bordeaux', 'Le Havre AC', 'OGC Nice', 'Le Mans FC', 'FC Lorient', 'Olympique Lyonnais', 'Toulouse FC', 'AS Monaco', 'Paris Saint-Germain', 'AS Nancy-Lorraine', 'LOSC Lille', 'Stade Rennais FC', 'Olympique de Marseille', 'FC Sochaux-Montbéliard', 'Grenoble Foot 38', 'Valenciennes FC', 'RC Lens', 'Montpellier Hérault SC', "US Boulogne Cote D'Opale", 'AC Arles-Avignon', 'Stade Brestois 29', 'AC Ajaccio', 'Évian Thonon Gaillard FC', 'Dijon FCO', 'SC Bastia', 'ES Troyes AC', 'En Avant de Guingamp', 'FC Metz', 'Angers SCO', 'GFC Ajaccio', 'FC Bayern Munich', 'Hamburger SV', 'Bayer 04 Leverkusen', 'Borussia Dortmund', 'FC Schalke 04', 'Hannover 96', 'VfL Wolfsburg', '1. FC Köln', 'Eintracht Frankfurt', 'Hertha BSC Berlin', 'DSC Arminia Bielefeld', 'SV Werder Bremen', 'FC Energie Cottbus', 'TSG 1899 Hoffenheim', 'Borussia Mönchengladbach', 'VfB Stuttgart', 'Karlsruher SC', 'VfL Bochum', 'SC Freiburg', '1. FC Nürnberg', '1. FSV Mainz 05', '1. FC Kaiserslautern', 'FC St. Pauli', 'FC Augsburg', 'Fortuna Düsseldorf', 'SpVgg Greuther Fürth', 'Eintracht Braunschweig', 'SC Paderborn 07', 'FC Ingolstadt 04', 'SV Darmstadt 98', 'Atalanta', 'Siena', 'Cagliari', 'Lazio', 'Catania', 'Genoa', 'Chievo Verona', 'Reggio Calabria', 'Fiorentina', 'Juventus', 'Bologna', 'Napoli', 'Torino', 'Lecce', 'Udinese', 'Bari', 'Livorno', 'Parma', 'Brescia', 'Novara', 'Pescara', 'Hellas Verona', 'Sassuolo', 'Empoli', 'Frosinone', 'Vitesse', 'FC Groningen', 'FC Twente', 'Willem II', 'Ajax', 'FC Utrecht', 'PSV', 'Heracles Almelo', 'Feyenoord', 'Sparta Rotterdam', 'ADO Den Haag', 'FC Volendam', 'AZ', 'NAC Breda', 'RKC Waalwijk', 'VVV-Venlo', 'Excelsior', 'PEC Zwolle', 'SC Cambuur', 'Go Ahead Eagles', 'Ruch Chorzów', 'Legia Warszawa', 'P. Warszawa', 'Lechia Gdańsk', 'Widzew Łódź', 'Odra Wodzisław', 'Lech Poznań', 'GKS Bełchatów', 'Arka Gdynia', 'Piast Gliwice', 'Cracovia', 'Zawisza Bydgoszcz', 'Górnik Łęczna', 'Termalica Bruk-Bet Nieciecza', 'FC Porto', 'CF Os Belenenses', 'Sporting CP', 'Trofense', 'Vitória Setúbal', 'SC Braga', 'Amadora', 'Académica de Coimbra', 'Rio Ave FC', 'Leixões SC', 'CD Nacional', 'Naval 1° de Maio', 'União de Leiria, SAD', 'S.C. Olhanense', 'Portimonense', 'SC Beira Mar', 'Feirense', 'Gil Vicente FC', 'Uniao da Madeira', 'Falkirk', 'Rangers', 'Motherwell', 'Hibernian', 'Aberdeen', 'Celtic', 'Hamilton Academical FC', 'St. Johnstone FC', 'Dunfermline Athletic', 'Ross County FC', 'Valencia CF', 'RCD Mallorca', 'CA Osasuna', 'Villarreal CF', 'RC Deportivo de La Coruña', 'Real Madrid CF', 'CD Numancia', 'FC Barcelona', 'Racing Santander', 'Sevilla FC', 'Real Betis Balompié', 'RC Recreativo', 'Real Valladolid', 'Athletic Club de Bilbao', 'UD Almería', 'Atlético Madrid', 'Málaga CF', 'Xerez Club Deportivo', 'Real Zaragoza', 'CD Tenerife', 'Hércules Club de Fútbol', 'Levante UD', 'Real Sociedad', 'Granada CF', 'RC Celta de Vigo', 'Elche CF', 'SD Eibar', 'Córdoba CF', 'Grasshopper Club Zürich', 'AC Bellinzona', 'BSC Young Boys', 'FC Basel', 'FC Aarau', 'FC Luzern', 'Neuchâtel Xamax', 'FC Zürich', 'FC St. Gallen', 'FC Thun', 'Servett ...

# %%
#get team averages definition
for player in teams['Napoli']:
    print(teams['Napoli'][player]['crossing'])
# Out:
# 79.0
# 38.0
# 43.0
# 80.0
# 70.0
# 60.0
# 75.0
# 78.0
# 79.0
# 68.0
# 76.0
# 30.0
# 78.0
# 70.0
# 74.0
# 46.0
# 70.0
# 81.0
